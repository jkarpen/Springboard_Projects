# %%
import pandas as pd
import json

# %% [markdown]
# # AirBnB Dataset Analysis

# %%
#Read in AirBnB data sample
#Start with Listings Data
path='D:/Coding Projects/Springboard/Capstone/AirBnB/Toronto/listings.csv'
abb_list = pd.read_csv(path)
abb_list.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   1419   https://www.airbnb.com/rooms/1419  20180808031137   2018-08-08
# 1   8077   https://www.airbnb.com/rooms/8077  20180808031137   2018-08-08
# 2  10314  https://www.airbnb.com/rooms/10314  20180808031137   2018-08-08
# 3  12604  https://www.airbnb.com/rooms/12604  20180808031137   2018-08-08
# 4  17936  https://www.airbnb.com/rooms/17936  20180808031137   2018-08-08
#
#                                  name  \
# 0     Beautiful home in amazing area!
# 1  Downtown Harbourfront Private Room
# 2          Union Inn II (Leslieville)
# 3      Seaton Village Parlour Bedroom
# 4    Private Room in Downtown Toronto
#
#                                              summary  \
# 0  This large, family home is located in one of T...
# 1  Guest room in a luxury condo with access to al...
# 2  We offer a private room for two with a queen b...
# 3   Comfortable sofa bed in airy main floor parlour.
# 4  First of all, I'd like to say a BIG Thank You ...
#
#                                                space  \
# 0  Visit Toronto with this fabulous furnished hom...
# 1  My husband and I are both artists. I give pain...
# 2  The 'union inn' offers a clean, spacious room ...
# 3  Family of 4 (2 kids)  plus a friendly dog open...
# 4  Welcome!  Charming walk-up apartment in Downto...
#
#                                          description experiences_offered  \
# 0  This large, family home is located in one of T...                none
# 1  Guest room in a luxury condo with access to al...                none
# 2  We offer a private room for two with a queen b...                none
# 3  Comfortable sofa bed in airy main floor parlou...                none
# 4  First of all, I'd like to say a BIG Thank You ...                none
#
#                                neighborhood_overview        ...          \
# 0  The apartment is located in the Ossington stri...        ...
# 1                                                NaN        ...
# 2  Our charming adopted home of Leslieville is a ...        ...
# 3                                                NaN        ...
# 4  The building is central to so many great neigh...        ...
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                t
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1               0.19
# 1                               2               1.56
# 2                               1               0.71
# 3                               1                NaN
# 4                               2               1.18
#
# [5 rows x 96 columns]

# %%
abb_list.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  1.754200e+04  1.754200e+04            0.0         0.0             0.0
# mean   1.683533e+07  2.018081e+13            NaN         NaN             NaN
# std    7.578725e+06  4.972798e+00            NaN         NaN             NaN
# min    1.419000e+03  2.018081e+13            NaN         NaN             NaN
# 25%    1.125480e+07  2.018081e+13            NaN         NaN             NaN
# 50%    1.847656e+07  2.018081e+13            NaN         NaN             NaN
# 75%    2.302324e+07  2.018081e+13            NaN         NaN             NaN
# max    2.758201e+07  2.018081e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  1.754200e+04                   0.0         17540.000000
# mean   6.267028e+07                   NaN             4.478506
# std    5.967271e+07                   NaN            10.010340
# min    1.565000e+03                   NaN             0.000000
# 25%    1.274210e+07                   NaN             1.000000
# 50%    3.953265e+07                   NaN             1.000000
# 75%    1.038567e+08                   NaN             3.000000
# max    2.081082e+08                   NaN           128.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed  \
# count               17540.000000                           0.0
# mean                    4.478506                           NaN
# std                    10.010340                           NaN
# min                     0.000000                           NaN
# 25%                     1.000000                           NaN
# 50%                     1.000000                           NaN
# 75%                     3.000000                           NaN
# max                   128.000000                           NaN
#
#              ...          review_scores_accuracy  review_scores_cleanliness  \
# count        ...                    14039.000000               14040.000000
# mean         ...                        9.635515                   9.405484
# std          ...                        0.798646                   0.963120
# min          ...                        2.000000                   2.000000
# 25%          ...                        9.000000                   9.000000
# 50%          ...                       10.000000                  10.000000
# 75%          ...                       10.000000                  10.000000
# max          ...                       10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           14035.000000                 14041.000000
# mean                9.755397                     9.762837
# std                 0.704294                     0.700338
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  license  \
# count            14032.000000         14033.000000      0.0
# mean                 9.641320             9.473455      NaN
# std                  0.708932             0.854359      NaN
# min                  2.000000             2.000000      NaN
# 25%                  9.000000             9.000000      NaN
# 50%                 10.000000            10.000000      NaN
# 75%                 10.000000            10.000000      NaN
# max                 10.000000            10.000000      NaN
#
#        jurisdiction_names  calculated_host_listings_count  reviews_per_month
# count                 0.0                    17542.000000       14315.000000
# mean                  NaN                        3.791130           1.950937
# std                   NaN                        7.754612           2.141343
# min                   NaN                        1.000000           0.010000
# 25%                   NaN                        1.000000           0.410000
# 50%                   NaN                        1.000000           1.100000
# 75%                   NaN                        3.000000           2.830000
# max                   NaN                       67.000000          16.860000
#
# [8 rows x 36 columns]

# %%
abb_list['jurisdiction_names'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: jurisdiction_names, dtype: float64

# %%
#Next view the Calendar data
path='D:/Coding Projects/Springboard/Capstone/AirBnB/Toronto/calendar.csv'
abb_cal = pd.read_csv(path)
abb_cal.head()
# Out:
#    listing_id        date available    price
# 0      183522  2019-08-07         t  $180.00
# 1      183522  2019-08-06         t  $180.00
# 2      183522  2019-08-05         t  $180.00
# 3      183522  2019-08-04         t  $180.00
# 4      183522  2019-08-03         t  $180.00

# %% [markdown]
# # Yelp Dataset Analysis
#
# Next we will open the Yelp dataset. This data comes from Yelp's Academic dataset, found here: https://www.yelp.com/dataset
#
# The data is made available by Yelp in JSON format.
#
# (Insert more info here, and the Kaggle links with additional documentation).

# %%
#Read in Yelp Business dataset
path='D:/Coding Projects/Springboard/Capstone/Yelp/yelp_academic_dataset_business.json'
yelp_df = pd.read_json(path, lines=True)

# %%
yelp_df.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                       {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': '{'ro...
# 3      211 W Monroe St                                               None
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
#         city                                              hours  is_open  \
# 0    Calgary  {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0'...        1
# 1  Henderson  {'Friday': '17:0-23:0', 'Saturday': '17:0-23:0...        0
# 2  Montr̩al  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...        0
# 3    Phoenix                                               None        1
# 4    Calgary  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1
#
#     latitude   longitude                  name               neighborhood  \
# 0  51.091813 -114.031675  Minhas Micro Brewery
# 1  35.960734 -114.939821   CK'S BBQ & Catering
# 2  45.540503  -73.599300         La Bastringue  Rosemont-La Petite-Patrie
# 3  33.449999 -112.076979       Geico Insurance
# 4  51.035591 -114.027366         Action Engine
#
#   postal_code  review_count  stars state
# 0     T2E 6L6            24    4.0    AB
# 1       89002             3    4.5    NV
# 2     H2G 1K7             5    4.0    QC
# 3       85003             8    1.5    AZ
# 4     T2H 0N5             4    2.0    AB

# %%
#View list of cities
print(list(yelp_df.city.unique()))
# Out:
# ['Calgary', 'Henderson', 'Montr̩al', 'Phoenix', 'Toronto', 'Mississauga', 'Avondale', 'Pittsburgh', 'Markham', 'Las Vegas', 'Cleveland', 'Monticello', 'Streetsboro', 'Sun Prairie', 'Cave Creek', 'Middlefield', 'Medina', 'Gilbert', 'Upper St Clair', 'Avalon', 'North York', 'Monroeville', 'Concord', 'Charlotte', 'Tolleson', 'Mesa', 'Kent', 'South Euclid', 'Surprise', 'Scottsdale', 'Woodbridge', 'Thornhill', 'Tempe', 'Gastonia', 'North Las Vegas', 'Rocky River', 'Glendale', 'Richmond Hill', 'North Randall', 'Peoria', 'Richfield', 'Laval', 'Brooklyn', 'Garfield Heights', 'Landau', 'las vegas', 'Goodyear', 'Mentor', 'Amherst', 'Matthews', 'Chagrin Falls', 'Montreal', 'Ajax', 'Laveen Village', 'Etobicoke', 'Lakewood', 'Scarborough', 'Madison', 'Oakville', 'Stouffville', 'Chandler', 'Monroe', 'Pleasant Hills', 'Brunswick', 'Fountain Hills', 'East Gwillimbury', 'Mount Holly', 'Longueuil', 'Fort Mill', 'Swissvale', 'Litchfield Park', 'Verona', 'Waxhaw', 'Paradise Valley', 'Fitchburg', 'Avon', 'Mayfield Heights', 'Dorval', 'Wesley Chapel', 'Brampton', 'Westlake', 'Champaign', 'Maple', 'Wexford', 'Bedford', 'Broadview Heights', 'Stow', 'Tuscola', 'Heidelberg', 'East Mississauga', 'Pepper Pike', 'Newmarket', 'Vaughan', 'Peninsula', 'Maricopa County', 'Waddell', 'Cramerton', 'Imperial', 'Pickering', 'Parma', 'St-Jerome', 'Urbana', 'Oka', 'Murrysville', 'Irwin', 'Paradise', 'University Heights', 'Blainville', 'Stoughton', 'Higley', 'Cheswick', 'Pineville', 'Moon Twp', 'Solon', 'Pointe-Claire', 'Brossard', 'Huntersville', 'Sainte-Julie', 'MESA', 'Millvale', 'Belmont', 'Fairlawn', 'Euclid', 'Homestead', 'Macedonia', 'Beachwood', 'San Tan Valley', 'Lasalle', 'Nobleton', 'Painesville', 'Allison Park', 'McMurray', 'Chesterland', 'Twinsburg', 'Strongsville', 'Mentor On the Lake', 'Kirtland', 'Aurora', 'Bridgeville', 'Cuyahoga Falls', 'Northfield', 'Oregon', 'Cornelius', 'Bolton', 'Anthem', 'North Ridgeville', 'Stanley', 'Springdale', 'Mayfield', 'Fairview Park', 'East York', 'Saint-Laurent', 'North Versailles', 'Woodmere', 'Oakland', 'West Mifflin', 'Youngtown', 'Davidson', 'Tallmadge', 'Sun City', 'Candiac', 'Whitby', 'DeForest', 'Dollard-Des-Ormeaux', 'Saint-Sauveur', 'Rosemere', 'Pitcairn', 'Wilmerding', 'clinton', 'Boisbriand', 'York', 'Lyndhurst', 'Chandler-Gilbert', 'Roosevelt', 'Hudson', 'Buckeye', 'Carnegie', 'Westmount', 'Coraopolis', 'Sainte-Anne-De-Bellevue', 'Outremont', 'Berea', 'Sainte-Therese', 'Waunakee', 'Laval, Pont Viau', 'Lawrenceville', 'Rosem̬re', 'Montreal-West', 'Moon', 'Chardon', 'De Forest', 'Olivos', 'Mirabel', 'Parma Heights', 'Lam', 'Chateauguay', 'Middleburg Heights', 'Dallas', 'Stallings', 'Trafford', 'Division No. 6', 'Bradfordwoods', 'Sewickley', 'Vanier', 'Middleton', 'Georgetown', 'Saint-Jerome', 'Boulder City', 'NorthEast Calgary', 'Brecksville', 'Thale', 'Lake Wylie', 'Penn Hills', 'Lowell', 'Glbert', 'North Royalton', 'Cecil', 'Robinson Township', 'Oakwood', 'Cross Plains', 'N Las Vegas', 'Braddock', 'St Martin', 'Canonsburg', 'LaSalle', 'Maple Heights', 'Castle Shannon', 'Indian Trail', 'Philo', 'McKees Rocks', 'Homer', 'Indian Land', 'Streetsville', 'Monona', 'West Homestead', 'N. Las Vegas', 'Brook Park', 'St. Jean Sur Richelieu', 'South Park Township', 'Brookline', 'Dollard-Des Ormeaux', 'Mantua', 'Sheffield Village', 'Mint Hill', 'Willowick', 'Avon Lake', 'Mount Albert', 'Kannapolis', 'Whitchurch-Stouffville', 'Fort  Mill', 'Frazer', 'Fort McDowell', 'Sainte-Marguerite-Esterel', 'Savoy', 'Highland Heights', 'Unionville', 'Boston Heights', 'Mahomet', 'Saint-Leonard', 'Oakmont', 'Brooklin', 'Sainte-Marguerite-du-lac-Masson', 'Kirkland', 'Brookpark', 'Pierrefonds', 'Saint-Lazare', 'Anjou', 'Stade', 'Noyan', 'King', 'Venetia', 'Bratenahl', 'Agincourt', 'Airdrie', 'peoria', 'Hinckley', 'Willoughby Hills', 'Verdun', 'Midland', 'West View', 'Lacolle', 'El Mirage', 'Harrisburg', 'Willoughby', 'Chestermere', 'Saint-Hubert', 'Guadalupe', 'Bay Village', 'Harrison City', 'Elyria', 'Schomberg', 'Spring Valley', 'Gi ...

# %%
#There are too many cities to view this way,
#...instead let's look for the top 10 cities in the dataset

city_count = yelp_df['city'].value_counts().to_frame().reset_index().sort_values('city', ascending=False)

city_count.head(10)
# Out:
#         index   city
# 0   Las Vegas  28865
# 1     Phoenix  18633
# 2     Toronto  18233
# 3   Charlotte   9204
# 4  Scottsdale   8822
# 5     Calgary   7384
# 6  Pittsburgh   6804
# 7        Mesa   6239
# 8   Montr̩al   6045
# 9   Henderson   4815
