# %% [markdown]
# # Capstone Statistical Inference Testing
#
# ## Introduction
# This script contains the code I used to perform statistical inference on my Capstone AirBnB dataset. I previously cleaned the data during the Data Wrangling step, and merged it with relevant Yelp data. Then I created visualizations showing some distributions and relationships between variables as a first step in the Exploratory Data Analysis process. The next EDA step is to perform statistical tests to dive deeper into those relationships.
#
# Questions I plan to answer:
#
#  - Does Price follow a normal distribution? What if I convert to a log scale?
#  - How correlated are Beds, Bedrooms, Bathrooms, and Accomodates with Price? What about their correlation with Reviews per Month?
#  - Are Price and Reviews per Month correlated?
#  - For hosts that respond 100% of the time, are any of the response time groupings more related to price than the others? What about Reviews per Month?
#  - For each Amenity, how does it impact Price/Reviews per Month (using t-tests against the rest of the listings that don't have that amenity).
#  - For each Property Type, how does it impact Price/Reviews per Month?
#  - Using the Yelp data, how are number of businesses, number of reviews, and avg. star rating correlated with Price/Reviews per Month?
#  - Using the Yelp data, is there a significant Price difference between listings with no businesses w/in .1 mile and those that do? What about between those that have no businesses w/in .5 mile and those that do? Same for Reviews per Month.
#
# ## Import packages, load data

# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy import stats
from statsmodels.stats.weightstats import ztest
#allow all columns to be viewed:
pd.set_option('display.max_columns', None)
import datetime as dt

# %%
current_path = % pwd
#If current_path is in Scripts folder, 
#go up one level so we can open the data folder
if (current_path.rsplit('\\', 1)[1] == 'Scripts'):
    % cd ..
# Out:
# D:\Coding Projects\Springboard\Springboard_Projects\Capstone

# %%
#Import data

#Read in AirBnB dataset that has been merged with summarized Yelp information:
#... (number of businesses, total reviews, and average star rating for businesses w/in .1 and .5 miles)
path1='../Capstone/Data/abb_merged.csv'
abb = pd.read_csv(path1)

print(abb.shape)
abb.head()
# Out:
# (16015, 239)
#       id                         listing_url host_response_time  \
# 0   1419   https://www.airbnb.com/rooms/1419     within an hour
# 1  10314  https://www.airbnb.com/rooms/10314     within an hour
# 2  12604  https://www.airbnb.com/rooms/12604     within an hour
# 3  17936  https://www.airbnb.com/rooms/17936     within an hour
# 4  23691  https://www.airbnb.com/rooms/23691     within an hour
#
#    host_response_rate host_is_superhost host_neighbourhood       neighborhood  \
# 0                 0.0                 f   Commercial Drive    Little Portugal
# 1                 0.0                 f          Riverdale          Riverdale
# 2                 0.0                 f          The Annex          The Annex
# 3               100.0                 t  Kensington Market  Kensington Market
# 4               100.0                 t           Fairbank           Wychwood
#
#   neighbourhood_cleansed   latitude  longitude property_type        room_type  \
# 0        Little Portugal  43.646168 -79.424510         House  Entire home/apt
# 1        South Riverdale  43.670186 -79.335848         House     Private room
# 2                  Annex  43.667241 -79.415978         House     Private room
# 3   Kensington-Chinatown  43.656400 -79.403295     Apartment     Private room
# 4   Briar Hill-Belgravia  43.696017 -79.454683         House     Private room
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0           6.0        2.0       3.0   4.0       Real Bed
# 1           2.0        1.0       1.0   1.0       Real Bed
# 2           1.0        1.5       1.0   1.0  Pull-out Sofa
# 3           4.0        1.0       1.0   2.0       Real Bed
# 4           2.0        1.0       1.0   1.0       Real Bed
#
#                                            amenities  price  security_deposit  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  470.0            1000.0
# 1  {Wifi,"Air conditioning",Kitchen,"Free parking...   69.0               0.0
# 2  {Internet,Wifi,"Pets live on this property",Ca...   65.0             130.0
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   99.0             300.0
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...   70.0               0.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0         150.0              1.0           0.0             4.0
# 1           0.0              2.0          20.0             1.0
# 2          26.0              1.0          20.0             1.0
# 3          80.0              1.0          20.0             2.0
# 4           0.0              2.0          25.0             1.0
#
#   calendar_updated  availability_30  availability_60  availability_90  \
# 0     6 months ago                0                0                0
# 1    11 months ago                0                0               21
# 2        yesterday                0                0                0
# 3       4 days ago                5                5               23
# 4            today                0               10               40
#
#    availability_365 instant_bookable          cancellation_policy  \
# 0                 0                f  strict_14_with_grace_period
# 1               296                f                     moderate
# 2                 0                f                     moderate
# 3                23                f  strict_14_with_grace_period
# 4               315                t  strict_14_with_grace_period
#
#    reviews_per_month  square_feet_notNA  monthly_price_notNA  \
# 0               0.19               True                False
# 1               0.71              False                 True
# 2               0.00               True                 True
# 3               1.18              False                 True
# 4               2.02              False                 True
#
#    weekly_price_notNA  bathrooms_notNA  beds_notNA  bedrooms_notNA  \
# 0                True             True        True            True
# 1                True             True        True            True
# 2                True             True        True            True
# 3                True             True        True            True
# 4                True             True        True            True
#
#    security_deposit_notNA  cleaning_fee_notNA  host_response_rate_notNA  \
# 0                    True                True                     False
# 1                   False               False                     False
# 2                    True                True                     False
# 3                    True                True                      True
# 4                    True                True                      True
#
#    reviews_per_month_notNA  neighbourhood_notNA  host_neighbourhood_notNA  \
# 0                     True                 True                      True
# 1                     True                 True                      True
# 2                    False                 True                      True
# 3                     True                 True                      True
# 4                     True                 True                      True
#
#    neighbourhood_cleansed_notNA  host_response_time_notNA  \
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                      True
# 4                          True                      True
#
#    host_is_superhost_notNA  has_Wifi  has_Heating  has_Essentials  \
# 0                     True      True        False           False
# 1                     True      True        False           False
# 2                     True      True        False           False
# 3                     True      True        False           False
# 4                     True      True        False           False
#
#    has_Kitchen  has_Smoke_detector  has_Air_conditioning  has_Hangers  \
# 0         True               False                  True        False
# 1         True               False                  True        False
# 2        False               False                 False        False
# 3         True               False                  True        False
# 4         True               False                  True        False
#
#    has_Washer  has_Dryer  has_Shampoo  has_Carbon_monoxide_detector  \
# 0       False      False        False                         False
# 1       False      False        False                         False
# 2       False      False        False                         False
# 3       False      False        False                         False
# 4       False      False        False                         False
#
#    has_Laptop_friendly_workspace  has_TV  has_Hair_dryer  has_Iron  \
# 0                          False    True           False     False
# 1                          False   False           False     False
# 2                          False   False           False     False
# 3                          False    True           False     False
# 4                          False   False           False     False
#
#    has_Hot_water  has_Fire_extinguisher  has_Familykid_friendly  has_Elevator  \
# 0          False                  False                   False         False
# 1          False                  False                   False         False
# 2          False                  False                   False         False
# 3          False                  False                   False         False
# 4          False                  False                   False         False
#
#    has_Free_parking_on_premises  has_First_aid_kit  has_Refrigerator  \
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
#
#    has_Internet  has_Dishes_and_silverware  has_Gym  has_Microwave  has_Stove  \
# 0          True                      False    False          False      False
# 1         False                      False    False          False      False
# 2          True                      False    False          False      False
# 3          True                      False    False          False      False
# 4          True                      False    False          False      False
#
#    has_Self_check-in  has_Oven  has_Bed_linens  has_Cooking_basics  \
# 0              False     False           False               False
# 1              False     False           False               False
# 2              False     False           False               False
# 3              False     False           False               False
# 4              False     False           False               False
#
#    has_Lock_on_bedroom_door  has_Long_term_stays_allowed  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    has_Private_entrance  has_Coffee_maker  has_Cable_TV  has_Step-free_access  \
# 0                 False             False         False                 False
# 1                 False             False         False                 False
# 2                 False             False         False                 False
# 3                 False             False         False                 False
# 4                 False             False         False                 False
#
#    has_Extra_pillows_and_blankets  has_Dishwasher  \
# 0                           False           False
# 1                           False           False
# 2                           False           False
# 3                           False           False
# 4                           False           False
#
#    has_translation_missing:_en.hosting_amenity_50  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    has_Paid_parking_off_premises  has_Pool  has_Luggage_dropoff_allowed  \
# 0                          False     False                        False
# 1                          False     False                        False
# 2                          False     False                        False
# 3                          False     False                        False
# 4                          False     False                        False
#
#    has_Patio_or_balcony  has_Safety_card  \
# 0                 False            False
# 1                 False            False
# 2                 False            False
# 3                 False            False
# 4                 False            False
#
#    has_translation_missing:_en.hosting_amenity_49  has_Hot_tub  \
# 0                                           False        False
# 1                                           False        False
# 2                                           False        False
# 3                                           False        False
# 4                                           False        False
#
#    has_Host_greets_you  has_Lockbox  has_24-hour_check-in  has_Pets_allowed  \
# 0                False        False                 False             False
# 1                False        False                 False             False
# 2                False        False                 False             False
# 3                False        False                 False             False
# 4                False        False                 False             False
#
#    has_Private_living_room  has_Paid_parking_on_premises  has_Breakfast  \
# 0                    False                         False          False
# 1                    False                         False          False
# 2                    False                         False          False
# 3                    False                         False          False
# 4                    False                         False          False
#
#    has_Bathtub  has_Wide_doorway  has_Buzzerwireless_intercom  \
# 0        False             False                        False
# 1        False             False                        False
# 2        False             False                        False
# 3        False             False                        False
# 4        False             False                        False
#
#    has_Garden_or_backyard  has_Indoor_fireplace  has_Keypad  \
# 0                   False                 False       False
# 1                   False                 False       False
# 2                   False                 False       False
# 3                   False                 False       False
# 4                   False                 False       False
#
#    has_Free_street_parking  has_Other  has_Wheelchair_accessible  has_Doorman  \
# 0                    False      False                      False        False
# 1                    False      False                      False        False
# 2                    False      False                      False        False
# 3                    False      False                      False        False
# 4                    False      False                      False        False
#
#    has_Pets_live_on_this_property  has_Well-lit_path_to_entrance  \
# 0                           False                          False
# 1                           False                          False
# 2                            True                          False
# 3                           False                          False
# 4                           False                          False
#
#    has_BBQ_grill  has_Ethernet_connection  has_Single_level_home  \
# 0          False                    False                  False
# 1          False                    False                  False
# 2          False                    False                  False
# 3          False                    False                  False
# 4          False                    False                  False
#
#    has_Wide_hallway_clearance  has_Room-darkening_shades  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    has_Flat_path_to_front_door  has_Smoking_allowed  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    has_Children’s_books_and_toys  has_Wide_clearance_to_bed  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
#
#    has_Building_staff  has_Smart_lock  has_Wide_entryway  has_High_chair  \
# 0               False           False              False           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False           False              False           False
# 4               False           False              False           False
#
#    has_Cleaning_before_checkout  has_Pack_’n_Playtravel_crib  has_Dog(s)  \
# 0                         False                        False       False
# 1                         False                        False       False
# 2                         False                        False       False
# 3                         False                        False       False
# 4                         False                        False       False
#
#    has_Accessible-height_bed  has_Cat(s)  has_Suitable_for_events  \
# 0                      False       False                    False
# 1                      False       False                    False
# 2                      False       False                    False
# 3                      False       False                    False
# 4                      False       False                    False
#
#    has_Accessible-height_toilet  has_Lake_access  has_Waterfront  has_Crib  \
# 0                         False            False           False     False
# 1                         False            False           False     False
# 2                         False            False           False     False
# 3                         False            False           False     False
# 4                         False            False           False     False
#
#    has_Handheld_shower_head  has_Children’s_dinnerware  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    has_Disabled_parking_spot  has_Game_console  has__toilet  \
# 0                      False             False        False
# 1                      False             False        False
# 2                      False             False        False
# 3                      False             False        False
# 4                      False             False        False
#
#    has_Wide_clearance_to_shower  has_Pocket_wifi  \
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
#
#    has_Babysitter_recommendations  has_Full_kitchen  has_Outlet_covers  \
# 0                           False             False              False
# 1                           False             False              False
# 2                           False             False              False
# 3                           False             False              False
# 4                           False             False              False
#
#    has_Stair_gates  has_Baby_bath  has_Hot_water_kettle  has_Window_guards  \
# 0            False          False                 False              False
# 1            False          False                 False              False
# 2            False          False                 False              False
# 3            False          False                 False              False
# 4            False          False                 False              False
#
#    has_Bathroom_essentials  has_Bedroom_comforts  has_Changing_table  \
# 0                    False                 False               False
# 1                    False                 False               False
# 2                    False                 False               False
# 3                    False                 False               False
# 4                    False                 False               False
#
#    has_Toilet_paper  has_Bath_towel  has_Body_soap  has_EV_charger  \
# 0             False           False          False           False
# 1             False           False          False           False
# 2             False           False          False           False
# 3             False           False          False           False
# 4             False           False          False           False
#
#    has_Beachfront  has_Fireplace_guards  has_Netflix  has_Other_pet(s)  \
# 0           False                 False        False             False
# 1           False                 False        False             False
# 2           False                 False        False             False
# 3           False                 False        False             False
# 4           False                 False        False             False
#
#    has_Roll-in_shower  has_  has_Beach_essentials  has_Smart_TV  \
# 0               False  True                 False         False
# 1               False  True                 False         False
# 2               False  True                 False         False
# 3               False  True                 False         False
# 4               False  True                 False         False
#
#    has_Baby_monitor  has_Fixed_grab_bars_for_shower  has_Breakfast_table  \
# 0             False                           False                False
# 1             False                           False                False
# 2             False                           False                False
# 3             False                           False                False
# 4             False                           False                False
#
#    has_Walk-in_shower  has_Convection_oven  has_Outdoor_seating  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
#
#    has_Sound_system  has_Bathtub_with_bath_chair  has_Rain_shower  \
# 0             False                        False            False
# 1             False                        False            False
# 2             False                        False            False
# 3             False                        False            False
# 4             False                        False            False
#
#    has_Balcony  has_Pillow-top_mattress  has_Table_corner_guards  \
# 0        False                    False                    False
# 1        False                    False                    False
# 2        False                    False                    False
# 3        False                    False                    False
# 4        False                    False                    False
#
#    has_Soaking_tub  has_Formal_dining_area  has_En_suite_bathroom  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    has_Memory_foam_mattress  has_Terrace  has_Central_air_conditioning  \
# 0                     False        False                         False
# 1                     False        False                         False
# 2                     False        False                         False
# 3                     False        False                         False
# 4                     False        False                         False
#
#    has_Shower_chair  has_Espresso_machine  has_Firm_mattress  has_Gas_oven  \
# 0             False                 False              False         False
# 1             False                 False              False         False
# 2             False                 False              False         False
# 3             False                 False              False         False
# 4             False                 False              False         False
#
#    has_Ceiling_fan  has_Heated_floors  has_Fixed_grab_bars_for_toilet  \
# 0            False              False                           False
# 1            False              False                           False
# 2            False              False                           False
# 3            False              False                           False
# 4            False              False                           False
#
#    has_DVD_player  has_Exercise_equipment  has_Printer  has_Outdoor_parking  \
# 0           False                   False        False                False
# 1           False                   False        False                False
# 2           False                   False        False                False
# 3           False                   False        False                False
# 4           False                   False        False                False
#
#    has_Private_bathroom  has_Shared_gym  has_Day_bed  has_HBO_GO  \
# 0                 False           False        False       False
# 1                 False           False        False       False
# 2                 False           False        False       False
# 3                 False           False        False       False
# 4                 False           False        False       False
#
#    has_Kitchenette  has_Murphy_bed  has_Amazon_Echo  has_Shared_pool  \
# 0            False           False            False            False
# 1            False           False            False            False
# 2            False           False            False            False
# 3            False           False            False            False
# 4            False           False            False            False
#
#    has_Warming_drawer  has_Ski_inSki_out  has_Fire_pit  has_Mini_fridge  \
# 0               False              False         False            False
# 1               False              False         False            False
# 2               False              False         False            False
# 3               False              False         False            False
# 4               False              False         False            False
#
#    has_Pool_with_pool_hoist  has_Sauna  has_Heated_towel_rack  \
# 0                     False      False                  False
# 1                     False      False                  False
# 2                     False      False                  False
# 3                     False      False                  False
# 4                     False      False                  False
#
#    has_Electric_profiling_bed  has_High-resolution_computer_monitor  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    has_Wine_cooler  has_Air_purifier  has_Ground_floor_access  \
# 0            False             False                    False
# 1            False             False                    False
# 2            False             False                    False
# 3            False             False                    False
# 4            False             False                    False
#
#    has_Shared_hot_tub  has_Jetted_tub  has_Mudroom  has_Touchless_faucets  \
# 0               False           False        False                  False
# 1               False           False        False                  False
# 2               False           False        False                  False
# 3               False           False        False                  False
# 4               False           False        False                  False
#
#    has_Sun_loungers  has_Mountain_view  has_Standing_valet  has_Double_oven  \
# 0             False              False               False            False
# 1             False              False               False            False
# 2             False              False               False            False
# 3             False              False               False            False
# 4             False              False               False            False
#
#    has_Fax_machine  has_Bidet  has_Beach_view  has_Brick_oven  \
# 0            False      False           False           False
# 1            False      False           False           False
# 2            False      False           False           False
# 3            False      False           False           False
# 4            False      False           False           False
#
#    has_Private_hot_tub  has_Washer__Dryer  has_Hammock  \
# 0                False              False        False
# 1                False              False        False
# 2                False              False        False
# 3                False              False        False
# 4                False              False        False
#
#    has_Projector_and_screen  has_Alfresco_bathtub  has_Steam_oven  \
# 0                     False                 False           False
# 1                     False                 False           False
# 2                     False                 False           False
# 3                     False                 False           False
# 4                     False                 False           False
#
#    host_lives_near_listing  yelp_bus_count_1  yelp_bus_total_reviews_1  \
# 0                    False               1.0                      66.0
# 1                     True               NaN                       NaN
# 2                     True               NaN                       NaN
# 3                     True              20.0                    1440.0
# 4                     True               NaN                       NaN
#
#    yelp_bus_avg_rating_1  yelp_bus_count_5  yelp_bus_total_reviews_5  \
# 0                   3.50             116.0                    8634.0
# 1                    NaN               NaN                       NaN
# 2                    NaN              11.0                    1631.0
# 3                   3.65             160.0                   11434.0
# 4                    NaN              11.0                     147.0
#
#    yelp_bus_avg_rating_5
# 0               3.758621
# 1                    NaN
# 2               3.045455
# 3               3.715625
# 4               3.363636

# %% [markdown]
# ## Drop Unnecessary Variables

# %% [markdown]
# First, I will drop variables that I have decided are not worth further analysis. These include the listing URL, the host neighborhood (I have already created a derived variable that checks if the host lives in their listing neighborhood), and the amenities (I have created flag variables for each amenity).

# %%
#Drop variables not needed for analysis
drop_cols = ['listing_url', 'host_neighbourhood', 'neighbourhood_cleansed', 'amenities', 'calendar_updated', 'latitude', 'longitude',
            "availability_60", "availability_90", "availability_30", "availability_365", "reviews_per_month"]
abb.drop(columns=drop_cols, axis=1, inplace=True)

# %%
abb.shape
# Out:
# (16015, 227)

# %% [markdown]
# ## Statistical Tests
#
# ### Test 1 - Normality of Price/Log Price
# My primary goal with this project is to predict the Price of AirBnB listings, so first I will example that outcome variable.
#
# First I will use the Kolmogorov-Smirnov test to check if the distribution of Price is normal. I suspect I will find that price is not normally distributed, because visualizing it shows a peak at the left or lower-priced end of the range, with a long tail to the right or high-priced end.
#
# The null hypothesis for this test is that Price follows a normal distribution. The alternate hypothesis is that it has any other distribution.

# %%
#As a reminder, here is what the plot of price distribution looks like.
plt.hist(abb.price, bins=10)
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
#generate summary statistics
price_mean = np.mean(abb.price)
price_std = np.std(abb.price)

test_stat = stats.kstest(abb['price'], 'norm', args=(price_mean, price_std))
test_stat
# Out:
# KstestResult(statistic=0.14900645034332038, pvalue=2.80763205512359e-309)

# %% [markdown]
# The p-value returned is extremely small, 2.81e-309, therefore we can reject the null hypothesis that Price follows a normal distribution. Next I will check log of price to see if it is normal. If so it would be more useful for statistical inference and modeling.

# %%
abb['log_price'] = np.log(abb.price)

# %%
plt.hist(abb.log_price, bins=10)
plt.xlabel('Log Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the histogram alone, log_price appears much more normally distributed compared to the original price variable. I will check again using the K-S test.

# %%
log_price_mean = np.mean(abb.log_price)
log_price_std = np.std(abb.log_price)

test_stat = stats.kstest(abb['log_price'], 'norm', args=(log_price_mean, log_price_std))
test_stat
# Out:
# KstestResult(statistic=0.037374718910779425, pvalue=7.412111228977069e-20)

# %% [markdown]
# Interestingly, the log of price still has a very low p-value from the K-S test. At 7.41e-20 it is higher than the p-value achieved by the original price variable, but it is still low enough that we must reject the null hypothesis that log price follows a normal distribution. However I will still use it for my statistical tests to follow.
#
# Next I want to check how log price changes the relationship with some of the variables that appeared to have a strong relationship to price, like # of beds.

# %%
fig=plt.figure(figsize=(10, 5), dpi=100)

sns.boxplot(x='bedrooms', y='price', data=abb, palette='Set3')
plt.show()

# %%
fig=plt.figure(figsize=(10, 5), dpi=100)

sns.boxplot(x='bedrooms', y='log_price', data=abb, palette='Set3')
plt.show()

# %%
fig=plt.figure(figsize=(10, 5), dpi=100)

sns.stripplot(y='log_price', x='bedrooms', data=abb, palette='Set3', alpha=.4)
plt.show()

# %% [markdown]
# ### Test 2 - Check the distribution of utilization rate
#
# My secondary goal is to predict the utilization rate of bookings, so I will test it's distribution next. First I need to derive the utilization rate. The process is described on pages 49-51 in the "Analysis of the impact of short-term rentals on housing" report from San Francisco's Budget and Legislative Office. The document is available here: https://sfbos.org/sites/default/files/FileCenter/Documents/52601-BLA.ShortTermRentals.051315.pdf
#
# I recommend reading the pages cited above to understand the full process of calculating the utilzation rate, but this section summarizes the model I will use:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Before I begin, I need to bring back in a handful of variables I previously dropped from my AirBnB dataset. I came to this model later in my analysis after I had dropped these variables thinking they were unnecessary. I will load my original, untransformed dataset now to calculate utilization rate, then merge the rate back to my cleaned dataframe.

# %%
#Read in AirBnB listing data, raw version before any transformations
path='../Capstone/Data/listings.csv'
abb_list = pd.read_csv(path)

# %%
#Set apparent review rate, the number of guests that actually leave a review. 
#Air BnB says this is 72%
app_review_rate = .72

#Days listing is active
#Calculated as Date of Last Review - Date Host Joined
abb_list['last_activity_date'] = np.where(abb_list['last_review'].isna(), 
                                                  abb_list['last_scraped'], 
                                                  abb_list['last_review'])

# %%
abb_list['Days_Active'] = pd.to_datetime(abb_list['last_activity_date']) - pd.to_datetime(abb_list['host_since'])

# %%
#Convert from delta to integer datatype, leaving NaNs as is
abb_list['Days_Active'] = abb_list['Days_Active'].astype(dt.timedelta).map(lambda x: np.nan if pd.isnull(x) else x.days)

# %%
#Calculate # reviews per average booked nights
# (# Reviews for a listing / Review Rate) * Average # nights for a listing
# Avg. # of nights for a listing is estimated as 5.1 by SF Travel per above citation, 
#... but I have decided to use the Minimum Nights value instead, unless it goes over 5.1. 
#This may underestimate utilization, but prevents having listings go over 100% utilization.
abb_list['Nights_Per_Booking'] = np.where(abb_list['minimum_nights'] > 5.1, 5.1, abb_list['minimum_nights'])
abb_list['number_of_reviews'] = np.where(abb_list['number_of_reviews'] == 0, 1, abb_list['number_of_reviews'])      
abb_list['Est_Nights_Booked'] = ((abb_list['number_of_reviews']+1) / app_review_rate) * abb_list['Nights_Per_Booking']

# %%
#Utilization rate over lifetime of listing
# Estimated # Nights Booked / # Days Listing Active
abb_list['Utilization_Rate'] = abb_list['Est_Nights_Booked'] / abb_list['Days_Active']

# %%
#Trim rates above 1 down to 1. 
abb_list['Utilization_Rate'] = np.where(abb_list['Utilization_Rate'] > 1, 1, abb_list['Utilization_Rate'])

# %%
#This cell not used because I decided to leave as a percentage. 
#But keeping in case I want to recreate this later.

#Utilization Rate, or the average number of days a listing is booked in a year
#Utilization rate over life of listing * 365 days
#abb_list['Utilization_Rate'] = abb_list['Lifetime_Utilization'] * 365

# %%
#Drop everything but ID and Utilization Rate, then merge with abb dataset
abb_util_rate = abb_list[['id', 'Utilization_Rate']]
#Check for null values
abb_util_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17542 entries, 0 to 17541
# Data columns (total 2 columns):
# id                  17542 non-null int64
# Utilization_Rate    17540 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 274.2 KB

# %%
abb_list[abb_list['Utilization_Rate'].isna()]
# Out:
#             id                            listing_url       scrape_id  \
# 2084   6104732   https://www.airbnb.com/rooms/6104732  20180808031137
# 8042  17417181  https://www.airbnb.com/rooms/17417181  20180808031137
#
#      last_scraped                                name  \
# 2084   2018-08-08  Distillery District Bachelor Condo
# 8042   2018-08-08                     Ivans Sweet Pad
#
#                                                 summary space  \
# 2084  Furnished and right beside the PanAm grounds. ...   NaN
# 8042  My place is close to Scarlett Woods Golf Cours...   NaN
#
#                                             description experiences_offered  \
# 2084  Furnished and right beside the PanAm grounds. ...                none
# 8042  My place is close to Scarlett Woods Golf Cours...                none
#
#      neighborhood_overview notes transit access interaction house_rules  \
# 2084                   NaN   NaN     NaN    NaN         NaN         NaN
# 8042                   NaN   NaN     NaN    NaN         NaN         NaN
#
#       thumbnail_url  medium_url  \
# 2084            NaN         NaN
# 8042            NaN         NaN
#
#                                             picture_url  xl_picture_url  \
# 2084  https://a0.muscache.com/im/pictures/76065060/2...             NaN
# 8042  https://a0.muscache.com/im/pictures/1f9ac231-f...             NaN
#
#        host_id                                    host_url host_name  \
# 2084  31675651  https://www.airbnb.com/users/show/31675651       NaN
# 8042  75779190  https://www.airbnb.com/users/show/75779190       NaN
#
#      host_since host_location host_about host_response_time  \
# 2084        NaN           NaN        NaN                NaN
# 8042        NaN           NaN        NaN                NaN
#
#      host_response_rate  host_acceptance_rate host_is_superhost  \
# 2084                NaN                   NaN               NaN
# 8042                NaN                   NaN               NaN
#
#      host_thumbnail_url host_picture_url host_neighbourhood  \
# 2084                NaN              NaN                NaN
# 8042                NaN              NaN                NaN
#
#       host_listings_count  host_total_listings_count host_verifications  \
# 2084                  NaN                        NaN               None
# 8042                  NaN                        NaN               None
#
#      host_has_profile_pic host_identity_verified               street  \
# 2084                  NaN                    NaN  Toronto, ON, Canada
# 8042                  NaN                    NaN  Toronto, ON, Canada
#
#          neighbourhood             neighbourhood_cleansed  \
# 2084  Downtown Toronto  Waterfront Communities-The Island
# 8042     Humber Valley           Edenbridge-Humber Valley
#
#       neighbourhood_group_cleansed     city state  zipcode   market  \
# 2084                           NaN  Toronto    ON  M5A 2Y1  Toronto
# 8042                           NaN  Toronto    ON  M9A 4W4  Toronto
#
#        smart_location country_code country   latitude  longitude  \
# 2084  Toronto, Canada           CA  Canada  43.650947 -79.356941
# 8042  Toronto, Canada           CA  Canada  43.681921 -79.513948
#
#      is_location_exact property_type        room_type  accommodates  \
# 2084                 t     Apartment  Entire home/apt             2
# 8042                 t     Apartment     Private room             2
#
#       bathrooms  bedrooms  beds  bed_type  \
# 2084        1.0       1.0   1.0  Real Bed
# 8042        2.0       1.0   2.0  Real Bed
#
#                                               amenities  square_feet    price  \
# 2084  {Internet,Wifi,"Air conditioning","Wheelchair ...          NaN  $301.00
# 8042  {TV,Wifi,"Air conditioning",Heating,Essentials...          NaN   $70.00
#
#      weekly_price monthly_price security_deposit cleaning_fee  \
# 2084          NaN           NaN              NaN          NaN
# 8042          NaN           NaN              NaN          NaN
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 2084                1        $0.00               1            1125
# 8042                1        $0.00               1            1125
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 2084    38 months ago                t                0                0
# 8042    11 months ago                t                0                0
#
#       availability_90  availability_365 calendar_last_scraped  \
# 2084                0                 0            2018-08-08
# 8042                0                 0            2018-08-08
#
#       number_of_reviews first_review last_review  review_scores_rating  \
# 2084                  1   2015-07-27  2015-07-27                 100.0
# 8042                  1          NaN         NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 2084                    10.0                       10.0
# 8042                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 2084                   10.0                         10.0
# 8042                    NaN                          NaN
#
#       review_scores_location  review_scores_value requires_license  license  \
# 2084                    10.0                 10.0                f      NaN
# 8042                     NaN                  NaN                f      NaN
#
#       jurisdiction_names instant_bookable is_business_travel_ready  \
# 2084                 NaN                f                        f
# 8042                 NaN                t                        f
#
#      cancellation_policy require_guest_profile_picture  \
# 2084            flexible                             f
# 8042            flexible                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 2084                                f                               1
# 8042                                f                               1
#
#       reviews_per_month last_activity_date  Days_Active  Nights_Per_Booking  \
# 2084               0.03         2015-07-27          NaN                 1.0
# 8042                NaN         2018-08-08          NaN                 1.0
#
#       Est_Nights_Booked  Utilization_Rate
# 2084           2.777778               NaN
# 8042           2.777778               NaN

# %%
abb_util_rate.describe()
# Out:
#                  id  Utilization_Rate
# count  1.754200e+04      17540.000000
# mean   1.683533e+07          0.093602
# std    7.578725e+06          0.142759
# min    1.419000e+03          0.000837
# 25%    1.125480e+07          0.011253
# 50%    1.847656e+07          0.036914
# 75%    2.302324e+07          0.115741
# max    2.758201e+07          1.000000

# %% [markdown]
# There are 2 missing values for Utilization Rate. This is because they have no "host_since" date. I will drop these records.

# %%
#Remove missing values from abb_util_rate
abb_util_rate = abb_util_rate.drop(2084)
abb_util_rate = abb_util_rate.drop(8042)

# %%
#Remove missing values from abb
abb = abb.drop(2084)
abb = abb.drop(8042)

# %%
#Merge Utilization Rate back into abb dataset
abb = pd.merge(abb, abb_util_rate, on='id')

# %%
abb.head()
# Out:
#       id host_response_time  host_response_rate host_is_superhost  \
# 0   1419     within an hour                 0.0                 f
# 1  10314     within an hour                 0.0                 f
# 2  12604     within an hour                 0.0                 f
# 3  17936     within an hour               100.0                 t
# 4  23691     within an hour               100.0                 t
#
#         neighborhood property_type        room_type  accommodates  bathrooms  \
# 0    Little Portugal         House  Entire home/apt           6.0        2.0
# 1          Riverdale         House     Private room           2.0        1.0
# 2          The Annex         House     Private room           1.0        1.5
# 3  Kensington Market     Apartment     Private room           4.0        1.0
# 4           Wychwood         House     Private room           2.0        1.0
#
#    bedrooms  beds       bed_type  price  security_deposit  cleaning_fee  \
# 0       3.0   4.0       Real Bed  470.0            1000.0         150.0
# 1       1.0   1.0       Real Bed   69.0               0.0           0.0
# 2       1.0   1.0  Pull-out Sofa   65.0             130.0          26.0
# 3       1.0   2.0       Real Bed   99.0             300.0          80.0
# 4       1.0   1.0       Real Bed   70.0               0.0           0.0
#
#    guests_included  extra_people  minimum_nights instant_bookable  \
# 0              1.0           0.0             4.0                f
# 1              2.0          20.0             1.0                f
# 2              1.0          20.0             1.0                f
# 3              1.0          20.0             2.0                f
# 4              2.0          25.0             1.0                t
#
#            cancellation_policy  square_feet_notNA  monthly_price_notNA  \
# 0  strict_14_with_grace_period               True                False
# 1                     moderate              False                 True
# 2                     moderate               True                 True
# 3  strict_14_with_grace_period              False                 True
# 4  strict_14_with_grace_period              False                 True
#
#    weekly_price_notNA  bathrooms_notNA  beds_notNA  bedrooms_notNA  \
# 0                True             True        True            True
# 1                True             True        True            True
# 2                True             True        True            True
# 3                True             True        True            True
# 4                True             True        True            True
#
#    security_deposit_notNA  cleaning_fee_notNA  host_response_rate_notNA  \
# 0                    True                True                     False
# 1                   False               False                     False
# 2                    True                True                     False
# 3                    True                True                      True
# 4                    True                True                      True
#
#    reviews_per_month_notNA  neighbourhood_notNA  host_neighbourhood_notNA  \
# 0                     True                 True                      True
# 1                     True                 True                      True
# 2                    False                 True                      True
# 3                     True                 True                      True
# 4                     True                 True                      True
#
#    neighbourhood_cleansed_notNA  host_response_time_notNA  \
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                      True
# 4                          True                      True
#
#    host_is_superhost_notNA  has_Wifi  has_Heating  has_Essentials  \
# 0                     True      True        False           False
# 1                     True      True        False           False
# 2                     True      True        False           False
# 3                     True      True        False           False
# 4                     True      True        False           False
#
#    has_Kitchen  has_Smoke_detector  has_Air_conditioning  has_Hangers  \
# 0         True               False                  True        False
# 1         True               False                  True        False
# 2        False               False                 False        False
# 3         True               False                  True        False
# 4         True               False                  True        False
#
#    has_Washer  has_Dryer  has_Shampoo  has_Carbon_monoxide_detector  \
# 0       False      False        False                         False
# 1       False      False        False                         False
# 2       False      False        False                         False
# 3       False      False        False                         False
# 4       False      False        False                         False
#
#    has_Laptop_friendly_workspace  has_TV  has_Hair_dryer  has_Iron  \
# 0                          False    True           False     False
# 1                          False   False           False     False
# 2                          False   False           False     False
# 3                          False    True           False     False
# 4                          False   False           False     False
#
#    has_Hot_water  has_Fire_extinguisher  has_Familykid_friendly  has_Elevator  \
# 0          False                  False                   False         False
# 1          False                  False                   False         False
# 2          False                  False                   False         False
# 3          False                  False                   False         False
# 4          False                  False                   False         False
#
#    has_Free_parking_on_premises  has_First_aid_kit  has_Refrigerator  \
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
#
#    has_Internet  has_Dishes_and_silverware  has_Gym  has_Microwave  has_Stove  \
# 0          True                      False    False          False      False
# 1         False                      False    False          False      False
# 2          True                      False    False          False      False
# 3          True                      False    False          False      False
# 4          True                      False    False          False      False
#
#    has_Self_check-in  has_Oven  has_Bed_linens  has_Cooking_basics  \
# 0              False     False           False               False
# 1              False     False           False               False
# 2              False     False           False               False
# 3              False     False           False               False
# 4              False     False           False               False
#
#    has_Lock_on_bedroom_door  has_Long_term_stays_allowed  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    has_Private_entrance  has_Coffee_maker  has_Cable_TV  has_Step-free_access  \
# 0                 False             False         False                 False
# 1                 False             False         False                 False
# 2                 False             False         False                 False
# 3                 False             False         False                 False
# 4                 False             False         False                 False
#
#    has_Extra_pillows_and_blankets  has_Dishwasher  \
# 0                           False           False
# 1                           False           False
# 2                           False           False
# 3                           False           False
# 4                           False           False
#
#    has_translation_missing:_en.hosting_amenity_50  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    has_Paid_parking_off_premises  has_Pool  has_Luggage_dropoff_allowed  \
# 0                          False     False                        False
# 1                          False     False                        False
# 2                          False     False                        False
# 3                          False     False                        False
# 4                          False     False                        False
#
#    has_Patio_or_balcony  has_Safety_card  \
# 0                 False            False
# 1                 False            False
# 2                 False            False
# 3                 False            False
# 4                 False            False
#
#    has_translation_missing:_en.hosting_amenity_49  has_Hot_tub  \
# 0                                           False        False
# 1                                           False        False
# 2                                           False        False
# 3                                           False        False
# 4                                           False        False
#
#    has_Host_greets_you  has_Lockbox  has_24-hour_check-in  has_Pets_allowed  \
# 0                False        False                 False             False
# 1                False        False                 False             False
# 2                False        False                 False             False
# 3                False        False                 False             False
# 4                False        False                 False             False
#
#    has_Private_living_room  has_Paid_parking_on_premises  has_Breakfast  \
# 0                    False                         False          False
# 1                    False                         False          False
# 2                    False                         False          False
# 3                    False                         False          False
# 4                    False                         False          False
#
#    has_Bathtub  has_Wide_doorway  has_Buzzerwireless_intercom  \
# 0        False             False                        False
# 1        False             False                        False
# 2        False             False                        False
# 3        False             False                        False
# 4        False             False                        False
#
#    has_Garden_or_backyard  has_Indoor_fireplace  has_Keypad  \
# 0                   False                 False       False
# 1                   False                 False       False
# 2                   False                 False       False
# 3                   False                 False       False
# 4                   False                 False       False
#
#    has_Free_street_parking  has_Other  has_Wheelchair_accessible  has_Doorman  \
# 0                    False      False                      False        False
# 1                    False      False                      False        False
# 2                    False      False                      False        False
# 3                    False      False                      False        False
# 4                    False      False                      False        False
#
#    has_Pets_live_on_this_property  has_Well-lit_path_to_entrance  \
# 0                           False                          False
# 1                           False                          False
# 2                            True                          False
# 3                           False                          False
# 4                           False                          False
#
#    has_BBQ_grill  has_Ethernet_connection  has_Single_level_home  \
# 0          False                    False                  False
# 1          False                    False                  False
# 2          False                    False                  False
# 3          False                    False                  False
# 4          False                    False                  False
#
#    has_Wide_hallway_clearance  has_Room-darkening_shades  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    has_Flat_path_to_front_door  has_Smoking_allowed  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    has_Children’s_books_and_toys  has_Wide_clearance_to_bed  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
#
#    has_Building_staff  has_Smart_lock  has_Wide_entryway  has_High_chair  \
# 0               False           False              False           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False           False              False           False
# 4               False           False              False           False
#
#    has_Cleaning_before_checkout  has_Pack_’n_Playtravel_crib  has_Dog(s)  \
# 0                         False                        False       False
# 1                         False                        False       False
# 2                         False                        False       False
# 3                         False                        False       False
# 4                         False                        False       False
#
#    has_Accessible-height_bed  has_Cat(s)  has_Suitable_for_events  \
# 0                      False       False                    False
# 1                      False       False                    False
# 2                      False       False                    False
# 3                      False       False                    False
# 4                      False       False                    False
#
#    has_Accessible-height_toilet  has_Lake_access  has_Waterfront  has_Crib  \
# 0                         False            False           False     False
# 1                         False            False           False     False
# 2                         False            False           False     False
# 3                         False            False           False     False
# 4                         False            False           False     False
#
#    has_Handheld_shower_head  has_Children’s_dinnerware  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    has_Disabled_parking_spot  has_Game_console  has__toilet  \
# 0                      False             False        False
# 1                      False             False        False
# 2                      False             False        False
# 3                      False             False        False
# 4                      False             False        False
#
#    has_Wide_clearance_to_shower  has_Pocket_wifi  \
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
#
#    has_Babysitter_recommendations  has_Full_kitchen  has_Outlet_covers  \
# 0                           False             False              False
# 1                           False             False              False
# 2                           False             False              False
# 3                           False             False              False
# 4                           False             False              False
#
#    has_Stair_gates  has_Baby_bath  has_Hot_water_kettle  has_Window_guards  \
# 0            False          False                 False              False
# 1            False          False                 False              False
# 2            False          False                 False              False
# 3            False          False                 False              False
# 4            False          False                 False              False
#
#    has_Bathroom_essentials  has_Bedroom_comforts  has_Changing_table  \
# 0                    False                 False               False
# 1                    False                 False               False
# 2                    False                 False               False
# 3                    False                 False               False
# 4                    False                 False               False
#
#    has_Toilet_paper  has_Bath_towel  has_Body_soap  has_EV_charger  \
# 0             False           False          False           False
# 1             False           False          False           False
# 2             False           False          False           False
# 3             False           False          False           False
# 4             False           False          False           False
#
#    has_Beachfront  has_Fireplace_guards  has_Netflix  has_Other_pet(s)  \
# 0           False                 False        False             False
# 1           False                 False        False             False
# 2           False                 False        False             False
# 3           False                 False        False             False
# 4           False                 False        False             False
#
#    has_Roll-in_shower  has_  has_Beach_essentials  has_Smart_TV  \
# 0               False  True                 False         False
# 1               False  True                 False         False
# 2               False  True                 False         False
# 3               False  True                 False         False
# 4               False  True                 False         False
#
#    has_Baby_monitor  has_Fixed_grab_bars_for_shower  has_Breakfast_table  \
# 0             False                           False                False
# 1             False                           False                False
# 2             False                           False                False
# 3             False                           False                False
# 4             False                           False                False
#
#    has_Walk-in_shower  has_Convection_oven  has_Outdoor_seating  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
#
#    has_Sound_system  has_Bathtub_with_bath_chair  has_Rain_shower  \
# 0             False                        False            False
# 1             False                        False            False
# 2             False                        False            False
# 3             False                        False            False
# 4             False                        False            False
#
#    has_Balcony  has_Pillow-top_mattress  has_Table_corner_guards  \
# 0        False                    False                    False
# 1        False                    False                    False
# 2        False                    False                    False
# 3        False                    False                    False
# 4        False                    False                    False
#
#    has_Soaking_tub  has_Formal_dining_area  has_En_suite_bathroom  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    has_Memory_foam_mattress  has_Terrace  has_Central_air_conditioning  \
# 0                     False        False                         False
# 1                     False        False                         False
# 2                     False        False                         False
# 3                     False        False                         False
# 4                     False        False                         False
#
#    has_Shower_chair  has_Espresso_machine  has_Firm_mattress  has_Gas_oven  \
# 0             False                 False              False         False
# 1             False                 False              False         False
# 2             False                 False              False         False
# 3             False                 False              False         False
# 4             False                 False              False         False
#
#    has_Ceiling_fan  has_Heated_floors  has_Fixed_grab_bars_for_toilet  \
# 0            False              False                           False
# 1            False              False                           False
# 2            False              False                           False
# 3            False              False                           False
# 4            False              False                           False
#
#    has_DVD_player  has_Exercise_equipment  has_Printer  has_Outdoor_parking  \
# 0           False                   False        False                False
# 1           False                   False        False                False
# 2           False                   False        False                False
# 3           False                   False        False                False
# 4           False                   False        False                False
#
#    has_Private_bathroom  has_Shared_gym  has_Day_bed  has_HBO_GO  \
# 0                 False           False        False       False
# 1                 False           False        False       False
# 2                 False           False        False       False
# 3                 False           False        False       False
# 4                 False           False        False       False
#
#    has_Kitchenette  has_Murphy_bed  has_Amazon_Echo  has_Shared_pool  \
# 0            False           False            False            False
# 1            False           False            False            False
# 2            False           False            False            False
# 3            False           False            False            False
# 4            False           False            False            False
#
#    has_Warming_drawer  has_Ski_inSki_out  has_Fire_pit  has_Mini_fridge  \
# 0               False              False         False            False
# 1               False              False         False            False
# 2               False              False         False            False
# 3               False              False         False            False
# 4               False              False         False            False
#
#    has_Pool_with_pool_hoist  has_Sauna  has_Heated_towel_rack  \
# 0                     False      False                  False
# 1                     False      False                  False
# 2                     False      False                  False
# 3                     False      False                  False
# 4                     False      False                  False
#
#    has_Electric_profiling_bed  has_High-resolution_computer_monitor  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    has_Wine_cooler  has_Air_purifier  has_Ground_floor_access  \
# 0            False             False                    False
# 1            False             False                    False
# 2            False             False                    False
# 3            False             False                    False
# 4            False             False                    False
#
#    has_Shared_hot_tub  has_Jetted_tub  has_Mudroom  has_Touchless_faucets  \
# 0               False           False        False                  False
# 1               False           False        False                  False
# 2               False           False        False                  False
# 3               False           False        False                  False
# 4               False           False        False                  False
#
#    has_Sun_loungers  has_Mountain_view  has_Standing_valet  has_Double_oven  \
# 0             False              False               False            False
# 1             False              False               False            False
# 2             False              False               False            False
# 3             False              False               False            False
# 4             False              False               False            False
#
#    has_Fax_machine  has_Bidet  has_Beach_view  has_Brick_oven  \
# 0            False      False           False           False
# 1            False      False           False           False
# 2            False      False           False           False
# 3            False      False           False           False
# 4            False      False           False           False
#
#    has_Private_hot_tub  has_Washer__Dryer  has_Hammock  \
# 0                False              False        False
# 1                False              False        False
# 2                False              False        False
# 3                False              False        False
# 4                False              False        False
#
#    has_Projector_and_screen  has_Alfresco_bathtub  has_Steam_oven  \
# 0                     False                 False           False
# 1                     False                 False           False
# 2                     False                 False           False
# 3                     False                 False           False
# 4                     False                 False           False
#
#    host_lives_near_listing  yelp_bus_count_1  yelp_bus_total_reviews_1  \
# 0                    False               1.0                      66.0
# 1                     True               NaN                       NaN
# 2                     True               NaN                       NaN
# 3                     True              20.0                    1440.0
# 4                     True               NaN                       NaN
#
#    yelp_bus_avg_rating_1  yelp_bus_count_5  yelp_bus_total_reviews_5  \
# 0                   3.50             116.0                    8634.0
# 1                    NaN               NaN                       NaN
# 2                    NaN              11.0                    1631.0
# 3                   3.65             160.0                   11434.0
# 4                    NaN              11.0                     147.0
#
#    yelp_bus_avg_rating_5  log_price  Utilization_Rate
# 0               3.758621   6.152733          0.013053
# 1                    NaN   4.234107          0.042601
# 2               3.045455   4.174387          0.000866
# 3               3.715625   4.595120          0.105691
# 4               3.363636   4.248495          0.092562

# %%
#Here is the distribution of Utilization Rate
fig=plt.figure(figsize=(10, 5), dpi=120)
plt.hist(abb['Utilization_Rate'], bins=50)
plt.xlabel('Utilization Rate')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Test 3 - How do Beds, Bedrooms, Bathrooms, Accommodates correlate with Price and Utilization?

# %%
#Calculate correlation for beds and price
beds_coef, beds_p_value = stats.pearsonr(abb.log_price, abb.beds)
print("Price/Beds Pearson Correlation Coefficient: ", beds_coef, "and a P-value of:", beds_p_value)

#Calculate correlation for bedrooms and price
brooms_coef, brooms_p_value = stats.pearsonr(abb.log_price, abb.bedrooms)
print("Price/Bedrooms Pearson Correlation Coefficient: ", brooms_coef, "and a P-value of:", brooms_p_value)

#Calculate correlation for bathrooms and price
bath_coef, bath_p_value = stats.pearsonr(abb.log_price, abb.bathrooms)
print("Price/Bathrooms Pearson Correlation Coefficient: ", bath_coef, "and a P-value of:", bath_p_value)


#Calculate correlation for accomodates and price
acc_coef, acc_p_value = stats.pearsonr(abb.log_price, abb.accommodates)
print("Price/Accommodates Pearson Correlation Coefficient: ", acc_coef, "and a P-value of:", acc_p_value)
# Out:
# Price/Beds Pearson Correlation Coefficient:  0.47499274195338764 and a P-value of: 0.0
# Price/Bedrooms Pearson Correlation Coefficient:  0.4348014588018532 and a P-value of: 0.0
# Price/Bathrooms Pearson Correlation Coefficient:  0.2993018172477555 and a P-value of: 0.0
# Price/Accommodates Pearson Correlation Coefficient:  0.5881518866503705 and a P-value of: 0.0

# %%
#Calculate correlation for beds and Utilization Rate
beds_coef2, beds_p_value2 = stats.pearsonr(abb.Utilization_Rate, abb.beds)
print("Utilization/Beds Pearson Correlation Coefficient: ", beds_coef2, "and a P-value of:", beds_p_value2)

#Calculate correlation for bedrooms and Utilization Rate
brooms_coef2, brooms_p_value2 = stats.pearsonr(abb.Utilization_Rate, abb.bedrooms)
print("Utilization/Bedrooms Pearson Correlation Coefficient: ", brooms_coef2, "and a P-value of:", brooms_p_value2)

#Calculate correlation for bathrooms and Utilization Rate
bath_coef2, bath_p_value2 = stats.pearsonr(abb.Utilization_Rate, abb.bathrooms)
print("Utilization/Bathrooms Pearson Correlation Coefficient: ", bath_coef2, "and a P-value of:", bath_p_value2)


#Calculate correlation for accomodates and Utilization Rate
acc_coef2, acc_p_value2 = stats.pearsonr(abb.Utilization_Rate, abb.accommodates)
print("Utilization/Accommodates Pearson Correlation Coefficient: ", acc_coef2, "and a P-value of:", acc_p_value2)
# Out:
# Utilization/Beds Pearson Correlation Coefficient:  0.05984430065696712 and a P-value of: 3.493715701668476e-14
# Utilization/Bedrooms Pearson Correlation Coefficient:  -0.0026300462566088358 and a P-value of: 0.7393106289640965
# Utilization/Bathrooms Pearson Correlation Coefficient:  -0.022449318979794044 and a P-value of: 0.0045007390375429585
# Utilization/Accommodates Pearson Correlation Coefficient:  0.07635386293933648 and a P-value of: 3.8594118982991233e-22

# %% [markdown]
# ### Test 4 - Are Price and Utilization correlated?

# %%
p_u_coef, p_u_value = stats.pearsonr(abb.price, abb.Utilization_Rate)
print("Price/Utilization Pearson Correlation Coefficient: ", p_u_coef, "and a P-value of:", p_u_value)
# Out:
# Price/Utilization Pearson Correlation Coefficient:  -0.023859717230602123 and a P-value of: 0.0025338178224514054

# %% [markdown]
# ### Test 5 - How do different response time groupings relate to price, for hosts that respond 100% of the time?

# %%
#create subset of AirBnB dataset with just hosts that respond 100% of the time
abb_100_response = abb[abb['host_response_rate'] == 100]
abb_100_response.host_response_time.value_counts()
# Out:
# within an hour        6996
# within a few hours    1711
# within a day           614
# Name: host_response_time, dtype: int64

# %%
hrt_1 = abb_100_response[abb_100_response['host_response_time']=='within an hour']['price']
hrt_2 = abb_100_response[abb_100_response['host_response_time']=='within a few hours']['price']
hrt_3 = abb_100_response[abb_100_response['host_response_time']=='within a day']['price']

# %%
print("Mean price for hosts responding within an hour: ", np.mean(hrt_1))
print("Mean price for hosts responding within a few hours: ", np.mean(hrt_2))
print("Mean price for hosts responding within a day: ", np.mean(hrt_3))
# Out:
# Mean price for hosts responding within an hour:  128.26643796455116
# Mean price for hosts responding within a few hours:  121.88194038573933
# Mean price for hosts responding within a day:  131.5114006514658

# %%
stats.f_oneway(hrt_1, hrt_2, hrt_3)
# Out:
# F_onewayResult(statistic=3.930655213433043, pvalue=0.019663364219449624)

# %% [markdown]
# ### Test 6 - Compare significance of each amenity type on price

# %%
#Drop the has_amenity columns that have fewer than 10 listings with that amenity
for col in abb.columns:
    if 'has_' in col:
        if abb[col].sum() < 10:
            abb = abb.drop([col], axis=1)

# %%
abb = abb.drop(['has_'], axis=1)

# %%
amenity_stats = pd.DataFrame()

for col in abb.columns:
    if 'has_' in col:
        statistic, pvalue = stats.ttest_ind(abb[abb[col] == True]['price'], 
                                            abb[abb[col] == False]['price'])
        pvalue = "{:.8f}".format(float(pvalue))
        mean_True = abb[abb[col] == True]['price'].mean()
        mean_False = abb[abb[col] == False]['price'].mean()
        count_has = abb[col].sum()
        
        data = pd.DataFrame({'amenity' : [col], 'stat' : [statistic], 'pvalue' : [pvalue],
                            'mean_True' : [mean_True], 'mean_False' : [mean_False],
                            'count_has' : [count_has], 'mean_diff' : [mean_True - mean_False]})
        
        amenity_stats = amenity_stats.append(data, ignore_index=True)

# %%
amenity_stats.sort_values(by=['mean_diff'], ascending=False)
# Out:
#                            amenity       stat      pvalue   mean_True  \
# 10                          has_TV  37.783322  0.00000000  145.082612
# 16                    has_Cable_TV  22.388415  0.00000000  156.316491
# 18                        has_Pool  17.473293  0.00000000  159.325764
# 15                         has_Gym   6.418468  0.00000000  146.875133
# 0                         has_Wifi   2.693960  0.00706822  127.968159
# 5             has_Air_conditioning   5.739538  0.00000001  130.349591
# 26                     has_Doorman   0.573756  0.56614121  135.320000
# 14                    has_Internet   4.338939  0.00001440  132.283953
# 23            has_Indoor_fireplace  -0.486156  0.62686298  120.108108
# 12                    has_Elevator  -4.079215  0.00004541  112.949924
# 3                      has_Kitchen -12.552449  0.00000000  121.776479
# 11          has_Familykid_friendly  -2.993379  0.00276328  104.735099
# 21                   has_Breakfast  -4.879602  0.00000107  102.299383
# 25       has_Wheelchair_accessible  -2.754234  0.00588961   96.600000
# 20                has_Pets_allowed  -5.318373  0.00000011   92.610837
# 13    has_Free_parking_on_premises  -7.853359  0.00000000   92.968468
# 19                     has_Hot_tub  -2.329777  0.01983029   88.129032
# 17   has_Paid_parking_off_premises  -7.467091  0.00000000   86.123675
# 1                      has_Heating -18.500379  0.00000000   88.499426
# 28             has_Smoking_allowed  -4.889659  0.00000102   81.122449
# 27  has_Pets_live_on_this_property  -3.364515  0.00076858   80.826087
# 4               has_Smoke_detector  -6.827333  0.00000000   78.470588
# 7                       has_Washer  -9.974242  0.00000000   78.931319
# 6                      has_Hangers  -1.761346  0.07819897   77.454545
# 2                   has_Essentials  -4.541421  0.00000563   76.830986
# 8                        has_Dryer  -9.276745  0.00000000   74.758364
# 22     has_Buzzerwireless_intercom  -2.687517  0.00720599   66.058824
# 24         has_Free_street_parking  -5.268196  0.00000014   65.063492
# 9                      has_Shampoo  -2.233518  0.02552858   64.000000
#
#     mean_False  count_has  mean_diff
# 10   85.635841      11318  59.446771
# 16  118.183911       3978  38.132580
# 18  122.372859       2290  36.952905
# 15  126.463580        937  20.411554
# 0   114.587601      15640  13.380557
# 5   120.834621      11482   9.514969
# 26  127.634108         50   7.685892
# 14  125.387187       5272   6.896766
# 23  127.675598         37  -7.567490
# 12  128.289474        659 -15.339550
# 3   142.477907      11462 -20.701428
# 11  127.876356        151 -23.141256
# 21  128.181870        324 -25.882488
# 25  127.794492         70 -31.194492
# 20  128.108173        203 -35.497336
# 13  128.647524        444 -35.679055
# 19  127.734793         31 -39.605761
# 17  128.405455        283 -42.281780
# 1   132.438713       1742 -43.939287
# 28  127.944699         98 -46.822250
# 27  127.793047         46 -46.966960
# 4   128.185973        170 -49.715385
# 7   128.791653        364 -49.860335
# 6   127.692625         11 -50.238080
# 2   127.884504         71 -51.053518
# 8   128.562063        269 -53.803699
# 22  127.723584         17 -61.664760
# 24  127.905380         63 -62.841888
# 9   127.701875         11 -63.701875

# %%
#Check relationship to Utilization_Rate
amenity_stats_Util = pd.DataFrame()

for col in abb.columns:
    if 'has_' in col:
        statistic, pvalue = stats.ttest_ind(abb[abb[col] == True]['Utilization_Rate'], 
                                            abb[abb[col] == False]['Utilization_Rate'])
        pvalue = "{:.8f}".format(float(pvalue))
        mean_True = abb[abb[col] == True]['Utilization_Rate'].mean()
        mean_False = abb[abb[col] == False]['Utilization_Rate'].mean()
        count_has = abb[col].sum()
        
        data = pd.DataFrame({'amenity' : [col], 'stat' : [statistic], 'pvalue' : [pvalue],
                            'mean_True' : [mean_True], 'mean_False' : [mean_False],
                            'count_has' : [count_has], 'mean_diff' : [mean_True - mean_False]})
        
        amenity_stats_Util = amenity_stats_Util.append(data, ignore_index=True)

# %%
amenity_stats_Util.sort_values(by=['mean_diff'], ascending=False)
# Out:
#                            amenity      stat      pvalue  mean_True  \
# 6                      has_Hangers  1.331626  0.18300202   0.151846
# 0                         has_Wifi  4.072595  0.00004672   0.095232
# 16                    has_Cable_TV  7.796053  0.00000000   0.109800
# 10                          has_TV  6.911666  0.00000000   0.099541
# 28             has_Smoking_allowed  0.621051  0.53457478   0.103457
# 14                    has_Internet  3.324073  0.00088912   0.099878
# 18                        has_Pool  2.267875  0.02335011   0.100790
# 19                     has_Hot_tub  0.205567  0.83713169   0.099793
# 5             has_Air_conditioning  1.416124  0.15675864   0.095529
# 12                    has_Elevator -0.737609  0.46076265   0.090506
# 15                         has_Gym -1.498704  0.13397007   0.087740
# 11          has_Familykid_friendly -0.699457  0.48427679   0.086433
# 13    has_Free_parking_on_premises -1.715788  0.08622024   0.083058
# 3                      has_Kitchen -5.018692  0.00000053   0.090959
# 1                      has_Heating -3.476655  0.00050906   0.083298
# 4               has_Smoke_detector -1.447301  0.14783231   0.078756
# 25       has_Wheelchair_accessible -1.005603  0.31462173   0.077396
# 20                has_Pets_allowed -1.778746  0.07530039   0.076809
# 23            has_Indoor_fireplace -0.777894  0.43664292   0.076281
# 17   has_Paid_parking_off_premises -2.387976  0.01695298   0.074434
# 21                   has_Breakfast -2.704398  0.00685005   0.073289
# 26                     has_Doorman -1.138439  0.25495440   0.071567
# 2                   has_Essentials -1.547795  0.12169148   0.068349
# 7                       has_Washer -4.462482  0.00000816   0.061520
# 8                        has_Dryer -4.345712  0.00001397   0.057023
# 24         has_Free_street_parking -2.403719  0.01624053   0.051364
# 27  has_Pets_live_on_this_property -2.557004  0.01056693   0.040766
# 9                      has_Shampoo -1.392989  0.16364256   0.034562
# 22     has_Buzzerwireless_intercom -1.909808  0.05617583   0.028411
#
#     mean_False  count_has  mean_diff
# 6     0.094485         11   0.057361
# 0     0.064693      15640   0.030539
# 16    0.089475       3978   0.020326
# 10    0.082427      11318   0.017114
# 28    0.094470         98   0.008988
# 14    0.091897       5272   0.007981
# 18    0.093479       2290   0.007311
# 19    0.094514         31   0.005278
# 5     0.091980      11482   0.003549
# 12    0.094697        659  -0.004191
# 15    0.094946        937  -0.007206
# 11    0.094602        151  -0.008168
# 13    0.094852        444  -0.011794
# 3     0.103510      11462  -0.012551
# 1     0.095895       1742  -0.012598
# 4     0.094694        170  -0.015938
# 25    0.094600         70  -0.017204
# 20    0.094752        203  -0.017943
# 23    0.094567         37  -0.018286
# 17    0.094886        283  -0.020452
# 21    0.094963        324  -0.021674
# 26    0.094597         50  -0.023030
# 2     0.094641         71  -0.026292
# 7     0.095292        364  -0.033772
# 8     0.095166        269  -0.038143
# 24    0.094695         63  -0.043331
# 27    0.094680         46  -0.053913
# 9     0.094566         11  -0.060004
# 22    0.094595         17  -0.066184

# %% [markdown]
# ### Test 7 - Compare Mean Price of Property Types
#
# Before I perform my test, I would like to lump all property types with fewer listings than "Other" into the "Other" category. Here is a look at the property types and their counts:

# %%
abb.property_type.value_counts()
# Out:
# Apartment                 5783
# House                     4117
# Condominium               3593
# Townhouse                  756
# Guest suite                473
# Loft                       389
# Bungalow                   364
# Serviced apartment         163
# Guesthouse                  95
# Bed and breakfast           86
# Other                       59
# Villa                       41
# Boutique hotel              29
# Hostel                      18
# Camper/RV                   10
# Boat                         7
# Cottage                      5
# Cabin                        4
# Cave                         3
# Tiny house                   3
# Aparthotel                   3
# In-law                       3
# Tent                         1
# Dorm                         1
# Earth house                  1
# Treehouse                    1
# Casa particular (Cuba)       1
# Hotel                        1
# Castle                       1
# Name: property_type, dtype: int64

# %%
#Convert property types smaller than Other, lumping them in with Other

#Calculate value counts for each type
prop_types = pd.value_counts(abb.property_type)
#Create a boolean mask, False if proportion less than .36 
#...(captures everything under "Other")
mask = (prop_types/prop_types.sum() * 100).lt(.36)

#Change the property types in abb dataframe
abb['property_type'] = np.where(abb['property_type'].isin(prop_types[mask].index),
                               'Other', abb['property_type'])

# %%
abb.property_type.value_counts()
# Out:
# Apartment             5783
# House                 4117
# Condominium           3593
# Townhouse              756
# Guest suite            473
# Loft                   389
# Bungalow               364
# Other                  192
# Serviced apartment     163
# Guesthouse              95
# Bed and breakfast       86
# Name: property_type, dtype: int64

# %%
property_stats = pd.DataFrame()
for index, value in abb.property_type.value_counts().iteritems():
    df = pd.DataFrame()
    statistic, pvalue = stats.ttest_ind(abb[abb['property_type'] == index]['price'], 
                                            abb[abb['property_type'] != index]['price'])
    pvalue = "{:.8f}".format(float(pvalue))
    mean_True = abb[abb['property_type'] == index]['price'].mean()
    mean_False = abb[abb['property_type'] != index]['price'].mean()
    count_has = abb[abb['property_type'] == index]['property_type'].count()

    data = pd.DataFrame({'prop_type' : [index], 'stat' : [statistic], 'pvalue' : [pvalue],
                        'mean_True' : [mean_True], 'mean_False' : [mean_False],
                        'count_has' : [count_has], 'mean_diff' : [mean_True - mean_False]})

    property_stats = property_stats.append(data, ignore_index=True)

# %%
property_stats.sort_values(by=['mean_diff'], ascending=False)
# Out:
#              prop_type       stat      pvalue   mean_True  mean_False  \
# 8   Serviced apartment   7.576832  0.00000000  183.398773  127.084806
# 2          Condominium  24.542851  0.00000000  161.136933  117.971412
# 5                 Loft   8.301040  0.00000000  166.892031  126.681155
# 10   Bed and breakfast   0.394885  0.69293321  131.674419  127.636421
# 3            Townhouse  -2.351048  0.01873267  119.765873  128.049230
# 0            Apartment  -7.830789  0.00000000  119.889158  132.050743
# 7                Other  -2.224645  0.02611898  112.567708  127.841267
# 1                House -10.816113  0.00000000  113.967209  132.397091
# 4          Guest suite  -8.200342  0.00000000   92.602537  128.725254
# 6             Bungalow  -8.029876  0.00000000   88.387363  128.571675
# 9           Guesthouse  -4.299796  0.00001720   86.084211  127.906258
#
#     count_has  mean_diff
# 8         163  56.313967
# 2        3593  43.165520
# 5         389  40.210876
# 10         86   4.037998
# 3         756  -8.283357
# 0        5783 -12.161585
# 7         192 -15.273558
# 1        4117 -18.429882
# 4         473 -36.122717
# 6         364 -40.184312
# 9          95 -41.822047

# %% [markdown]
# ### Test 8 - How are Number of Businesses, Number of Reviews, and Avg. Star Rating from Yelp data correlated with Price and Utilization?

# %% [markdown]
# #### Price Correlations where businesses w/in .1 mile

# %%
#Create DF of listings w/ a business in .1 mile
point_one_listings = abb[abb['yelp_bus_count_1'].notna()]
point_one_listings.shape
# Out:
# (6832, 73)

# %%
# Number of businesses in .1 mile against price
coef1, value1 = stats.pearsonr(point_one_listings.log_price, point_one_listings.yelp_bus_count_1)
print("Price/Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef1, "and a P-value of:", value1)

# Total reviews of businesses in .1 mile against price
coef2, value2 = stats.pearsonr(point_one_listings.log_price, point_one_listings.yelp_bus_total_reviews_1)
print("Price/Reviews of Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef2, "and a P-value of:", value2)

# Avg. rating of businesses in .1 mile against price
coef3, value3 = stats.pearsonr(point_one_listings.log_price, point_one_listings.yelp_bus_avg_rating_1)
print("Price/Avg. Rating of Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef3, "and a P-value of:", value3)
# Out:
# Price/Bus. w/in .1 mile Pearson Correlation Coefficient:  0.07220852453654084 and a P-value of: 2.2985014408755724e-09
# Price/Reviews of Bus. w/in .1 mile Pearson Correlation Coefficient:  0.08936923126882851 and a P-value of: 1.358209666032656e-13
# Price/Avg. Rating of Bus. w/in .1 mile Pearson Correlation Coefficient:  -0.08095696841895797 and a P-value of: 2.0650394937601973e-11

# %% [markdown]
# #### Utilization Correlations where businesses w/in .1 mile

# %%
# Number of businesses in .1 mile against utilization
coef4, value4 = stats.pearsonr(point_one_listings.Utilization_Rate, point_one_listings.yelp_bus_count_1)
print("Util./Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef4, "and a P-value of:", value4)

# Total reviews of businesses in .1 mile against utilization
coef5, value5 = stats.pearsonr(point_one_listings.Utilization_Rate, point_one_listings.yelp_bus_total_reviews_1)
print("Util./Reviews of Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef5, "and a P-value of:", value5)

# Avg. rating of businesses in .1 mile against utilization
coef6, value6 = stats.pearsonr(point_one_listings.Utilization_Rate, point_one_listings.yelp_bus_avg_rating_1)
print("Util./Avg. Rating of Bus. w/in .1 mile Pearson Correlation Coefficient: ", coef6, "and a P-value of:", value6)
# Out:
# Util./Bus. w/in .1 mile Pearson Correlation Coefficient:  0.03148682828271557 and a P-value of: 0.00924816195927074
# Util./Reviews of Bus. w/in .1 mile Pearson Correlation Coefficient:  0.040065002148488245 and a P-value of: 0.0009252125526479116
# Util./Avg. Rating of Bus. w/in .1 mile Pearson Correlation Coefficient:  -0.026051084348787133 and a P-value of: 0.03129922661011841

# %% [markdown]
# #### Price Correlations where businesses w/in .5 mile

# %%
#Create DF of listings w/ a business in .1 mile
point_five_listings = abb[abb['yelp_bus_count_5'].notna()]
point_five_listings.shape
# Out:
# (14217, 73)

# %%
# Number of businesses in .5 mile against price
coef7, value7 = stats.pearsonr(point_five_listings.log_price, point_five_listings.yelp_bus_count_5)
print("Price/Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef7, "and a P-value of:", value7)

# Total reviews of businesses in .5 mile against price
coef8, value8 = stats.pearsonr(point_five_listings.log_price, point_five_listings.yelp_bus_total_reviews_5)
print("Price/Reviews of Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef8, "and a P-value of:", value8)

# Avg. rating of businesses in .5 mile against price
coef9, value9 = stats.pearsonr(point_five_listings.log_price, point_five_listings.yelp_bus_avg_rating_5)
print("Price/Avg. Rating of Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef9, "and a P-value of:", value9)
# Out:
# Price/Bus. w/in .5 mile Pearson Correlation Coefficient:  0.23047291093296468 and a P-value of: 9.682790349265773e-171
# Price/Reviews of Bus. w/in .5 mile Pearson Correlation Coefficient:  0.23424038808388548 and a P-value of: 1.846117232208922e-176
# Price/Avg. Rating of Bus. w/in .5 mile Pearson Correlation Coefficient:  -0.06800961796858454 and a P-value of: 4.746414033771311e-16

# %% [markdown]
# #### Utilization Correlations where businesses w/in .5 mile

# %%
# Number of businesses in .5 mile against utilization
coef10, value10 = stats.pearsonr(point_five_listings.Utilization_Rate, point_five_listings.yelp_bus_count_5)
print("Util./Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef10, "and a P-value of:", value10)

# Total reviews of businesses in .5 mile against utilization
coef11, value11 = stats.pearsonr(point_five_listings.Utilization_Rate, point_five_listings.yelp_bus_total_reviews_5)
print("Util./Reviews of Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef11, "and a P-value of:", value11)

# Avg. rating of businesses in .5 mile against utilization
coef12, value12 = stats.pearsonr(point_five_listings.Utilization_Rate, point_five_listings.yelp_bus_avg_rating_5)
print("Util./Avg. Rating of Bus. w/in .5 mile Pearson Correlation Coefficient: ", coef12, "and a P-value of:", value12)
# Out:
# Util./Bus. w/in .5 mile Pearson Correlation Coefficient:  0.06497352900199646 and a P-value of: 8.859730723415319e-15
# Util./Reviews of Bus. w/in .5 mile Pearson Correlation Coefficient:  0.06691700562898488 and a P-value of: 1.381445887016668e-15
# Util./Avg. Rating of Bus. w/in .5 mile Pearson Correlation Coefficient:  -0.03261088909542575 and a P-value of: 0.00010063581269613242

# %% [markdown]
# ### Test 9 -  Is there a significant price difference in listings with no businesses in .1 and .5 miles and those that have them?

# %%
point_one_test = stats.ttest_ind(abb[abb['yelp_bus_count_1'].notna()]['price'],
                       abb[abb['yelp_bus_count_1'].isna()]['price'])

print("Listings with at least one business w/in .1 mile charge an average of $", abb[abb['yelp_bus_count_1'].notna()]['price'].mean())
print("Listings that do not have at least one business w/in .1 mile charge an average of $", abb[abb['yelp_bus_count_1'].isna()]['price'].mean())

print(point_one_test)
# Out:
# Listings with at least one business w/in .1 mile charge an average of $ 147.47614168618267
# Listings that do not have at least one business w/in .1 mile charge an average of $ 112.90739731996949
# Ttest_indResult(statistic=23.258669790000315, pvalue=1.0319679763764273e-117)

# %%
point_five_test = stats.ttest_ind(abb[abb['yelp_bus_count_5'].notna()]['price'],
                       abb[abb['yelp_bus_count_5'].isna()]['price'])

print("Listings with at least one business w/in .5 mile charge an average of $", abb[abb['yelp_bus_count_5'].notna()]['price'].mean())
print("Listings that do not have at least one business w/in .5 mile charge an average of $", abb[abb['yelp_bus_count_5'].isna()]['price'].mean())

print(point_five_test)
# Out:
# Listings with at least one business w/in .5 mile charge an average of $ 131.0193430400225
# Listings that do not have at least one business w/in .5 mile charge an average of $ 101.0211817168339
# Ttest_indResult(statistic=12.723537741251237, pvalue=6.603882616586518e-37)

# %% [markdown]
# ### Test 10 - Statistical Significance of \_notNA variables
# The \_notNA variables were created in the Data Wrangling script to records with a specific variable missing, under the assumption that some of the missing data might turn out to have predictive power. If the \_notNA variable is True that means it was not missing, False means it was missing.

# %%
notNA_stats_Price = pd.DataFrame()

for col in abb.columns:
    if '_notNA' in col:
        statistic, pvalue = stats.ttest_ind(abb[abb[col] == True]['price'], 
                                            abb[abb[col] == False]['price'])
        pvalue = "{:.8f}".format(float(pvalue))
        mean_True = abb[abb[col] == True]['price'].mean()
        mean_False = abb[abb[col] == False]['price'].mean()
        count_NA = len(abb.index) - abb[col].sum()
        
        data = pd.DataFrame({'variable' : [col], 'stat' : [statistic], 'pvalue' : [pvalue],
                            'mean_True' : [mean_True], 'mean_False' : [mean_False],
                            'count_NA' : [count_NA], 'mean_diff' : [mean_False - mean_True]})
        
        notNA_stats_Price = notNA_stats_Price.append(data, ignore_index=True)


notNA_stats_Price.sort_values(by=['mean_diff'], ascending=False)
# Out:
#                         variable       stat      pvalue   mean_True  \
# 9        reviews_per_month_notNA  -8.846299  0.00000000  124.584157
# 1            monthly_price_notNA  -1.340370  0.18014400  124.941023
# 2             weekly_price_notNA  -0.031444  0.97491545  127.599821
# 10           neighbourhood_notNA   0.609427  0.54225024  127.766297
# 8       host_response_rate_notNA   2.642208  0.00824474  128.707763
# 13      host_response_time_notNA   2.642208  0.00824474  128.707763
# 11      host_neighbourhood_notNA   2.147864  0.03173949  128.273190
# 0              square_feet_notNA   1.040260  0.29823465  135.208333
# 7             cleaning_fee_notNA  12.292426  0.00000000  132.049189
# 6         security_deposit_notNA  19.133387  0.00000000  136.215377
# 3                bathrooms_notNA        NaN         nan  127.658110
# 4                     beds_notNA        NaN         nan  127.658110
# 5                 bedrooms_notNA        NaN         nan  127.658110
# 12  neighbourhood_cleansed_notNA        NaN         nan  127.658110
# 14       host_is_superhost_notNA        NaN         nan  127.658110
#
#     mean_False  count_NA  mean_diff
# 9   141.810991      2857  17.226834
# 1   128.027457     14095   3.086434
# 2   127.667586     13772   0.067765
# 10  125.740351       855  -2.025946
# 8   123.944161      3528  -4.763602
# 13  123.944161      3528  -4.763602
# 11  123.469268      2050  -4.803921
# 0   127.578047     15843  -7.630286
# 7   108.614000      3000 -23.435189
# 6   104.293103      4292 -31.922273
# 3          NaN         0        NaN
# 4          NaN         0        NaN
# 5          NaN         0        NaN
# 12         NaN         0        NaN
# 14         NaN         0        NaN

# %%
notNA_stats_Util = pd.DataFrame()

for col in abb.columns:
    if '_notNA' in col:
        statistic, pvalue = stats.ttest_ind(abb[abb[col] == True]['Utilization_Rate'], 
                                            abb[abb[col] == False]['Utilization_Rate'])
        pvalue = "{:.8f}".format(float(pvalue))
        mean_True = abb[abb[col] == True]['Utilization_Rate'].mean()
        mean_False = abb[abb[col] == False]['Utilization_Rate'].mean()
        count_NA = len(abb.index) - abb[col].sum()
        
        data = pd.DataFrame({'variable' : [col], 'stat' : [statistic], 'pvalue' : [pvalue],
                            'mean_True' : [mean_True], 'mean_False' : [mean_False],
                            'count_NA' : [count_NA], 'mean_diff' : [mean_False - mean_True]})
        
        notNA_stats_Util = notNA_stats_Util.append(data, ignore_index=True)


notNA_stats_Util.sort_values(by=['mean_diff'], ascending=False)
# Out:
#                         variable       stat      pvalue  mean_True  \
# 0              square_feet_notNA  -1.634260  0.10222392   0.076613
# 2             weekly_price_notNA  -1.382155  0.16694342   0.090656
# 11      host_neighbourhood_notNA   0.923382  0.35582189   0.094924
# 1            monthly_price_notNA   0.944267  0.34504761   0.097415
# 7             cleaning_fee_notNA   5.342253  0.00000009   0.097418
# 6         security_deposit_notNA   8.071868  0.00000000   0.100027
# 8       host_response_rate_notNA  10.956418  0.00000000   0.101075
# 13      host_response_time_notNA  10.956418  0.00000000   0.101075
# 10           neighbourhood_notNA   6.967057  0.00000000   0.096390
# 9        reviews_per_month_notNA  22.457598  0.00000000   0.106157
# 3                bathrooms_notNA        NaN         nan   0.094525
# 4                     beds_notNA        NaN         nan   0.094525
# 5                 bedrooms_notNA        NaN         nan   0.094525
# 12  neighbourhood_cleansed_notNA        NaN         nan   0.094525
# 14       host_is_superhost_notNA        NaN         nan   0.094525
#
#     mean_False  count_NA  mean_diff
# 0     0.094715     15843   0.018102
# 2     0.095154     13772   0.004498
# 11    0.091805      2050  -0.003119
# 1     0.094132     14095  -0.003284
# 7     0.081978      3000  -0.015440
# 6     0.079500      4292  -0.020527
# 8     0.071349      3528  -0.029726
# 13    0.071349      3528  -0.029726
# 10    0.061465       855  -0.034925
# 9     0.040970      2857  -0.065187
# 3          NaN         0        NaN
# 4          NaN         0        NaN
# 5          NaN         0        NaN
# 12         NaN         0        NaN
# 14         NaN         0        NaN

# %% [markdown]
# ### Save Modified Data File

# %%
abb.shape
# Out:
# (16011, 73)

# %%
abb.to_csv('../Capstone/Data/abb_stat_inf_changes.csv', index=False)
