# %% [markdown]
# # Data Merge Project Script
#
# This script handles merging cleaned versions of the AirBnB Toronto and Yelp Business datasets. For details on how I created those datasets refer to this notebook: http://localhost:8888/notebooks/Springboard/Springboard_Projects/Capstone/Scripts/1%20-%20Capstone_DataWrangling_Script.ipynb

# %%
#import libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import preprocessing
#allow all columns to be viewed:
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
current_path = % pwd
#print(current_path)

# %%
#If current_path is in Scripts folder, 
#go up one level so we can open the data folder
if (current_path.rsplit('\\', 1)[1] == 'Scripts'):
    % cd ..
    #% pwd
# Out:
# D:\Coding Projects\Springboard\Springboard_Projects\Capstone

# %%
#Import data

#Read in AirBnB cleaned listing data for Toronto
path1='../Capstone/Data/listings_clean.csv'
abb = pd.read_csv(path1)

#Read in Yelp cleaned business data for Toronto
path2='../Capstone/Data/yelp_clean.csv'
yelp = pd.read_csv(path2)

print(abb.shape)
print(yelp.shape)
# Out:
# (16939, 232)
# (13175, 10)

# %% [markdown]
# ## Fix Missing Neighborhoods and Mismatches
#
# The ultimate goal is to use the keep the AirBnB listings dataset and merge in for each listing the total number of businesses, their average star rating, and the number of reviews, for all Yelp businesses within 0.1 miles of the AirBnB listing. Without any other filtering this would involve comparing the lat/long of every single AirBnB listing (16,947) against every Yelp business (14,023). This could be very time-consuming.
#
# To limit the number of comparisons and make the process more manageable I plan to only compare listings in the same neighborhood, which is a variable in both datasets. There were a significant number of missing neighborhood values in each dataset, so my next step will be to use K Nearest Neighbors to predict those missing values so those records can be used.

# %% [markdown]
# ### Rename Mismatched Neighborhoods
# First I will inspect the neighborhoods in each dataset and check how many match or do not match in each dataset.

# %%
abb_hoods = pd.DataFrame(abb['neighbourhood'].value_counts().reset_index())
yelp_hoods = pd.DataFrame(yelp['neighborhood'].value_counts().reset_index())
print(abb_hoods.shape)
print(yelp_hoods.shape)
print(abb_hoods.head())
print(yelp_hoods.head())
# Out:
# (140, 2)
# (113, 2)
#                     index  neighbourhood
# 0        Downtown Toronto           2081
# 1  Entertainment District           1571
# 2                 Unknown            855
# 3                 Niagara            696
# 4              Willowdale            504
#            index  neighborhood
# 0        Unknown          5320
# 1    Scarborough           846
# 2  Downtown Core           627
# 3      Etobicoke           585
# 4       Milliken           268

# %%
#Next check how many neighborhood matches there are between datasets:
match_hoods = pd.merge(abb_hoods, yelp_hoods, 
                       on=['index'], how='outer')

# %%
#Count records where there is no match on each side.
abb_nomatch = match_hoods.neighbourhood[match_hoods.neighborhood.isnull()]
print('There are ' + str(abb_nomatch.sum()) + ' AirBnB listings with no match in the Yelp data.')

yelp_nomatch = match_hoods.neighborhood[match_hoods.neighbourhood.isnull()]
print('There are ' + str(yelp_nomatch.sum()) + ' Yelp listings with no match in the AirBnB data.')
# Out:
# There are 9547.0 AirBnB listings with no match in the Yelp data.
# There are 5528.0 Yelp listings with no match in the AirBnB data.

# %% [markdown]
# It seems there are quite a few mismatches. 9,554 out of approx. 17K records in the AirBnB dataset do not have a neighborhood match in the Yelp dataset, which is approximately 56%. On the other side 7,077 Yelp listings out of approx. 14K do not have a neighborhood match on the AirBnB side, which is around 50%. Eventually I will drop the Yelp records that don't have a match, but first I will manually inspect the names to see if there are any neighborhoods that are simply named differently in each dataset.

# %%
#View matches and mismatches side by side. 
#neighbourhood column shows the count of records in the AirBnB dataset
#neighborhood (no "u") shows the count of records in the Yelp dataset. 
#NaN in neighbourhood column indicates a name that exists in Yelp but not AirBnB.
#NaN in neighborhood column indicates a name that exists in AirBnB but not Yelp. 
print(match_hoods.sort_values('index'))
# Out:
#                              index  neighbourhood  neighborhood
# 38                       Agincourt          102.0           NaN
# 95                       Alderwood           32.0           NaN
# 166                 Alexandra Park            NaN          50.0
# 107                       Amesbury           26.0           NaN
# 77                  Armour Heights           42.0           NaN
# 73                         Bayview           44.0           NaN
# 76                 Bayview Village           42.0          21.0
# 176           Beaconsfield Village            NaN          38.0
# 89                    Bedford Park           35.0           NaN
# 82                         Bendale           40.0           NaN
# 169                  Bickford Park            NaN          43.0
# 67                     Birch Cliff           49.0           NaN
# 215                      Birchwood            NaN           3.0
# 165             Bloor-West Village            NaN          50.0
# 175              Bloordale Village            NaN          38.0
# 196                      Box Grove            NaN          18.0
# 70                 Broadview North           46.0           NaN
# 171               Brockton Village            NaN          42.0
# 153                Brown's Corners            NaN          98.0
# 207                  Burnhamthorpe            NaN           6.0
# 200                    Buttonville            NaN          15.0
# 19                     Cabbagetown          217.0          41.0
# 105                      Casa Loma           26.0           6.0
# 213                   Cedar Valley            NaN           5.0
# 40              Cedarvale Humewood           93.0           NaN
# 149                      Chinatown            NaN         114.0
# 190                  Christie Pits            NaN          22.0
# 145       Church-Wellesley Village            NaN         142.0
# 187                     City Place            NaN          24.0
# 50                        Clairlea           66.0           NaN
# 68                    Clanton Park           49.0           NaN
# 203                       Clarkson            NaN          11.0
# 104                     Cliffcrest           27.0           NaN
# 92                       Cliffside           34.0           NaN
# 155                     Cooksville            NaN          95.0
# 93                        Corktown           34.0          94.0
# 222                        Cornell            NaN           2.0
# 194                   Corso Italia            NaN          20.0
# 88                   Crescent Town           36.0           NaN
# 36                Danforth Village          108.0           NaN
# 12                      Davisville          291.0           NaN
# 52                       Deer Park           63.0          14.0
# 189             Discovery District            NaN          24.0
# 186            Distillery District            NaN          25.0
# 168                          Dixie            NaN          47.0
# 62                       Don Mills           54.0           NaN
# 37              Don Valley Village          102.0           NaN
# 90                     Dorset Park           34.0           NaN
# 177                     Dovercourt            NaN          37.0
# 17                 Dovercourt Park          223.0           NaN
# 54                       Downsview           62.0          47.0
# 141                  Downtown Core            NaN         627.0
# 0                 Downtown Toronto         2081.0           NaN
# 26                  Dufferin Grove          166.0          55.0
# 146                    East Credit            NaN         140.0
# 159                      East York            NaN          74.0
# 195                        Edgeley            NaN          18.0
# 103                  Eglinton East           27.0           NaN
# 1           Entertainment District         1571.0         207.0
# 148                     Erin Mills            NaN         116.0
# 221                       Erindale            NaN           2.0
# 81                        Eringate           41.0           NaN
# 142                      Etobicoke            NaN         585.0
# 101            Etobicoke West Mall           29.0           NaN
# 23                        Fairbank          184.0           NaN
# 8                 Fashion District          367.0           NaN
# 44              Financial District           86.0         157.0
# 106                Flemingdon Park           26.0           NaN
# 55                     Forest Hill           61.0           NaN
# 9                  Garden District          339.0           NaN
# 39                       Glen Park           98.0           NaN
# 51                      Greek Town           64.0           NaN
# 156                      Greektown            NaN          93.0
# 193                  Greensborough            NaN          20.0
# 34               Greenwood-Coxwell          113.0           NaN
# 113                      Guildwood           20.0           NaN
# 183                         Hanlan            NaN          26.0
# 15                    Harbourfront          252.0          59.0
# 47                      Henry Farm           78.0           NaN
# 170                      High Park            NaN          42.0
# 27                 High Park North          159.0           NaN
# 98                  Highland Creek           30.0           NaN
# 61               Hillcrest Village           54.0           NaN
# 220                  Hogg's Hollow            NaN           2.0
# 125                  Humber Summit           10.0           NaN
# 115                  Humber Valley           17.0           NaN
# 127                      Humberlea           10.0           NaN
# 119                     Humbermede           15.0           NaN
# 80                         Ionview           41.0           NaN
# 30                       Islington          124.0           NaN
# 99                  Jane and Finch           29.0           NaN
# 94                      Keelesdale           33.0           NaN
# 28               Kensington Market          158.0         141.0
# 202                      Kleinburg            NaN          11.0
# 160                      Koreatown            NaN          71.0
# 29                      L'Amoreaux          140.0           NaN
# 208                       Lakeview            NaN           6.0
# 109             Lambton Baby Point           26.0           NaN
# 162                      Langstaff            NaN          57.0
# 114                  Lawrence Park           19.0           1.0
# 91                         Leaside           34.0           NaN
# 144                    Leslieville            NaN         153.0
# 163                Liberty Village            NaN          54.0
# 192                         Lisgar            NaN          21.0
# 154                   Little Italy            NaN          95.0
# 11                 Little Portugal          323.0          49.0
# 72                     Long Branch           44.0           NaN
# 212                     Lorne Park            NaN           5.0
# 86                     Lytton Park           36.0           NaN
# 210                         Malton            NaN           5.0
# 65                         Malvern           51.0           NaN
# 129                   Malvern West           10.0           NaN
# 126                   Manse Valley           10.0           NaN
# 197                          Maple            NaN          18.0
# 206                Markham Village            NaN          10.0
# 211                  Markland Wood            NaN           5.0
# 136                 Markland Woods            6.0           NaN
# 205             Meadowvale Village            NaN          10.0
# 56                        Milliken           60.0         268.0
# 21                          Mimico          202.0           NaN
# 218                        Mineola            NaN           2.0
# 181             Mississauga Valley            NaN          32.0
# 108                    Morningside           26.0           NaN
# 128            Morningside Heights           10.0           NaN
# 78                    Mount Dennis           41.0           NaN
# 131                    Mount Olive            9.0           NaN
# 150  Mount Pleasant and Davisville            NaN         110.0
# 64                     New Toronto           52.0          37.0
# 16                     Newtonbrook          243.0           NaN
# 3                          Niagara          696.0          82.0
# 120                     North Park           14.0           NaN
# 137                        Nortown            6.0           NaN
# 100                       Oakridge           29.0           NaN
# 22                         Oakwood          196.0           NaN
# 83                   Old East York           40.0           NaN
# 201             Old Malton Village            NaN          13.0
# 167                Ossington Strip            NaN          48.0
# 198                     Palmerston            NaN          17.0
# 10         Palmerston/Little Italy          336.0           NaN
# 5                         Parkdale          438.0          89.0
# 69                        Parkview           47.0           NaN
# 42                       Parkwoods           87.0           NaN
# 57                     Pellam Park           60.0           NaN
# 117                     Pelmo Park           17.0           NaN
# 152                     Pine Grove            NaN         105.0
# 58                   Pleasant View           60.0           NaN
# 161                    Port Credit            NaN          71.0
# 123                     Port Union           13.0           NaN
# 116                       Princess           17.0           NaN
# 158              Queen Street West            NaN          79.0
# 122                        Rexdale           13.0          11.0
# 87                        Richview           36.0           NaN
# 214                      Ridgewood            NaN           4.0
# 14                       Riverdale          284.0         105.0
# 66               Rockcliffe Smythe           50.0           NaN
# 199               Rockwood Village            NaN          15.0
# 13                    Roncesvalles          291.0          75.0
# 43                        Rosedale           86.0          14.0
# 139                          Rouge            4.0           NaN
# 79                       Runnymede           41.0           NaN
# 164                        Ryerson            NaN          53.0
# 96         Saint Andrew/Windfields           31.0           NaN
# 31                  Saint Lawrence          120.0           NaN
# 140                    Scarborough            NaN         846.0
# 110        Scarborough City Centre           25.0           NaN
# 84            Scarborough Junction           37.0           NaN
# 124            Scarborough Village           12.0           NaN
# 184                 Seaton Village            NaN          26.0
# 223                     South Hill            NaN           2.0
# 75            South Hill/Rathnelly           42.0           NaN
# 147                   St. Lawrence            NaN         131.0
# 63             Stonegate-Queensway           53.0           NaN
# 174                   Streetsville            NaN          38.0
# 35                 Studio District          108.0           NaN
# 185                    Summer Hill            NaN          25.0
# 216                    Summerville            NaN           3.0
# 133                     Sunnybrook            8.0           NaN
# 49                         Swansea           70.0          29.0
# 53                   Tam O'Shanter           62.0           NaN
# 7                        The Annex          395.0         111.0
# 157                      The Beach            NaN          93.0
# 25                     The Beaches          170.0           NaN
# 33                    The Danforth          116.0         149.0
# 134                       The Elms            7.0           NaN
# 46                    The Junction           82.0         114.0
# 135                   The Kingsway            7.0           NaN
# 60                      The Pocket           57.0           NaN
# 97                     The Westway           30.0           NaN
# 130                    Thistletown           10.0           NaN
# 118               Thorncliffe Park           17.0           NaN
# 204                      Thornhill            NaN          11.0
# 188                Thornhill Woods            NaN          24.0
# 138                Toronto Islands            5.0           NaN
# 179              Trinity Bellwoods            NaN          34.0
# 6                Trinity-Bellwoods          410.0           NaN
# 143                     Unionville            NaN         193.0
# 191          Unionville Mainstreet            NaN          22.0
# 180          University of Toronto            NaN          32.0
# 2                          Unknown          855.0        5320.0
# 172                    Upper Beach            NaN          41.0
# 111               Victoria Village           23.0           NaN
# 219                Victory Village            NaN           2.0
# 18                 Wallace Emerson          219.0          18.0
# 209                 West Don Lands            NaN           5.0
# 85                       West Hill           37.0           NaN
# 59                     West Humber           60.0           NaN
# 182                West Queen West            NaN          29.0
# 132                     West Rouge            9.0           NaN
# 48             Westminster/Branson           74.0           NaN
# 121                      Westmount           14.0           NaN
# 102                         Weston           28.0           NaN
# 74                Wexford/Maryvale           43.0           NaN
# 4                       Willowdale          504.0         226.0
# 112                         Woburn           21.0           NaN
# 32               Woodbine Corridor          118.0           NaN
# 71                Woodbine/Lumsden           44.0           NaN
# 217                     Woodbridge            NaN           3.0
# 178                       Wychwood            NaN          37.0
# 45                   Wychwood Park           82.0           NaN
# 41                  Yonge Eglinton           87.0           NaN
# 151             Yonge and Eglinton            NaN         109.0
# 173            Yonge and St. Clair            NaN          38.0
# 24         York University Heights          172.0           NaN
# 20                       Yorkville          212.0         107.0

# %%
#Checking neighbourhood against neighbourhood_cleansed in the AirBnB dataset might also provide context
print(abb[['neighbourhood_cleansed', 'neighbourhood']].drop_duplicates().sort_values(by=['neighbourhood_cleansed', 'neighbourhood']))
# Out:
#                     neighbourhood_cleansed            neighbourhood
# 881                        Agincourt North                Agincourt
# 13882                      Agincourt North                  Unknown
# 322           Agincourt South-Malvern West                Agincourt
# 2170          Agincourt South-Malvern West             Malvern West
# 1476                             Alderwood                Alderwood
# 10872                            Alderwood                  Unknown
# 12325                                Annex                Casa Loma
# 1070                                 Annex         Downtown Toronto
# 2707                                 Annex  Palmerston/Little Italy
# 3488                                 Annex                 Rosedale
# 2                                    Annex                The Annex
# 463                                  Annex                  Unknown
# 256                                  Annex                Yorkville
# 308                      Banbury-Don Mills                Don Mills
# 13201                       Bathurst Manor                  Unknown
# 1674                        Bathurst Manor      Westminster/Branson
# 116                    Bay Street Corridor         Downtown Toronto
# 888                    Bay Street Corridor   Entertainment District
# 726                    Bay Street Corridor       Financial District
# 4661                   Bay Street Corridor          Garden District
# 168                    Bay Street Corridor                  Unknown
# 696                        Bayview Village          Bayview Village
# 9884                       Bayview Village       Don Valley Village
# 214                        Bayview Village               Henry Farm
# 1269                       Bayview Village                  Unknown
# 121                  Bayview Woods-Steeles                  Bayview
# 9760                 Bayview Woods-Steeles              Newtonbrook
# 8732                 Bayview Woods-Steeles                  Unknown
# 1899                  Bedford Park-Nortown             Bedford Park
# 4399                  Bedford Park-Nortown                Glen Park
# 4859                  Bedford Park-Nortown              Lytton Park
# 4095                  Bedford Park-Nortown                  Nortown
# 6498                  Bedford Park-Nortown                  Unknown
# 2642               Beechborough-Greenbrook                 Amesbury
# 8092               Beechborough-Greenbrook             Mount Dennis
# 8414               Beechborough-Greenbrook                  Unknown
# 545                                Bendale                  Bendale
# 5125                               Bendale                  Ionview
# 1019                               Bendale  Scarborough City Centre
# 5966                               Bendale                  Unknown
# 246                  Birchcliffe-Cliffside              Birch Cliff
# 184                  Birchcliffe-Cliffside                Cliffside
# 16823                Birchcliffe-Cliffside              The Beaches
# 9487                 Birchcliffe-Cliffside             The Danforth
# 52                   Birchcliffe-Cliffside                  Unknown
# 2620                           Black Creek           Jane and Finch
# 1081                           Blake-Jones                Riverdale
# 91                             Blake-Jones               The Pocket
# 1198                           Blake-Jones                  Unknown
# 4                     Briar Hill-Belgravia                 Fairbank
# 613                   Briar Hill-Belgravia                  Oakwood
# 5318                  Briar Hill-Belgravia                  Unknown
# 1353     Bridle Path-Sunnybrook-York Mills               Davisville
# 5920     Bridle Path-Sunnybrook-York Mills            Lawrence Park
# 5753     Bridle Path-Sunnybrook-York Mills               Sunnybrook
# 10077    Bridle Path-Sunnybrook-York Mills                  Unknown
# 77                         Broadview North          Broadview North
# 16215                      Broadview North               Greek Town
# 9966                       Broadview North            Old East York
# 212                        Broadview North                  Unknown
# 128                    Brookhaven-Amesbury                 Amesbury
# 229        Cabbagetown-South St.James Town              Cabbagetown
# 869        Cabbagetown-South St.James Town         Downtown Toronto
# 956        Cabbagetown-South St.James Town                  Unknown
# 68                      Caledonia-Fairbank                 Fairbank
# 70                      Caledonia-Fairbank                  Unknown
# 289                              Casa Loma                Casa Loma
# 2468                             Casa Loma              Forest Hill
# 244                              Casa Loma     South Hill/Rathnelly
# 11826                            Casa Loma                The Annex
# 1680                             Casa Loma                  Unknown
# 2270                             Casa Loma            Wychwood Park
# 7780                Centennial Scarborough           Highland Creek
# 7802                Centennial Scarborough               Port Union
# 6626                Centennial Scarborough                  Unknown
# 2268                 Church-Yonge Corridor              Cabbagetown
# 16                   Church-Yonge Corridor         Downtown Toronto
# 16106                Church-Yonge Corridor       Financial District
# 13                   Church-Yonge Corridor          Garden District
# 26                   Church-Yonge Corridor                 Rosedale
# 1785                 Church-Yonge Corridor           Saint Lawrence
# 865                  Church-Yonge Corridor                  Unknown
# 2095                   Clairlea-Birchmount                 Clairlea
# 5851                   Clairlea-Birchmount     Scarborough Junction
# 6833                   Clairlea-Birchmount                  Unknown
# 697                           Clanton Park             Clanton Park
# 3388                          Clanton Park                  Unknown
# 11571                         Clanton Park      Westminster/Branson
# 761                             Cliffcrest               Cliffcrest
# 3066                            Cliffcrest                Cliffside
# 3244                            Cliffcrest                  Unknown
# 436                 Corso Italia-Davenport                 Fairbank
# 1101                Corso Italia-Davenport                  Oakwood
# 208                 Corso Italia-Davenport                  Unknown
# 106                               Danforth         Danforth Village
# 719                               Danforth        Greenwood-Coxwell
# 4980                              Danforth               The Pocket
# 750                               Danforth        Woodbine Corridor
# 34                      Danforth East York         Danforth Village
# 1987                    Danforth East York               Greek Town
# 2542                    Danforth East York                  Unknown
# 236                     Don Valley Village       Don Valley Village
# 3018                    Don Valley Village                  Unknown
# 8266                           Dorset Park                  Bendale
# 1556                           Dorset Park              Dorset Park
# 14008                          Dorset Park                  Unknown
# 11496                          Dorset Park         Wexford/Maryvale
# 65     Dovercourt-Wallace Emerson-Junction          Dovercourt Park
# 282    Dovercourt-Wallace Emerson-Junction                 Fairbank
# 325    Dovercourt-Wallace Emerson-Junction                  Unknown
# 137    Dovercourt-Wallace Emerson-Junction          Wallace Emerson
# 47                    Downsview-Roding-CFB                Downsview
# 11215                 Downsview-Roding-CFB                  Unknown
# 5485                        Dufferin Grove          Dovercourt Park
# 23                          Dufferin Grove           Dufferin Grove
# 658                         Dufferin Grove          Little Portugal
# 5019                        Dufferin Grove  Palmerston/Little Italy
# 569                         Dufferin Grove                  Unknown
# 470                         Dufferin Grove          Wallace Emerson
# 2043                     East End-Danforth              The Beaches
# 119                      East End-Danforth             The Danforth
# 777                      East End-Danforth                  Unknown
# 14928                    East End-Danforth        Woodbine Corridor
# 3117              Edenbridge-Humber Valley            Humber Valley
# 7189              Edenbridge-Humber Valley             The Kingsway
# 5700                         Eglinton East            Eglinton East
# 4903                         Eglinton East                  Ionview
# 8797                         Eglinton East     Scarborough Junction
# 4162                         Eglinton East                  Unknown
# 5468                      Elms-Old Rexdale                 The Elms
# 577                    Englemount-Lawrence                Glen Park
# 5160                   Englemount-Lawrence                  Unknown
# 913         Eringate-Centennial-West Deane                 Eringate
# 960                    Etobicoke West Mall      Etobicoke West Mall
# 12477                  Etobicoke West Mall                Islington
# 12791                  Etobicoke West Mall                  Unknown
# 115                        Flemingdon Park          Flemingdon Park
# 8103                       Flemingdon Park                 Parkview
# 9693                       Flemingdon Park                  Unknown
# 1011                     Forest Hill North              Forest Hill
# 6556                     Forest Hill North                  Oakwood
# 12768                    Forest Hill North                  Unknown
# 11147                    Forest Hill South       Cedarvale Humewood
# 922                      Forest Hill South              Forest Hill
# 7972                Glenfield-Jane Heights                Downsview
# 5153                Glenfield-Jane Heights           Jane and Finch
# 7361                Glenfield-Jane Heights                  Unknown
# 5                        Greenwood-Coxwell        Greenwood-Coxwell
# 2033                     Greenwood-Coxwell                Riverdale
# 1852                     Greenwood-Coxwell              The Beaches
# 1223                     Greenwood-Coxwell                  Unknown
# 1025                             Guildwood                Guildwood
# 13240                            Guildwood      Scarborough Village
# 12077                            Guildwood                  Unknown
# 12155                           Henry Farm       Don Valley Village
# 1507                            Henry Farm               Henry Farm
# 11837                           Henry Farm                  Unknown
# 31                         High Park North          High Park North
# 2546                       High Park North                Runnymede
# 100                        High Park North                  Unknown
# 11278                      High Park North          Wallace Emerson
# 2660                     High Park-Swansea          High Park North
# 53                       High Park-Swansea             Roncesvalles
# 42                       High Park-Swansea                  Swansea
# 1517                     High Park-Swansea                  Unknown
# 890                         Highland Creek           Highland Creek
# 6446                     Hillcrest Village                  Bayview
# 9958                     Hillcrest Village       Don Valley Village
# 1566                     Hillcrest Village        Hillcrest Village
# 3546                     Hillcrest Village                  Unknown
# 11279             Humber Heights-Westmount                  Unknown
# 1129              Humber Heights-Westmount                Westmount
# 7312                         Humber Summit            Humber Summit
# 206                             Humbermede               Humbermede
# 49                      Humewood-Cedarvale       Cedarvale Humewood
# 2833                    Humewood-Cedarvale                  Oakwood
# 5202                    Humewood-Cedarvale                  Unknown
# 1292                               Ionview                  Ionview
# 6851                               Ionview                  Unknown
# 546             Islington-City Centre West                Islington
# 7613            Islington-City Centre West      Stonegate-Queensway
# 3662            Islington-City Centre West                  Unknown
# 927                          Junction Area          High Park North
# 620                          Junction Area        Rockcliffe Smythe
# 11316                        Junction Area                Runnymede
# 54                           Junction Area             The Junction
# 10654                        Junction Area                  Unknown
# 1629              Keelesdale-Eglinton West               Keelesdale
# 6708              Keelesdale-Eglinton West                  Unknown
# 2114                          Kennedy Park                  Ionview
# 2431                          Kennedy Park     Scarborough Junction
# 9520                          Kennedy Park                  Unknown
# 83                    Kensington-Chinatown         Downtown Toronto
# 8403                  Kensington-Chinatown   Entertainment District
# 4034                  Kensington-Chinatown         Fashion District
# 3                     Kensington-Chinatown        Kensington Market
# 2510                  Kensington-Chinatown        Trinity-Bellwoods
# 24                    Kensington-Chinatown                  Unknown
# 86           Kingsview Village-The Westway              The Westway
# 1290                        Kingsway South            Humber Valley
# 1837                        Kingsway South             The Kingsway
# 12465                           L'Amoreaux                Agincourt
# 1014                            L'Amoreaux               L'Amoreaux
# 15229                           L'Amoreaux            Tam O'Shanter
# 5626                            L'Amoreaux                  Unknown
# 1072                    Lambton Baby Point       Lambton Baby Point
# 3645                    Lambton Baby Point        Rockcliffe Smythe
# 2168                    Lambton Baby Point                Runnymede
# 12863                   Lambton Baby Point                  Unknown
# 1962                      Lansing-Westgate           Armour Heights
# 2340                      Lansing-Westgate                  Unknown
# 1172                      Lansing-Westgate               Willowdale
# 531                    Lawrence Park North             Bedford Park
# 3403                   Lawrence Park South              Forest Hill
# 469                    Lawrence Park South            Lawrence Park
# 1367                   Lawrence Park South              Lytton Park
# 383                    Lawrence Park South                  Unknown
# 4143                   Lawrence Park South           Yonge Eglinton
# 223                     Leaside-Bennington                  Leaside
# 8852                    Leaside-Bennington                  Unknown
# 563                        Little Portugal           Dufferin Grove
# 0                          Little Portugal          Little Portugal
# 13134                      Little Portugal                  Niagara
# 98                         Little Portugal                 Parkdale
# 7672                       Little Portugal        Trinity-Bellwoods
# 493                        Little Portugal                  Unknown
# 166                            Long Branch              Long Branch
# 4775                           Long Branch                  Unknown
# 1073                               Malvern                  Malvern
# 14069                              Malvern                  Unknown
# 2966                            Maple Leaf               North Park
# 11345                           Maple Leaf                  Unknown
# 3585                         Markland Wood           Markland Woods
# 14634                             Milliken                Agincourt
# 3060                              Milliken                 Milliken
# 7714                              Milliken                  Unknown
# 156    Mimico (includes Humber Bay Shores)                   Mimico
# 245    Mimico (includes Humber Bay Shores)                  Unknown
# 194                            Morningside              Morningside
# 12191                          Morningside                  Unknown
# 705                            Morningside                   Woburn
# 12362                            Moss Park              Cabbagetown
# 363                              Moss Park                 Corktown
# 18                               Moss Park         Downtown Toronto
# 120                              Moss Park          Garden District
# 73                               Moss Park           Saint Lawrence
# 72                               Moss Park                  Unknown
# 600                           Mount Dennis             Mount Dennis
# 11130                         Mount Dennis                  Unknown
# 4670     Mount Olive-Silverstone-Jamestown              Mount Olive
# 13434    Mount Olive-Silverstone-Jamestown                  Unknown
# 15099    Mount Olive-Silverstone-Jamestown              West Humber
# 89                     Mount Pleasant East               Davisville
# 4763                   Mount Pleasant East              Lytton Park
# 4264                   Mount Pleasant East                  Unknown
# 6                      Mount Pleasant West               Davisville
# 3144                   Mount Pleasant West                  Unknown
# 7839                   Mount Pleasant West           Yonge Eglinton
# 2534                           New Toronto              Long Branch
# 800                            New Toronto              New Toronto
# 7172                           New Toronto                  Unknown
# 1083                      Newtonbrook East              Newtonbrook
# 4459                      Newtonbrook East                  Unknown
# 6651                      Newtonbrook East               Willowdale
# 527                       Newtonbrook West              Newtonbrook
# 2004                      Newtonbrook West                  Unknown
# 268                       Newtonbrook West      Westminster/Branson
# 7355                      Newtonbrook West               Willowdale
# 14926                              Niagara         Downtown Toronto
# 4601                               Niagara         Fashion District
# 17                                 Niagara                  Niagara
# 754                                Niagara                 Parkdale
# 768                                Niagara        Trinity-Bellwoods
# 19                                 Niagara                  Unknown
# 366                        North Riverdale               Greek Town
# 60                         North Riverdale                Riverdale
# 2633                       North Riverdale               The Pocket
# 892                        North Riverdale                  Unknown
# 2665                   North St.James Town              Cabbagetown
# 63                     North St.James Town         Downtown Toronto
# 12138                  North St.James Town                 Rosedale
# 2717                   North St.James Town                  Unknown
# 917                      O'Connor-Parkview                 Parkview
# 2309                     O'Connor-Parkview                  Unknown
# 4455                              Oakridge              Birch Cliff
# 494                               Oakridge                 Clairlea
# 9929                              Oakridge            Crescent Town
# 8                                 Oakridge                 Oakridge
# 4054                              Oakridge                  Unknown
# 8888                       Oakwood Village       Cedarvale Humewood
# 130                        Oakwood Village                  Oakwood
# 4207                       Oakwood Village                  Unknown
# 7921                         Old East York         Danforth Village
# 450                          Old East York            Old East York
# 4611                         Old East York                  Unknown
# 6094               Palmerston-Little Italy          Dovercourt Park
# 9180               Palmerston-Little Italy           Dufferin Grove
# 9257               Palmerston-Little Italy        Kensington Market
# 20                 Palmerston-Little Italy  Palmerston/Little Italy
# 815                Palmerston-Little Italy        Trinity-Bellwoods
# 1037               Palmerston-Little Italy                  Unknown
# 140                      Parkwoods-Donalda                Parkwoods
# 6662                     Parkwoods-Donalda                  Unknown
# 3783                  Pelmo Park-Humberlea                Humberlea
# 7174                  Pelmo Park-Humberlea               Pelmo Park
# 6350                  Pelmo Park-Humberlea                  Unknown
# 2622              Playter Estates-Danforth         Danforth Village
# 274               Playter Estates-Danforth               Greek Town
# 2893              Playter Estates-Danforth                  Unknown
# 14480                        Pleasant View               L'Amoreaux
# 263                          Pleasant View            Pleasant View
# 3613                         Pleasant View                  Unknown
# 2490                    Princess-Rosethorn                 Princess
# 8826                    Princess-Rosethorn                  Unknown
# 9371                           Regent Park              Cabbagetown
# 16828                          Regent Park                 Corktown
# 111                            Regent Park         Downtown Toronto
# 455                            Regent Park                  Unknown
# 3023                       Rexdale-Kipling                  Rexdale
# 1002                     Rockcliffe-Smythe             Mount Dennis
# 838                      Rockcliffe-Smythe        Rockcliffe Smythe
# 4413                     Rockcliffe-Smythe                  Unknown
# 4161                          Roncesvalles           Dufferin Grove
# 1555                          Roncesvalles          Little Portugal
# 8196                          Roncesvalles                 Parkdale
# 76                            Roncesvalles             Roncesvalles
# 187                           Roncesvalles                  Unknown
# 3844                   Rosedale-Moore Park               Davisville
# 1326                   Rosedale-Moore Park                Deer Park
# 11                     Rosedale-Moore Park                 Rosedale
# 3852                   Rosedale-Moore Park                  Unknown
# 1299                   Rosedale-Moore Park                Yorkville
# 2780                                 Rouge      Morningside Heights
# 7193                                 Rouge                    Rouge
# 7660                                 Rouge                  Unknown
# 2790                                 Rouge               West Rouge
# 1431          Runnymede-Bloor West Village       Lambton Baby Point
# 735           Runnymede-Bloor West Village                Runnymede
# 10113         Runnymede-Bloor West Village                  Swansea
# 10371         Runnymede-Bloor West Village                  Unknown
# 15543                               Rustic               North Park
# 3299                   Scarborough Village                Guildwood
# 460                    Scarborough Village      Scarborough Village
# 7                           South Parkdale                 Parkdale
# 1807                        South Parkdale             Roncesvalles
# 1422                        South Parkdale                  Swansea
# 104                         South Parkdale                  Unknown
# 15245                      South Riverdale        Greenwood-Coxwell
# 1                          South Riverdale                Riverdale
# 66                         South Riverdale          Studio District
# 13681                      South Riverdale              The Beaches
# 8054                       South Riverdale               The Pocket
# 215                        South Riverdale                  Unknown
# 485                   St.Andrew-Windfields  Saint Andrew/Windfields
# 10051                 St.Andrew-Windfields                  Unknown
# 935                                Steeles               L'Amoreaux
# 6425                               Steeles                  Unknown
# 5324                   Stonegate-Queensway                Islington
# 57                     Stonegate-Queensway      Stonegate-Queensway
# 3567                   Stonegate-Queensway                  Unknown
# 6596                Tam O'Shanter-Sullivan                Agincourt
# 1190                Tam O'Shanter-Sullivan            Tam O'Shanter
# 8149                Tam O'Shanter-Sullivan                  Unknown
# 421                          Taylor-Massey            Crescent Town
# 9658                         Taylor-Massey                  Unknown
# 14484                        Taylor-Massey         Woodbine/Lumsden
# 15225                          The Beaches              Birch Cliff
# 50                             The Beaches              The Beaches
# 1893                           The Beaches                  Unknown
# 4042          Thistletown-Beaumond Heights              Thistletown
# 4598                      Thorncliffe Park                  Leaside
# 3232                      Thorncliffe Park         Thorncliffe Park
# 10373                     Thorncliffe Park                  Unknown
# 3215                     Trinity-Bellwoods        Kensington Market
# 4178                     Trinity-Bellwoods          Little Portugal
# 5038                     Trinity-Bellwoods                  Niagara
# 744                      Trinity-Bellwoods  Palmerston/Little Italy
# 33                       Trinity-Bellwoods        Trinity-Bellwoods
# 467                      Trinity-Bellwoods                  Unknown
# 349                             University         Downtown Toronto
# 8098                            University        Kensington Market
# 7759                            University  Palmerston/Little Italy
# 13421                           University                The Annex
# 3479                            University                  Unknown
# 12485                     Victoria Village          Flemingdon Park
# 16388                     Victoria Village                Parkwoods
# 10784                     Victoria Village                  Unknown
# 3033                      Victoria Village         Victoria Village
# 224      Waterfront Communities-The Island         Downtown Toronto
# 9        Waterfront Communities-The Island   Entertainment District
# 129      Waterfront Communities-The Island         Fashion District
# 11505    Waterfront Communities-The Island       Financial District
# 79       Waterfront Communities-The Island             Harbourfront
# 10259    Waterfront Communities-The Island                  Niagara
# 41       Waterfront Communities-The Island           Saint Lawrence
# 753      Waterfront Communities-The Island          Toronto Islands
# 93       Waterfront Communities-The Island                  Unknown
# 1601                             West Hill             Manse Valley
# 6222                             West Hill                  Unknown
# 2350                             West Hill                West Hill
# 3194                West Humber-Clairville                  Unknown
# 1093                West Humber-Clairville              West Humber
# 1502                   Westminster-Branson      Westminster/Branson
# 12447                               Weston               Pelmo Park
# 1597                                Weston                  Unknown
# 4445                                Weston                Westmount
# 1966                                Weston                   Weston
# 784                     Weston-Pellam Park              Pellam Park
# 8169                    Weston-Pellam Park                  Unknown
# 13291                     Wexford/Maryvale                  Unknown
# 10                        Wexford/Maryvale         Wexford/Maryvale
# 3888                       Willowdale East           Armour Heights
# 3470                       Willowdale East          Bayview Village
# 4841                       Willowdale East              Newtonbrook
# 447                        Willowdale East                  Unknown
# 46                         Willowdale East               Willowdale
# 5346                       Willowdale West              Newtonbrook
# 2714                       Willowdale West                  Unknown
# 335                        Willowdale West               Willowdale
# 4509      Willowridge-Martingrove-Richview                 Eringate
# 3017      Willowridge-Martingrove-Richview                 Richview
# 11396     Willowridge-Martingrove-Richview              The Westway
# 2712      Willowridge-Martingrove-Richview                  Unknown
# 2284                                Woburn                  Bendale
# 1737                                Woburn            Eglinton East
# 6585                                Woburn              Morningside
# 48                                  Woburn  Scarborough City Centre
# 11776                               Woburn                  Unknown
# 4999                                Woburn                   Woburn
# 7470                     Woodbine Corridor        Greenwood-Coxwell
# 4672                     Woodbine Corridor             The Danforth
# 2300                     Woodbine Corridor                  Unknown
# 126                      Woodbine Corridor        Woodbine Corridor
# 2217                      Woodbine-Lumsden                  Unknown
# 62                        Woodbine-Lumsden         Woodbine/Lumsden
# 5699                              Wychwood                Casa Loma
# 2890                              Wychwood       Cedarvale Humewood
# 1225                              Wychwood                 Fairbank
# 11726                             Wychwood                  Oakwood
# 3869                              Wychwood                The Annex
# 273                               Wychwood                  Unknown
# 132                               Wychwood            Wychwood Park
# 2358                        Yonge-Eglinton               Davisville
# 3374                        Yonge-Eglinton              Forest Hill
# 4543                        Yonge-Eglinton                  Unknown
# 35                          Yonge-Eglinton           Yonge Eglinton
# 78                          Yonge-St.Clair                Deer Park
# 1527                        Yonge-St.Clair     South Hill/Rathnelly
# 11143                       Yonge-St.Clair                  Unknown
# 14112              York University Heights                  Unknown
# 374                York University Heights  York University Heights
# 856                     Yorkdale-Glen Park                Glen Park
# 7554                    Yorkdale-Glen Park                  Unknown

# %% [markdown]
# Inspecting the list shows a few obvious misnamings: The Beach in Yelp, The Beaches in AirBnB, for example. Where I see these I will correct the spelling in the Yelp dataset to match the AirBnB dataset.
#
# Others are not as obvious. The Yelp dataset has Scarborough neighborhood, while the AirBnB dataset has Scarborough City Centre, Scarborough Junction, and Scarborough Village. Consulting Wikipedia (https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto) it seems safe to group these together under Scarborough, along with other neighborhoods like Tam O'Shanter.
#
# Before renaming anything, I will create a derived feature that tells me if the host lives in the same neighborhood as their listing by comparing host_neighbourhood to neighbourhood. This will not work after renaming neighborhoods.

# %%
abb['host_lives_near_listing'] = abb['neighbourhood'] == abb['host_neighbourhood']

# %%
#Rename Scarborough Neighborhoods as Scarborough in AirBnB
abb.neighbourhood.replace(['Agincourt', 'Scarborough Village', 'Tam O\'Shanter', 
                          'Scarborough Junction', 'Scarborough City Centre', 'Bendale', 'Birch Cliff',
                          'Clairlea', 'Cliffcrest', 'Dover Park', 'Cliffside', 'Dorset Park', 'Eglinton East',
                          'Guildwood', 'Highland Creek', 'Ionview', 'L\'Amoreaux', 'Malvern', 'Malvern West',
                          'Morningside', 'Morningside Heights', 'Oakridge', 'Port Union', 'Rouge', 'West Hill',
                          'West Rouge', 'Wexford/Maryvale', 'Woburn', 'Manse Valley', 'Milliken'],
                        'Scarborough', inplace=True)

# %%
#Rename Etobicoke Neighborhoods as Etobicoke in AirBnB
abb.neighbourhood.replace(['Etobicoke West Mall', 'Alderwood', 'Eringate', 'Humber Valley', 'Islington', 'Long Branch',
                          'Mimico', 'Princess', 'Richview', 'Stonegate-Queensway', 'The Elms', 'The Kingsway', 
                           'The Westway', 'Thistletown', 'West Humber', 'Westmount'],
                        'Etobicoke', inplace=True)

# %%
#Rename Downtown Core Neighborhoods as Downtown Core in AirBnB
abb.neighbourhood.replace(['Downtown Toronto', 'Fashion District', 'Garden District', 'Saint Andrew/Windfields',
                          'Toronto Islands', 'Studio District'],
                        'Downtown Core', inplace=True)

# %%
#Rename East York neighborhoods as East York in AirBnB
abb.neighbourhood.replace(['Broadview North', 'Crescent Town', 'Old East York', 'Parkview', 'Thorncliffe Park',
                          'Flemingdon Park'],
                        'East York', inplace=True)

# %%
#Miscellaneous AirBnB Renamings
abb.neighbourhood.replace(['Bedford Park'],
                        'Lawrence Park', inplace=True)
abb.neighbourhood.replace(['Lawrence Park'],
                        'Yonge Eglinton', inplace=True)
abb.neighbourhood.replace(['Greek Town', 'The Pocket'],
                        'Greektown', inplace=True)
abb.neighbourhood.replace(['Humberlea'],
                        'Pelmo Park', inplace=True)
abb.neighbourhood.replace(['Markland Woods'],
                        'Markland Wood', inplace=True)
abb.neighbourhood.replace(['South Hill/Rathnelly'],
                        'South Hill', inplace=True)
abb.neighbourhood.replace(['Danforth Village', 'Woodbine/Lumsden'],
                        'The Danforth', inplace=True)
abb.neighbourhood.replace(['Bayview', 'Henry Farm', 'Don Valley Village', 'Hillcrest Village'],
                        'Bayview Village', inplace=True)
abb.neighbourhood.replace(['Cedarvale Humewood'],
                        'Wychwood', inplace=True)
abb.neighbourhood.replace(['Financial District', 'Harbourfront'],
                        'Entertainment District', inplace=True)
abb.neighbourhood.replace(['Forest Hill', 'Lytton Park'],
                        'Yonge Eglinton', inplace=True)
abb.neighbourhood.replace(['Greenwood-Coxwell'],
                        'Greektown', inplace=True)
abb.neighbourhood.replace(['Runnymede', 'Lambton Baby Point'],
                        'High Park North', inplace=True)
abb.neighbourhood.replace(['Leaside', 'Sunnybrook'],
                        'Davisville', inplace=True)
abb.neighbourhood.replace(['Markland Wood'],
                        'Etobicoke', inplace=True)
abb.neighbourhood.replace(['Newtonbrook'],
                        'Willowdale', inplace=True)
abb.neighbourhood.replace(['Woodbine Corridor'],
                        'The Beaches', inplace=True)
abb.neighbourhood.replace(['Wychwood Park', 'Fairbank', 'Oakwood'],
                        'Wychwood', inplace=True)
abb.neighbourhood.replace(['Armour Heights', ],
                        'Hogg\'s Hollow', inplace=True)

# %%
#Rename Downtown Core Neighborhoods as Downtown Core in Yelp
yelp.neighborhood.replace(['Alexandra Park', 'Chinatown', 'Christie Pits', 'Church-Wellesley Village', 'City Place',
                          'Discovery District', 'Distillery District', 'Financial District', 'Queen Street West', 'Hanlan',
                          'Koreatown', 'Leslieville', 'Ryerson', 'University of Toronto'],
                        'Downtown Core', inplace=True)

# %%
#Rename Scarborough Neighborhoods as Scarborough in Yelp
yelp.neighborhood.replace(['Milliken', 'Cedar Valley'],
                         'Scarborough', inplace=True)

# %%
#Rename Palmerston/Little Italy neighborhoods as Palmerston/Little Italy in Yelp
yelp.neighborhood.replace(['Palmerston', 'Little Italy', 'Seaton Village'],
                        'Palmerston/Little Italy', inplace=True)

# %%
#Miscellaneous Yelp Renamings
yelp.neighborhood.replace(['Dovercourt'],
                        'Dovercourt Park', inplace=True)
yelp.neighborhood.replace(['High Park'],
                        'High Park North', inplace=True)
yelp.neighborhood.replace(['Mount Pleasant and Davisville'],
                        'Davisville', inplace=True)
yelp.neighborhood.replace(['St. Lawrence'],
                        'Saint Lawrence', inplace=True)
yelp.neighborhood.replace(['The Beach'],
                        'The Beaches', inplace=True)
yelp.neighborhood.replace(['Trinity Bellwoods'],
                        'Trinity-Bellwoods', inplace=True)
yelp.neighborhood.replace(['Yonge and St. Clair', 'Moore Park'],
                        'Deer Park', inplace=True)
yelp.neighborhood.replace(['Yonge and Eglinton'],
                        'Yonge Eglinton', inplace=True)
yelp.neighborhood.replace(['Beaconsfield Village', 'Ossington Strip', 'Lisgar'],
                        'Little Portugal', inplace=True)
yelp.neighborhood.replace(['Bloor-West Village'],
                        'Swansea', inplace=True)
yelp.neighborhood.replace(['Corso Italia'],
                        'Wychwood', inplace=True)
yelp.neighborhood.replace(['Bloordale Village'],
                        'Dovercourt Park', inplace=True)
yelp.neighborhood.replace(['Brockton Village', 'Lakeview', 'Bickford Park'],
                        'Palmerston/Little Italy', inplace=True)
yelp.neighborhood.replace(['Harbourfront'],
                        'Entertainment District', inplace=True)
yelp.neighborhood.replace(['Liberty Village', 'West Queen West'],
                        'Niagara', inplace=True)
yelp.neighborhood.replace(['Markland Wood', 'Burnhamthorpe'],
                        'Etobicoke', inplace=True)
yelp.neighborhood.replace(['Summer Hill'],
                        'Yorkville', inplace=True)
yelp.neighborhood.replace(['Upper Beach'],
                        'The Beaches', inplace=True)
yelp.neighborhood.replace(['West Don Lands'],
                        'Corktown', inplace=True)
yelp.neighborhood.replace(['Birchwood'],
                        'Hogg\'s Hollow', inplace=True)
yelp.neighborhood.replace(['Box Grove', 'Brown\'s Corners', 'Buttonville'],
                        'Markham Village', inplace=True)
yelp.neighborhood.replace(['Cooksville', 'East Credit', 'Erin Mills', 'Erindale',
                          'Lorne Park'],
                        'Mississauga', inplace=True)
yelp.neighborhood.replace(['Cornell'],
                        'Mount Dennis', inplace=True)
yelp.neighborhood.replace(['Lawrence Park'],
                        'Yonge Eglinton', inplace=True)

# %%
#Check matches again
abb_hoods = pd.DataFrame(abb['neighbourhood'].value_counts().reset_index())
yelp_hoods = pd.DataFrame(yelp['neighborhood'].value_counts().reset_index())
match_hoods = pd.merge(abb_hoods, yelp_hoods, 
                       on=['index'], how='outer')
#Count records where there is no match on each side.
abb_nomatch = match_hoods.neighbourhood[match_hoods.neighborhood.isnull()]
print('There are ' + str(abb_nomatch.sum()) + ' AirBnB listings with no match in the Yelp data.')

yelp_nomatch = match_hoods.neighborhood[match_hoods.neighbourhood.isnull()]
print('There are ' + str(yelp_nomatch.sum()) + ' Yelp listings with no match in the AirBnB data.')

print(match_hoods.sort_values('index'))
# Out:
# There are 0 AirBnB listings with no match in the Yelp data.
# There are 0 Yelp listings with no match in the AirBnB data.
#                       index  neighbourhood  neighborhood
# 14          Bayview Village            320            21
# 24              Cabbagetown            217            41
# 40                Casa Loma             26             6
# 39                 Corktown             34            99
# 12               Davisville            333           110
# 33                Deer Park             63            52
# 22          Dovercourt Park            223            75
# 34                Downsview             62            47
# 0             Downtown Core           2931          1599
# 27           Dufferin Grove            166            55
# 26                East York            212            74
# 1    Entertainment District           1909           266
# 5                 Etobicoke            729           596
# 20                Greektown            234            93
# 21          High Park North            226            42
# 36            Hogg's Hollow             42             5
# 28        Kensington Market            158           141
# 13          Little Portugal            323           156
# 38             Mount Dennis             41             2
# 35              New Toronto             52            37
# 6                   Niagara            696           165
# 11  Palmerston/Little Italy            336           229
# 8                  Parkdale            438            89
# 41                  Rexdale             13            11
# 17                Riverdale            284           105
# 15             Roncesvalles            291            75
# 30                 Rosedale             86            14
# 29           Saint Lawrence            120           131
# 2               Scarborough           1069          1119
# 37               South Hill             42             2
# 32                  Swansea             70            79
# 10                The Annex            395           111
# 16              The Beaches            288           134
# 18             The Danforth            268           149
# 31             The Junction             82           114
# 9         Trinity-Bellwoods            410            34
# 3                   Unknown            855          5320
# 23          Wallace Emerson            219            18
# 4                Willowdale            747           226
# 7                  Wychwood            555            57
# 19           Yonge Eglinton            238           110
# 25                Yorkville            212           132

# %%
#Drop records in each dataset where no neighborhood match exists
#This will drop 6% of AirBnB listings, approx 1000 out of 17000 records. I could impute the Yelp metrics for these
#... but I don't think it would be representative to impute records for the suburbs based on downtown.
#Only 7 Yelp records are ummatched which is a small number to drop.
abb_drop_hoods = ['Amesbury', 'Armour Heights', 'Clanton Park', 'Don Mills', 'Glen Park',
                  'Humber Summit', 'Humbermede', 'Jane and Finch', 'Keelesdale', 
                  'Mount Olive', 'North Park', 'Nortown', 'Oakwood', 'Parkwoods', 'Pellam Park', 'Pelmo Park',
                  'Pleasant View', 'Rockcliffe Smythe','Victoria Village', 'Westminster/Branson', 
                  'Weston', 'York University Heights']
                  
yelp_drop_hoods = ['Edgeley', 'Erin Mills', 'Langstaff', 'Meadowvale Village', 'Mississauga Valley',
                  'Thornhill', 'Thornhill Woods', 'Dixie', 'Greensborough', 'Kleinburg', 'Langstaff',
                  'Malton', 'Maple', 'Markham Village', 'Meadowvale Village', 'Mississauga',
                  'Mississauga Valley', 'Old Malton Village', 'Pine Grove', 'Port Credit',
                  'Rockwood Village', 'Streetsville', 'Summerville',
                  'Unionville', 'Unionville Mainstreet', 'Victory Village', 'Ridgewood',
                  'Woodbridge', 'Clarkson', 'Mineola']

abb = abb[~abb['neighbourhood'].isin(abb_drop_hoods)]
yelp = yelp[~yelp['neighborhood'].isin(yelp_drop_hoods)]

# %% [markdown]
# ### Imputing Missing Neighborhoods with KNN
# Previously in the Data Wrangling script I renamed missing Neighborhood values with "Unknown". I now plan to predict the value for those neighborhoods by using K Nearest Neighbors. First I will create a single data frame with the Neighborhoods and Lat/Longs from both the AirBnB and Yelp datasets. Then I will split the data frame into "train" and "test" datasets. The test dataset will include all neighborhoods with the value "Unknown". Next I will run K Nearest Neighbors on the train dataset and use the resulting model to predict the values in the test dataset.

# %%
#Create dfs with neighborhood, lat, long from each dataset
abb_hoods_df = abb[['id', 
                    'neighbourhood', 'latitude', 'longitude']]
abb_hoods_df = abb_hoods_df.rename(columns={'neighbourhood':'neighborhood'})
print(abb_hoods_df.head())
yelp_hoods_df = yelp[['business_id', 
                      'neighborhood', 'latitude', 'longitude']]
print(yelp_hoods_df.head())
# Out:
#       id       neighborhood   latitude  longitude
# 0   1419    Little Portugal  43.646168 -79.424510
# 1  10314          Riverdale  43.670186 -79.335848
# 2  12604          The Annex  43.667241 -79.415978
# 3  17936  Kensington Market  43.656400 -79.403295
# 4  23691           Wychwood  43.696017 -79.454683
#               business_id   neighborhood   latitude  longitude
# 1  5J3b7j3Fzo9ISjChmoUoUA       Wychwood  43.681328 -79.427884
# 2  Be7Mwq06nf1eNLblo1ekow      Downsview  43.731316 -79.465133
# 3  RJEtBRLJmmji_QoqS6ysjg  Downtown Core  43.667749 -79.396167
# 4  YIez_A3WOt9J2SXN7OMa2Q        Unknown  43.745928 -79.324623
# 5  j7yI3qYRsbGBUv9rShLCaQ        Unknown  43.776719 -79.603614

# %%
neighborhoods_df = pd.concat([abb_hoods_df, yelp_hoods_df], sort=True)
neighborhoods_df.shape
# Out:
# (27956, 5)

# %%
#Remove Unknown neighborhoods
neighborhoods_df = neighborhoods_df[neighborhoods_df['neighborhood'] != 'Unknown']
print(neighborhoods_df.head())
print(neighborhoods_df.shape)
# Out:
#   business_id       id   latitude  longitude       neighborhood
# 0         NaN   1419.0  43.646168 -79.424510    Little Portugal
# 1         NaN  10314.0  43.670186 -79.335848          Riverdale
# 2         NaN  12604.0  43.667241 -79.415978          The Annex
# 3         NaN  17936.0  43.656400 -79.403295  Kensington Market
# 4         NaN  23691.0  43.696017 -79.454683           Wychwood
# (21781, 5)

# %%
#Convert neighborhoods to numeric for prediction
le = preprocessing.LabelEncoder()
le.fit(neighborhoods_df['neighborhood'].astype(str)) #fit to list of all neighborhoods to ensure all possible values are encoded
# Out:
# LabelEncoder()

# %%
#Create train/test split from neighborhoods_df
x = neighborhoods_df[['latitude', 'longitude']]
y = neighborhoods_df[['neighborhood', 'business_id', 'id']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
y_train['neighborhood'] = le.transform(y_train['neighborhood'].astype(str))
y_test['neighborhood'] = le.transform(y_test['neighborhood'].astype(str))
#print(y_train)
#Code below converts back to original values
#print("")
#y_train['neighborhood'] = le.inverse_transform(y_train['neighborhood'])
#print(y_train)
# Out:
# C:\Users\jshka\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\jshka\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Scale lat/long before modeling
scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Run K Means on training set
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train.loc[:, 'neighborhood'].values.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
#Make predictions
y_pred = classifier.predict(x_test)

# %%
# Evaluate model
print(confusion_matrix(y_test.loc[:, 'neighborhood'], y_pred))
print(classification_report(y_test.loc[:, 'neighborhood'], y_pred))
# Out:
# [[ 68   0   0 ...   0   0   0]
#  [  0  48   0 ...   0   0   0]
#  [  0   0   3 ...   4   0   0]
#  ...
#  [  0   0   1 ... 117   0   0]
#  [  0   0   0 ...   2  58   0]
#  [  0   0   0 ...   0   0  63]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        68
#           1       0.89      0.94      0.91        51
#           2       0.75      0.43      0.55         7
#           3       0.92      0.55      0.69        22
#           4       0.96      0.92      0.94       104
#           5       0.97      1.00      0.98        30
#           6       0.87      0.91      0.89        76
#           7       1.00      1.00      1.00        23
#           8       0.93      0.96      0.94       878
#           9       0.85      0.80      0.82        35
#          10       0.95      0.91      0.93        69
#          11       0.98      0.95      0.96       424
#          12       1.00      1.00      1.00       268
#          13       0.78      0.91      0.84        54
#          14       0.91      0.92      0.92        53
#          15       1.00      0.78      0.88         9
#          16       0.91      0.94      0.93        54
#          17       0.89      0.93      0.91        98
#          18       1.00      1.00      1.00         7
#          19       1.00      0.93      0.97        15
#          20       0.95      0.98      0.97       173
#          21       0.80      0.91      0.85        86
#          22       0.93      0.95      0.94       104
#          23       0.67      1.00      0.80         2
#          24       0.92      0.84      0.88        86
#          25       0.99      0.92      0.95        91
#          26       0.94      0.74      0.83        23
#          27       1.00      0.92      0.96        60
#          28       1.00      1.00      1.00       438
#          29       1.00      0.92      0.96        12
#          30       0.90      0.93      0.92        29
#          31       0.93      0.94      0.93       106
#          32       0.94      0.89      0.92        94
#          33       0.88      0.86      0.87        95
#          34       0.84      0.93      0.88        28
#          35       0.94      0.72      0.82        86
#          36       0.91      0.82      0.86        49
#          37       0.99      1.00      1.00       202
#          38       0.94      0.98      0.96       119
#          39       0.88      0.92      0.90        63
#          40       0.88      0.95      0.91        66
#
# avg / total       0.94      0.94      0.94      4357

# %% [markdown]
# The above predictions were great, but I want to confirm I used the best value for K. Possibly setting 5 as the n_neighbors parameter was not the best value, so I will try  the below loop to test multiple values and use a plot to determine the best outcome.

# %%
error = []

for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i, weights='distance')
    knn.fit(x_train, y_train.loc[:, 'neighborhood'].values.ravel())
    pred_i = knn.predict(x_test)
    error.append(np.mean(pred_i != y_test.loc[:, 'neighborhood']))

# %%
#Plot the errors against the various k values
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0,0.5,'Mean Error')

# %% [markdown]
# K=4 seems to do the best with around 0.05 mean error. I will change the parameter and run it one more time, then use the model to predict the "Unknown" values.

# %%
# Run K Means on training set, this time setting n_neighbors to optimal value
classifier = KNeighborsClassifier(n_neighbors=4, weights='distance')
classifier.fit(x_train, y_train.loc[:, 'neighborhood'].values.ravel())

#Make predictions
y_pred = classifier.predict(x_test)

# %% [markdown]
# ### Predict neighborhood in AirBnB dataset

# %%
#Use the model to predict the Unknown neighborhoods in AirBnB data.
abb_copy = abb.loc[abb['neighbourhood']=='Unknown', ['id', 'latitude', 'longitude', 'neighbourhood']]

#Transform
abb_copy[['latitude', 'longitude']] = scaler.transform(abb_copy[['latitude', 'longitude']])

#Create a new column containing transformed values of neighbourhood
abb_copy['neighborhood'] = None

# %%
#Predict values of neighborhood
abb_copy['neighborhood'] = classifier.predict(abb_copy[['latitude', 'longitude']])

#Convert neighborhood back to original text values (instead of numeric)
abb_copy['neighborhood'] = le.inverse_transform(abb_copy['neighborhood'])
# Out:
# C:\Users\jshka\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
#Merge predicted neighborhood back into abb
abb = pd.merge(abb, abb_copy, how='outer', on='id')

# %%
#Replace unknown values
abb.loc[abb['neighbourhood_x']=='Unknown', 'neighbourhood_x'] = abb.loc[abb['neighbourhood_x']=='Unknown', 'neighborhood']

# %%
#Drop unecessary columns
abb.drop(columns=['latitude_y', 'longitude_y', 'neighbourhood_y', 'neighborhood'], inplace=True)
abb.head()
# Out:
#       id                         listing_url host_response_time  \
# 0   1419   https://www.airbnb.com/rooms/1419     within an hour
# 1  10314  https://www.airbnb.com/rooms/10314     within an hour
# 2  12604  https://www.airbnb.com/rooms/12604     within an hour
# 3  17936  https://www.airbnb.com/rooms/17936     within an hour
# 4  23691  https://www.airbnb.com/rooms/23691     within an hour
#
#    host_response_rate host_is_superhost host_neighbourhood    neighbourhood_x  \
# 0                 0.0                 f   Commercial Drive    Little Portugal
# 1                 0.0                 f          Riverdale          Riverdale
# 2                 0.0                 f          The Annex          The Annex
# 3               100.0                 t  Kensington Market  Kensington Market
# 4               100.0                 t           Fairbank           Wychwood
#
#   neighbourhood_cleansed  latitude_x  longitude_x property_type  \
# 0        Little Portugal   43.646168   -79.424510         House
# 1        South Riverdale   43.670186   -79.335848         House
# 2                  Annex   43.667241   -79.415978         House
# 3   Kensington-Chinatown   43.656400   -79.403295     Apartment
# 4   Briar Hill-Belgravia   43.696017   -79.454683         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0  Entire home/apt           6.0        2.0       3.0   4.0       Real Bed
# 1     Private room           2.0        1.0       1.0   1.0       Real Bed
# 2     Private room           1.0        1.5       1.0   1.0  Pull-out Sofa
# 3     Private room           4.0        1.0       1.0   2.0       Real Bed
# 4     Private room           2.0        1.0       1.0   1.0       Real Bed
#
#                                            amenities  price  security_deposit  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  470.0            1000.0
# 1  {Wifi,"Air conditioning",Kitchen,"Free parking...   69.0               0.0
# 2  {Internet,Wifi,"Pets live on this property",Ca...   65.0             130.0
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   99.0             300.0
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...   70.0               0.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0         150.0              1.0           0.0             4.0
# 1           0.0              2.0          20.0             1.0
# 2          26.0              1.0          20.0             1.0
# 3          80.0              1.0          20.0             2.0
# 4           0.0              2.0          25.0             1.0
#
#   calendar_updated  availability_30  availability_60  availability_90  \
# 0     6 months ago                0                0                0
# 1    11 months ago                0                0               21
# 2        yesterday                0                0                0
# 3       4 days ago                5                5               23
# 4            today                0               10               40
#
#    availability_365 instant_bookable          cancellation_policy  \
# 0                 0                f  strict_14_with_grace_period
# 1               296                f                     moderate
# 2                 0                f                     moderate
# 3                23                f  strict_14_with_grace_period
# 4               315                t  strict_14_with_grace_period
#
#    reviews_per_month  square_feet_notNA  monthly_price_notNA  \
# 0               0.19               True                False
# 1               0.71              False                 True
# 2               0.00               True                 True
# 3               1.18              False                 True
# 4               2.02              False                 True
#
#    weekly_price_notNA  bathrooms_notNA  beds_notNA  bedrooms_notNA  \
# 0                True             True        True            True
# 1                True             True        True            True
# 2                True             True        True            True
# 3                True             True        True            True
# 4                True             True        True            True
#
#    security_deposit_notNA  cleaning_fee_notNA  host_response_rate_notNA  \
# 0                    True                True                     False
# 1                   False               False                     False
# 2                    True                True                     False
# 3                    True                True                      True
# 4                    True                True                      True
#
#    reviews_per_month_notNA  neighbourhood_notNA  host_neighbourhood_notNA  \
# 0                     True                 True                      True
# 1                     True                 True                      True
# 2                    False                 True                      True
# 3                     True                 True                      True
# 4                     True                 True                      True
#
#    neighbourhood_cleansed_notNA  host_response_time_notNA  \
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                      True
# 4                          True                      True
#
#    host_is_superhost_notNA  has_Wifi  has_Heating  has_Essentials  \
# 0                     True      True        False           False
# 1                     True      True        False           False
# 2                     True      True        False           False
# 3                     True      True        False           False
# 4                     True      True        False           False
#
#    has_Kitchen  has_Smoke_detector  has_Air_conditioning  has_Hangers  \
# 0         True               False                  True        False
# 1         True               False                  True        False
# 2        False               False                 False        False
# 3         True               False                  True        False
# 4         True               False                  True        False
#
#    has_Washer  has_Dryer  has_Shampoo  has_Carbon_monoxide_detector  \
# 0       False      False        False                         False
# 1       False      False        False                         False
# 2       False      False        False                         False
# 3       False      False        False                         False
# 4       False      False        False                         False
#
#    has_Laptop_friendly_workspace  has_TV  has_Hair_dryer  has_Iron  \
# 0                          False    True           False     False
# 1                          False   False           False     False
# 2                          False   False           False     False
# 3                          False    True           False     False
# 4                          False   False           False     False
#
#    has_Hot_water  has_Fire_extinguisher  has_Familykid_friendly  has_Elevator  \
# 0          False                  False                   False         False
# 1          False                  False                   False         False
# 2          False                  False                   False         False
# 3          False                  False                   False         False
# 4          False                  False                   False         False
#
#    has_Free_parking_on_premises  has_First_aid_kit  has_Refrigerator  \
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
#
#    has_Internet  has_Dishes_and_silverware  has_Gym  has_Microwave  has_Stove  \
# 0          True                      False    False          False      False
# 1         False                      False    False          False      False
# 2          True                      False    False          False      False
# 3          True                      False    False          False      False
# 4          True                      False    False          False      False
#
#    has_Self_check-in  has_Oven  has_Bed_linens  has_Cooking_basics  \
# 0              False     False           False               False
# 1              False     False           False               False
# 2              False     False           False               False
# 3              False     False           False               False
# 4              False     False           False               False
#
#    has_Lock_on_bedroom_door  has_Long_term_stays_allowed  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    has_Private_entrance  has_Coffee_maker  has_Cable_TV  has_Step-free_access  \
# 0                 False             False         False                 False
# 1                 False             False         False                 False
# 2                 False             False         False                 False
# 3                 False             False         False                 False
# 4                 False             False         False                 False
#
#    has_Extra_pillows_and_blankets  has_Dishwasher  \
# 0                           False           False
# 1                           False           False
# 2                           False           False
# 3                           False           False
# 4                           False           False
#
#    has_translation_missing:_en.hosting_amenity_50  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    has_Paid_parking_off_premises  has_Pool  has_Luggage_dropoff_allowed  \
# 0                          False     False                        False
# 1                          False     False                        False
# 2                          False     False                        False
# 3                          False     False                        False
# 4                          False     False                        False
#
#    has_Patio_or_balcony  has_Safety_card  \
# 0                 False            False
# 1                 False            False
# 2                 False            False
# 3                 False            False
# 4                 False            False
#
#    has_translation_missing:_en.hosting_amenity_49  has_Hot_tub  \
# 0                                           False        False
# 1                                           False        False
# 2                                           False        False
# 3                                           False        False
# 4                                           False        False
#
#    has_Host_greets_you  has_Lockbox  has_24-hour_check-in  has_Pets_allowed  \
# 0                False        False                 False             False
# 1                False        False                 False             False
# 2                False        False                 False             False
# 3                False        False                 False             False
# 4                False        False                 False             False
#
#    has_Private_living_room  has_Paid_parking_on_premises  has_Breakfast  \
# 0                    False                         False          False
# 1                    False                         False          False
# 2                    False                         False          False
# 3                    False                         False          False
# 4                    False                         False          False
#
#    has_Bathtub  has_Wide_doorway  has_Buzzerwireless_intercom  \
# 0        False             False                        False
# 1        False             False                        False
# 2        False             False                        False
# 3        False             False                        False
# 4        False             False                        False
#
#    has_Garden_or_backyard  has_Indoor_fireplace  has_Keypad  \
# 0                   False                 False       False
# 1                   False                 False       False
# 2                   False                 False       False
# 3                   False                 False       False
# 4                   False                 False       False
#
#    has_Free_street_parking  has_Other  has_Wheelchair_accessible  has_Doorman  \
# 0                    False      False                      False        False
# 1                    False      False                      False        False
# 2                    False      False                      False        False
# 3                    False      False                      False        False
# 4                    False      False                      False        False
#
#    has_Pets_live_on_this_property  has_Well-lit_path_to_entrance  \
# 0                           False                          False
# 1                           False                          False
# 2                            True                          False
# 3                           False                          False
# 4                           False                          False
#
#    has_BBQ_grill  has_Ethernet_connection  has_Single_level_home  \
# 0          False                    False                  False
# 1          False                    False                  False
# 2          False                    False                  False
# 3          False                    False                  False
# 4          False                    False                  False
#
#    has_Wide_hallway_clearance  has_Room-darkening_shades  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    has_Flat_path_to_front_door  has_Smoking_allowed  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    has_Children’s_books_and_toys  has_Wide_clearance_to_bed  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
#
#    has_Building_staff  has_Smart_lock  has_Wide_entryway  has_High_chair  \
# 0               False           False              False           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False           False              False           False
# 4               False           False              False           False
#
#    has_Cleaning_before_checkout  has_Pack_’n_Playtravel_crib  has_Dog(s)  \
# 0                         False                        False       False
# 1                         False                        False       False
# 2                         False                        False       False
# 3                         False                        False       False
# 4                         False                        False       False
#
#    has_Accessible-height_bed  has_Cat(s)  has_Suitable_for_events  \
# 0                      False       False                    False
# 1                      False       False                    False
# 2                      False       False                    False
# 3                      False       False                    False
# 4                      False       False                    False
#
#    has_Accessible-height_toilet  has_Lake_access  has_Waterfront  has_Crib  \
# 0                         False            False           False     False
# 1                         False            False           False     False
# 2                         False            False           False     False
# 3                         False            False           False     False
# 4                         False            False           False     False
#
#    has_Handheld_shower_head  has_Children’s_dinnerware  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    has_Disabled_parking_spot  has_Game_console  has__toilet  \
# 0                      False             False        False
# 1                      False             False        False
# 2                      False             False        False
# 3                      False             False        False
# 4                      False             False        False
#
#    has_Wide_clearance_to_shower  has_Pocket_wifi  \
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
#
#    has_Babysitter_recommendations  has_Full_kitchen  has_Outlet_covers  \
# 0                           False             False              False
# 1                           False             False              False
# 2                           False             False              False
# 3                           False             False              False
# 4                           False             False              False
#
#    has_Stair_gates  has_Baby_bath  has_Hot_water_kettle  has_Window_guards  \
# 0            False          False                 False              False
# 1            False          False                 False              False
# 2            False          False                 False              False
# 3            False          False                 False              False
# 4            False          False                 False              False
#
#    has_Bathroom_essentials  has_Bedroom_comforts  has_Changing_table  \
# 0                    False                 False               False
# 1                    False                 False               False
# 2                    False                 False               False
# 3                    False                 False               False
# 4                    False                 False               False
#
#    has_Toilet_paper  has_Bath_towel  has_Body_soap  has_EV_charger  \
# 0             False           False          False           False
# 1             False           False          False           False
# 2             False           False          False           False
# 3             False           False          False           False
# 4             False           False          False           False
#
#    has_Beachfront  has_Fireplace_guards  has_Netflix  has_Other_pet(s)  \
# 0           False                 False        False             False
# 1           False                 False        False             False
# 2           False                 False        False             False
# 3           False                 False        False             False
# 4           False                 False        False             False
#
#    has_Roll-in_shower  has_  has_Beach_essentials  has_Smart_TV  \
# 0               False  True                 False         False
# 1               False  True                 False         False
# 2               False  True                 False         False
# 3               False  True                 False         False
# 4               False  True                 False         False
#
#    has_Baby_monitor  has_Fixed_grab_bars_for_shower  has_Breakfast_table  \
# 0             False                           False                False
# 1             False                           False                False
# 2             False                           False                False
# 3             False                           False                False
# 4             False                           False                False
#
#    has_Walk-in_shower  has_Convection_oven  has_Outdoor_seating  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
#
#    has_Sound_system  has_Bathtub_with_bath_chair  has_Rain_shower  \
# 0             False                        False            False
# 1             False                        False            False
# 2             False                        False            False
# 3             False                        False            False
# 4             False                        False            False
#
#    has_Balcony  has_Pillow-top_mattress  has_Table_corner_guards  \
# 0        False                    False                    False
# 1        False                    False                    False
# 2        False                    False                    False
# 3        False                    False                    False
# 4        False                    False                    False
#
#    has_Soaking_tub  has_Formal_dining_area  has_En_suite_bathroom  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    has_Memory_foam_mattress  has_Terrace  has_Central_air_conditioning  \
# 0                     False        False                         False
# 1                     False        False                         False
# 2                     False        False                         False
# 3                     False        False                         False
# 4                     False        False                         False
#
#    has_Shower_chair  has_Espresso_machine  has_Firm_mattress  has_Gas_oven  \
# 0             False                 False              False         False
# 1             False                 False              False         False
# 2             False                 False              False         False
# 3             False                 False              False         False
# 4             False                 False              False         False
#
#    has_Ceiling_fan  has_Heated_floors  has_Fixed_grab_bars_for_toilet  \
# 0            False              False                           False
# 1            False              False                           False
# 2            False              False                           False
# 3            False              False                           False
# 4            False              False                           False
#
#    has_DVD_player  has_Exercise_equipment  has_Printer  has_Outdoor_parking  \
# 0           False                   False        False                False
# 1           False                   False        False                False
# 2           False                   False        False                False
# 3           False                   False        False                False
# 4           False                   False        False                False
#
#    has_Private_bathroom  has_Shared_gym  has_Day_bed  has_HBO_GO  \
# 0                 False           False        False       False
# 1                 False           False        False       False
# 2                 False           False        False       False
# 3                 False           False        False       False
# 4                 False           False        False       False
#
#    has_Kitchenette  has_Murphy_bed  has_Amazon_Echo  has_Shared_pool  \
# 0            False           False            False            False
# 1            False           False            False            False
# 2            False           False            False            False
# 3            False           False            False            False
# 4            False           False            False            False
#
#    has_Warming_drawer  has_Ski_inSki_out  has_Fire_pit  has_Mini_fridge  \
# 0               False              False         False            False
# 1               False              False         False            False
# 2               False              False         False            False
# 3               False              False         False            False
# 4               False              False         False            False
#
#    has_Pool_with_pool_hoist  has_Sauna  has_Heated_towel_rack  \
# 0                     False      False                  False
# 1                     False      False                  False
# 2                     False      False                  False
# 3                     False      False                  False
# 4                     False      False                  False
#
#    has_Electric_profiling_bed  has_High-resolution_computer_monitor  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    has_Wine_cooler  has_Air_purifier  has_Ground_floor_access  \
# 0            False             False                    False
# 1            False             False                    False
# 2            False             False                    False
# 3            False             False                    False
# 4            False             False                    False
#
#    has_Shared_hot_tub  has_Jetted_tub  has_Mudroom  has_Touchless_faucets  \
# 0               False           False        False                  False
# 1               False           False        False                  False
# 2               False           False        False                  False
# 3               False           False        False                  False
# 4               False           False        False                  False
#
#    has_Sun_loungers  has_Mountain_view  has_Standing_valet  has_Double_oven  \
# 0             False              False               False            False
# 1             False              False               False            False
# 2             False              False               False            False
# 3             False              False               False            False
# 4             False              False               False            False
#
#    has_Fax_machine  has_Bidet  has_Beach_view  has_Brick_oven  \
# 0            False      False           False           False
# 1            False      False           False           False
# 2            False      False           False           False
# 3            False      False           False           False
# 4            False      False           False           False
#
#    has_Private_hot_tub  has_Washer__Dryer  has_Hammock  \
# 0                False              False        False
# 1                False              False        False
# 2                False              False        False
# 3                False              False        False
# 4                False              False        False
#
#    has_Projector_and_screen  has_Alfresco_bathtub  has_Steam_oven  \
# 0                     False                 False           False
# 1                     False                 False           False
# 2                     False                 False           False
# 3                     False                 False           False
# 4                     False                 False           False
#
#    host_lives_near_listing
# 0                    False
# 1                     True
# 2                     True
# 3                     True
# 4                     True

# %%
#Rename fields changed by merge
abb = abb.rename(columns={'neighbourhood_x':'neighborhood', 'latitude_x':'latitude', 
                          'longitude_x':'longitude'})

# %% [markdown]
# ### Predict neighborhood in Yelp dataset

# %%
#Use the model to predict the Unknown neighborhoods in Yelp data.
yelp_copy = yelp.loc[yelp['neighborhood']=='Unknown', ['business_id', 'latitude', 'longitude', 'neighborhood']]

#Transform
yelp_copy[['latitude', 'longitude']] = scaler.transform(yelp_copy[['latitude', 'longitude']])

#Create a new column containing transformed values of neighbourhood
yelp_copy['neighborhood'] = None

# %%
#Predict values of neighborhood
yelp_copy['neighborhood'] = classifier.predict(yelp_copy[['latitude', 'longitude']])

#Convert neighborhood back to original text values (instead of numeric)
yelp_copy['neighborhood'] = le.inverse_transform(yelp_copy['neighborhood'])
# Out:
# C:\Users\jshka\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
#Merge predicted neighborhood back into yelp
yelp = pd.merge(yelp, yelp_copy, how='outer', on='business_id')

# %%
yelp.head()
# Out:
#               business_id        city  latitude_x  longitude_x neighborhood_x  \
# 0  5J3b7j3Fzo9ISjChmoUoUA     Toronto   43.681328   -79.427884       Wychwood
# 1  Be7Mwq06nf1eNLblo1ekow  North York   43.731316   -79.465133      Downsview
# 2  RJEtBRLJmmji_QoqS6ysjg     Toronto   43.667749   -79.396167  Downtown Core
# 3  YIez_A3WOt9J2SXN7OMa2Q     Toronto   43.745928   -79.324623        Unknown
# 4  j7yI3qYRsbGBUv9rShLCaQ  Woodbridge   43.776719   -79.603614        Unknown
#
#    review_count  stars     city-state  is_restaurant  is_bar  latitude_y  \
# 0            23    4.0     Toronto-ON           True   False         NaN
# 1             5    2.5  North York-ON           True   False         NaN
# 2             3    4.5     Toronto-ON          False    True         NaN
# 3           105    4.0     Toronto-ON           True   False    1.388884
# 4            28    3.0  Woodbridge-ON           True   False    2.018737
#
#    longitude_y neighborhood_y
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3     1.013310    Scarborough
# 4    -3.136048      Etobicoke

# %%
#Replace unknown values
yelp.loc[yelp['neighborhood_x']=='Unknown', 'neighborhood_x'] = yelp.loc[yelp['neighborhood_x']=='Unknown', 'neighborhood_y']

# %%
#Drop unecessary columns
yelp.drop(columns=['latitude_y', 'longitude_y', 'neighborhood_y'], inplace=True)
yelp.head()
# Out:
#               business_id        city  latitude_x  longitude_x neighborhood_x  \
# 0  5J3b7j3Fzo9ISjChmoUoUA     Toronto   43.681328   -79.427884       Wychwood
# 1  Be7Mwq06nf1eNLblo1ekow  North York   43.731316   -79.465133      Downsview
# 2  RJEtBRLJmmji_QoqS6ysjg     Toronto   43.667749   -79.396167  Downtown Core
# 3  YIez_A3WOt9J2SXN7OMa2Q     Toronto   43.745928   -79.324623    Scarborough
# 4  j7yI3qYRsbGBUv9rShLCaQ  Woodbridge   43.776719   -79.603614      Etobicoke
#
#    review_count  stars     city-state  is_restaurant  is_bar
# 0            23    4.0     Toronto-ON           True   False
# 1             5    2.5  North York-ON           True   False
# 2             3    4.5     Toronto-ON          False    True
# 3           105    4.0     Toronto-ON           True   False
# 4            28    3.0  Woodbridge-ON           True   False

# %%
#Rename fields changed by merge
yelp = yelp.rename(columns={'neighborhood_x':'neighborhood', 'latitude_x':'latitude', 
                          'longitude_x':'longitude'})

# %% [markdown]
# ## Merge abb and yelp datasets by computing distance

# %%
#Function to compute distance between two lat/longs
#Adapted from: 
#https://stackoverflow.com/questions/19412462/getting-distance-between-two-points-based-on-latitude-longitude
from math import sin, cos, sqrt, atan2, radians

def compute_distance(lat1, lon1, lat2, lon2):

    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    
    return distance

# %%
#Make df that’s columns airbnb_id, neighborhood, lat, long
abb_hoods = abb[['id', 'neighborhood', 'latitude', 'longitude']]
abb_hoods.head()
# Out:
#       id       neighborhood   latitude  longitude
# 0   1419    Little Portugal  43.646168 -79.424510
# 1  10314          Riverdale  43.670186 -79.335848
# 2  12604          The Annex  43.667241 -79.415978
# 3  17936  Kensington Market  43.656400 -79.403295
# 4  23691           Wychwood  43.696017 -79.454683

# %%
#Make df that's columns business_id, neighborhood, number of reviews, average star rating, lat, long from Yelp
yelp_hoods = yelp[['business_id', 'neighborhood', 'latitude', 
                      'longitude', 'review_count', 'stars']]
yelp_hoods.head()
# Out:
#               business_id   neighborhood   latitude  longitude  review_count  \
# 0  5J3b7j3Fzo9ISjChmoUoUA       Wychwood  43.681328 -79.427884            23
# 1  Be7Mwq06nf1eNLblo1ekow      Downsview  43.731316 -79.465133             5
# 2  RJEtBRLJmmji_QoqS6ysjg  Downtown Core  43.667749 -79.396167             3
# 3  YIez_A3WOt9J2SXN7OMa2Q    Scarborough  43.745928 -79.324623           105
# 4  j7yI3qYRsbGBUv9rShLCaQ      Etobicoke  43.776719 -79.603614            28
#
#    stars
# 0    4.0
# 1    2.5
# 2    4.5
# 3    4.0
# 4    3.0

# %%
#merge on neighborhood (the two dfs created above)
merge = pd.merge(abb_hoods, yelp_hoods, how='inner', on='neighborhood', suffixes = ('_abb', '_yelp'))
merge.shape
# Out:
# (13376562, 9)

# %% [markdown]
# The resulting dataset has 13,376,562 rows. This was expected as I am joining datasets with a many to many relationship. For each AirBnB listing I pulled in all Yelp businesses with a matching neighborhood, so the Yelp businesses are repeated many times. The dataset would have been much larger (potentially up to 200+ million rows) if I had not matched on neighborhood and compared every AirBnB listing to every Yelp listing. Cleaning up the neighborhood names to increase matches helped too.

# %%
#apply function to generate distance
merge['distance'] = list(map(compute_distance, merge['latitude_abb'], 
                            merge['longitude_abb'], merge['latitude_yelp'],
                            merge['longitude_yelp']))

# %%
#Output full merge dataframe to a pickle file for later re-use
merge.to_pickle('full_merge.pickle')

# %%
merge.loc[merge['distance']>0].head()
# Out:
#      id     neighborhood  latitude_abb  longitude_abb             business_id  \
# 0  1419  Little Portugal     43.646168      -79.42451  s8-aBYSaPLR8wbfmnkqGWw
# 1  1419  Little Portugal     43.646168      -79.42451  DM6SwVs5ksGe9mWKO94Q0A
# 2  1419  Little Portugal     43.646168      -79.42451  a9sK9Ma4kIkN0Zpu0SSAtA
# 3  1419  Little Portugal     43.646168      -79.42451  g4rBVDdbeDPKnJiNhNWgSQ
# 4  1419  Little Portugal     43.646168      -79.42451  8al-XRt5nuIize8_STWffQ
#
#    latitude_yelp  longitude_yelp  review_count  stars   distance
# 0      43.610812      -79.748986            11    3.5  26.418342
# 1      43.649112      -79.420954            51    3.5   0.434949
# 2      43.596900      -79.785846            17    1.5  29.606594
# 3      43.574035      -79.739762             3    4.0  26.626706
# 4      43.643191      -79.423903            53    3.5   0.334715

# %% [markdown]
# Now that I have computed distance between each AirBnB listing and all Yelp businesses in the same neighborhood, I want to create two sets of features: number of businesses, number of reviews, and average star rating, for all businesses within .1 and .5 miles. The end result should be 6 new variables.
#
# First I need to create two new dataframes - one containing all records from merge where distance is <= .1, the other where distance is <= .5.

# %%
#filter for distance < .1
merge_1 = merge[merge['distance']<=.1]
#filter for distance < .5
merge_5 = merge[merge['distance']<=.5]
print(merge_1.shape)
print(merge_5.shape)
# Out:
# (44667, 10)
# (787058, 10)

# %%
#For each dataset, group by airbnb_id with count to get number of businesses in that distance 
#Also avg. star rating and number of reviews
#For everything within .1 mile:
merge_group_1 = merge_1.groupby(['id']).agg({'business_id':'count',
                                                        'review_count':'sum',
                                                        'stars':'mean'})
merge_group_1 = merge_group_1.rename(columns={'business_id':'yelp_bus_count_1', 
                                          'review_count':'yelp_bus_total_reviews_1', 
                                          'stars':'yelp_bus_avg_rating_1'})

#For everything within .5 mile:
merge_group_5 = merge_5.groupby(['id']).agg({'business_id':'count',
                                                        'review_count':'sum',
                                                        'stars':'mean'})
merge_group_5 = merge_group_5.rename(columns={'business_id':'yelp_bus_count_5', 
                                          'review_count':'yelp_bus_total_reviews_5', 
                                          'stars':'yelp_bus_avg_rating_5'})

# %%
#Merge merge_group_1 and merge_group_5 together
merge_both = pd.merge(merge_group_1, merge_group_5, how='right', on='id')
merge_both.head()
# Out:
#        yelp_bus_count_1  yelp_bus_total_reviews_1  yelp_bus_avg_rating_1  \
# id
# 1419                1.0                      66.0               3.500000
# 17936              20.0                    1440.0               3.650000
# 42892               2.0                      18.0               3.500000
# 44452              11.0                     222.0               3.136364
# 44469              13.0                     232.0               3.115385
#
#        yelp_bus_count_5  yelp_bus_total_reviews_5  yelp_bus_avg_rating_5
# id
# 1419                116                      8634               3.758621
# 17936               160                     11434               3.715625
# 42892                83                      3378               3.162651
# 44452                16                       255               3.250000
# 44469                16                       255               3.250000

# %%
#Merge merge_both with abb
abb = pd.merge(abb, merge_both, on='id', how='left')
abb.head()
# Out:
#       id                         listing_url host_response_time  \
# 0   1419   https://www.airbnb.com/rooms/1419     within an hour
# 1  10314  https://www.airbnb.com/rooms/10314     within an hour
# 2  12604  https://www.airbnb.com/rooms/12604     within an hour
# 3  17936  https://www.airbnb.com/rooms/17936     within an hour
# 4  23691  https://www.airbnb.com/rooms/23691     within an hour
#
#    host_response_rate host_is_superhost host_neighbourhood       neighborhood  \
# 0                 0.0                 f   Commercial Drive    Little Portugal
# 1                 0.0                 f          Riverdale          Riverdale
# 2                 0.0                 f          The Annex          The Annex
# 3               100.0                 t  Kensington Market  Kensington Market
# 4               100.0                 t           Fairbank           Wychwood
#
#   neighbourhood_cleansed   latitude  longitude property_type        room_type  \
# 0        Little Portugal  43.646168 -79.424510         House  Entire home/apt
# 1        South Riverdale  43.670186 -79.335848         House     Private room
# 2                  Annex  43.667241 -79.415978         House     Private room
# 3   Kensington-Chinatown  43.656400 -79.403295     Apartment     Private room
# 4   Briar Hill-Belgravia  43.696017 -79.454683         House     Private room
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0           6.0        2.0       3.0   4.0       Real Bed
# 1           2.0        1.0       1.0   1.0       Real Bed
# 2           1.0        1.5       1.0   1.0  Pull-out Sofa
# 3           4.0        1.0       1.0   2.0       Real Bed
# 4           2.0        1.0       1.0   1.0       Real Bed
#
#                                            amenities  price  security_deposit  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  470.0            1000.0
# 1  {Wifi,"Air conditioning",Kitchen,"Free parking...   69.0               0.0
# 2  {Internet,Wifi,"Pets live on this property",Ca...   65.0             130.0
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   99.0             300.0
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...   70.0               0.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0         150.0              1.0           0.0             4.0
# 1           0.0              2.0          20.0             1.0
# 2          26.0              1.0          20.0             1.0
# 3          80.0              1.0          20.0             2.0
# 4           0.0              2.0          25.0             1.0
#
#   calendar_updated  availability_30  availability_60  availability_90  \
# 0     6 months ago                0                0                0
# 1    11 months ago                0                0               21
# 2        yesterday                0                0                0
# 3       4 days ago                5                5               23
# 4            today                0               10               40
#
#    availability_365 instant_bookable          cancellation_policy  \
# 0                 0                f  strict_14_with_grace_period
# 1               296                f                     moderate
# 2                 0                f                     moderate
# 3                23                f  strict_14_with_grace_period
# 4               315                t  strict_14_with_grace_period
#
#    reviews_per_month  square_feet_notNA  monthly_price_notNA  \
# 0               0.19               True                False
# 1               0.71              False                 True
# 2               0.00               True                 True
# 3               1.18              False                 True
# 4               2.02              False                 True
#
#    weekly_price_notNA  bathrooms_notNA  beds_notNA  bedrooms_notNA  \
# 0                True             True        True            True
# 1                True             True        True            True
# 2                True             True        True            True
# 3                True             True        True            True
# 4                True             True        True            True
#
#    security_deposit_notNA  cleaning_fee_notNA  host_response_rate_notNA  \
# 0                    True                True                     False
# 1                   False               False                     False
# 2                    True                True                     False
# 3                    True                True                      True
# 4                    True                True                      True
#
#    reviews_per_month_notNA  neighbourhood_notNA  host_neighbourhood_notNA  \
# 0                     True                 True                      True
# 1                     True                 True                      True
# 2                    False                 True                      True
# 3                     True                 True                      True
# 4                     True                 True                      True
#
#    neighbourhood_cleansed_notNA  host_response_time_notNA  \
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                      True
# 4                          True                      True
#
#    host_is_superhost_notNA  has_Wifi  has_Heating  has_Essentials  \
# 0                     True      True        False           False
# 1                     True      True        False           False
# 2                     True      True        False           False
# 3                     True      True        False           False
# 4                     True      True        False           False
#
#    has_Kitchen  has_Smoke_detector  has_Air_conditioning  has_Hangers  \
# 0         True               False                  True        False
# 1         True               False                  True        False
# 2        False               False                 False        False
# 3         True               False                  True        False
# 4         True               False                  True        False
#
#    has_Washer  has_Dryer  has_Shampoo  has_Carbon_monoxide_detector  \
# 0       False      False        False                         False
# 1       False      False        False                         False
# 2       False      False        False                         False
# 3       False      False        False                         False
# 4       False      False        False                         False
#
#    has_Laptop_friendly_workspace  has_TV  has_Hair_dryer  has_Iron  \
# 0                          False    True           False     False
# 1                          False   False           False     False
# 2                          False   False           False     False
# 3                          False    True           False     False
# 4                          False   False           False     False
#
#    has_Hot_water  has_Fire_extinguisher  has_Familykid_friendly  has_Elevator  \
# 0          False                  False                   False         False
# 1          False                  False                   False         False
# 2          False                  False                   False         False
# 3          False                  False                   False         False
# 4          False                  False                   False         False
#
#    has_Free_parking_on_premises  has_First_aid_kit  has_Refrigerator  \
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False              False             False
# 4                         False              False             False
#
#    has_Internet  has_Dishes_and_silverware  has_Gym  has_Microwave  has_Stove  \
# 0          True                      False    False          False      False
# 1         False                      False    False          False      False
# 2          True                      False    False          False      False
# 3          True                      False    False          False      False
# 4          True                      False    False          False      False
#
#    has_Self_check-in  has_Oven  has_Bed_linens  has_Cooking_basics  \
# 0              False     False           False               False
# 1              False     False           False               False
# 2              False     False           False               False
# 3              False     False           False               False
# 4              False     False           False               False
#
#    has_Lock_on_bedroom_door  has_Long_term_stays_allowed  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    has_Private_entrance  has_Coffee_maker  has_Cable_TV  has_Step-free_access  \
# 0                 False             False         False                 False
# 1                 False             False         False                 False
# 2                 False             False         False                 False
# 3                 False             False         False                 False
# 4                 False             False         False                 False
#
#    has_Extra_pillows_and_blankets  has_Dishwasher  \
# 0                           False           False
# 1                           False           False
# 2                           False           False
# 3                           False           False
# 4                           False           False
#
#    has_translation_missing:_en.hosting_amenity_50  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    has_Paid_parking_off_premises  has_Pool  has_Luggage_dropoff_allowed  \
# 0                          False     False                        False
# 1                          False     False                        False
# 2                          False     False                        False
# 3                          False     False                        False
# 4                          False     False                        False
#
#    has_Patio_or_balcony  has_Safety_card  \
# 0                 False            False
# 1                 False            False
# 2                 False            False
# 3                 False            False
# 4                 False            False
#
#    has_translation_missing:_en.hosting_amenity_49  has_Hot_tub  \
# 0                                           False        False
# 1                                           False        False
# 2                                           False        False
# 3                                           False        False
# 4                                           False        False
#
#    has_Host_greets_you  has_Lockbox  has_24-hour_check-in  has_Pets_allowed  \
# 0                False        False                 False             False
# 1                False        False                 False             False
# 2                False        False                 False             False
# 3                False        False                 False             False
# 4                False        False                 False             False
#
#    has_Private_living_room  has_Paid_parking_on_premises  has_Breakfast  \
# 0                    False                         False          False
# 1                    False                         False          False
# 2                    False                         False          False
# 3                    False                         False          False
# 4                    False                         False          False
#
#    has_Bathtub  has_Wide_doorway  has_Buzzerwireless_intercom  \
# 0        False             False                        False
# 1        False             False                        False
# 2        False             False                        False
# 3        False             False                        False
# 4        False             False                        False
#
#    has_Garden_or_backyard  has_Indoor_fireplace  has_Keypad  \
# 0                   False                 False       False
# 1                   False                 False       False
# 2                   False                 False       False
# 3                   False                 False       False
# 4                   False                 False       False
#
#    has_Free_street_parking  has_Other  has_Wheelchair_accessible  has_Doorman  \
# 0                    False      False                      False        False
# 1                    False      False                      False        False
# 2                    False      False                      False        False
# 3                    False      False                      False        False
# 4                    False      False                      False        False
#
#    has_Pets_live_on_this_property  has_Well-lit_path_to_entrance  \
# 0                           False                          False
# 1                           False                          False
# 2                            True                          False
# 3                           False                          False
# 4                           False                          False
#
#    has_BBQ_grill  has_Ethernet_connection  has_Single_level_home  \
# 0          False                    False                  False
# 1          False                    False                  False
# 2          False                    False                  False
# 3          False                    False                  False
# 4          False                    False                  False
#
#    has_Wide_hallway_clearance  has_Room-darkening_shades  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
#
#    has_Flat_path_to_front_door  has_Smoking_allowed  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    has_Children’s_books_and_toys  has_Wide_clearance_to_bed  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
#
#    has_Building_staff  has_Smart_lock  has_Wide_entryway  has_High_chair  \
# 0               False           False              False           False
# 1               False           False              False           False
# 2               False           False              False           False
# 3               False           False              False           False
# 4               False           False              False           False
#
#    has_Cleaning_before_checkout  has_Pack_’n_Playtravel_crib  has_Dog(s)  \
# 0                         False                        False       False
# 1                         False                        False       False
# 2                         False                        False       False
# 3                         False                        False       False
# 4                         False                        False       False
#
#    has_Accessible-height_bed  has_Cat(s)  has_Suitable_for_events  \
# 0                      False       False                    False
# 1                      False       False                    False
# 2                      False       False                    False
# 3                      False       False                    False
# 4                      False       False                    False
#
#    has_Accessible-height_toilet  has_Lake_access  has_Waterfront  has_Crib  \
# 0                         False            False           False     False
# 1                         False            False           False     False
# 2                         False            False           False     False
# 3                         False            False           False     False
# 4                         False            False           False     False
#
#    has_Handheld_shower_head  has_Children’s_dinnerware  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    has_Disabled_parking_spot  has_Game_console  has__toilet  \
# 0                      False             False        False
# 1                      False             False        False
# 2                      False             False        False
# 3                      False             False        False
# 4                      False             False        False
#
#    has_Wide_clearance_to_shower  has_Pocket_wifi  \
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
#
#    has_Babysitter_recommendations  has_Full_kitchen  has_Outlet_covers  \
# 0                           False             False              False
# 1                           False             False              False
# 2                           False             False              False
# 3                           False             False              False
# 4                           False             False              False
#
#    has_Stair_gates  has_Baby_bath  has_Hot_water_kettle  has_Window_guards  \
# 0            False          False                 False              False
# 1            False          False                 False              False
# 2            False          False                 False              False
# 3            False          False                 False              False
# 4            False          False                 False              False
#
#    has_Bathroom_essentials  has_Bedroom_comforts  has_Changing_table  \
# 0                    False                 False               False
# 1                    False                 False               False
# 2                    False                 False               False
# 3                    False                 False               False
# 4                    False                 False               False
#
#    has_Toilet_paper  has_Bath_towel  has_Body_soap  has_EV_charger  \
# 0             False           False          False           False
# 1             False           False          False           False
# 2             False           False          False           False
# 3             False           False          False           False
# 4             False           False          False           False
#
#    has_Beachfront  has_Fireplace_guards  has_Netflix  has_Other_pet(s)  \
# 0           False                 False        False             False
# 1           False                 False        False             False
# 2           False                 False        False             False
# 3           False                 False        False             False
# 4           False                 False        False             False
#
#    has_Roll-in_shower  has_  has_Beach_essentials  has_Smart_TV  \
# 0               False  True                 False         False
# 1               False  True                 False         False
# 2               False  True                 False         False
# 3               False  True                 False         False
# 4               False  True                 False         False
#
#    has_Baby_monitor  has_Fixed_grab_bars_for_shower  has_Breakfast_table  \
# 0             False                           False                False
# 1             False                           False                False
# 2             False                           False                False
# 3             False                           False                False
# 4             False                           False                False
#
#    has_Walk-in_shower  has_Convection_oven  has_Outdoor_seating  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
#
#    has_Sound_system  has_Bathtub_with_bath_chair  has_Rain_shower  \
# 0             False                        False            False
# 1             False                        False            False
# 2             False                        False            False
# 3             False                        False            False
# 4             False                        False            False
#
#    has_Balcony  has_Pillow-top_mattress  has_Table_corner_guards  \
# 0        False                    False                    False
# 1        False                    False                    False
# 2        False                    False                    False
# 3        False                    False                    False
# 4        False                    False                    False
#
#    has_Soaking_tub  has_Formal_dining_area  has_En_suite_bathroom  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    has_Memory_foam_mattress  has_Terrace  has_Central_air_conditioning  \
# 0                     False        False                         False
# 1                     False        False                         False
# 2                     False        False                         False
# 3                     False        False                         False
# 4                     False        False                         False
#
#    has_Shower_chair  has_Espresso_machine  has_Firm_mattress  has_Gas_oven  \
# 0             False                 False              False         False
# 1             False                 False              False         False
# 2             False                 False              False         False
# 3             False                 False              False         False
# 4             False                 False              False         False
#
#    has_Ceiling_fan  has_Heated_floors  has_Fixed_grab_bars_for_toilet  \
# 0            False              False                           False
# 1            False              False                           False
# 2            False              False                           False
# 3            False              False                           False
# 4            False              False                           False
#
#    has_DVD_player  has_Exercise_equipment  has_Printer  has_Outdoor_parking  \
# 0           False                   False        False                False
# 1           False                   False        False                False
# 2           False                   False        False                False
# 3           False                   False        False                False
# 4           False                   False        False                False
#
#    has_Private_bathroom  has_Shared_gym  has_Day_bed  has_HBO_GO  \
# 0                 False           False        False       False
# 1                 False           False        False       False
# 2                 False           False        False       False
# 3                 False           False        False       False
# 4                 False           False        False       False
#
#    has_Kitchenette  has_Murphy_bed  has_Amazon_Echo  has_Shared_pool  \
# 0            False           False            False            False
# 1            False           False            False            False
# 2            False           False            False            False
# 3            False           False            False            False
# 4            False           False            False            False
#
#    has_Warming_drawer  has_Ski_inSki_out  has_Fire_pit  has_Mini_fridge  \
# 0               False              False         False            False
# 1               False              False         False            False
# 2               False              False         False            False
# 3               False              False         False            False
# 4               False              False         False            False
#
#    has_Pool_with_pool_hoist  has_Sauna  has_Heated_towel_rack  \
# 0                     False      False                  False
# 1                     False      False                  False
# 2                     False      False                  False
# 3                     False      False                  False
# 4                     False      False                  False
#
#    has_Electric_profiling_bed  has_High-resolution_computer_monitor  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    has_Wine_cooler  has_Air_purifier  has_Ground_floor_access  \
# 0            False             False                    False
# 1            False             False                    False
# 2            False             False                    False
# 3            False             False                    False
# 4            False             False                    False
#
#    has_Shared_hot_tub  has_Jetted_tub  has_Mudroom  has_Touchless_faucets  \
# 0               False           False        False                  False
# 1               False           False        False                  False
# 2               False           False        False                  False
# 3               False           False        False                  False
# 4               False           False        False                  False
#
#    has_Sun_loungers  has_Mountain_view  has_Standing_valet  has_Double_oven  \
# 0             False              False               False            False
# 1             False              False               False            False
# 2             False              False               False            False
# 3             False              False               False            False
# 4             False              False               False            False
#
#    has_Fax_machine  has_Bidet  has_Beach_view  has_Brick_oven  \
# 0            False      False           False           False
# 1            False      False           False           False
# 2            False      False           False           False
# 3            False      False           False           False
# 4            False      False           False           False
#
#    has_Private_hot_tub  has_Washer__Dryer  has_Hammock  \
# 0                False              False        False
# 1                False              False        False
# 2                False              False        False
# 3                False              False        False
# 4                False              False        False
#
#    has_Projector_and_screen  has_Alfresco_bathtub  has_Steam_oven  \
# 0                     False                 False           False
# 1                     False                 False           False
# 2                     False                 False           False
# 3                     False                 False           False
# 4                     False                 False           False
#
#    host_lives_near_listing  yelp_bus_count_1  yelp_bus_total_reviews_1  \
# 0                    False               1.0                      66.0
# 1                     True               NaN                       NaN
# 2                     True               NaN                       NaN
# 3                     True              20.0                    1440.0
# 4                     True               NaN                       NaN
#
#    yelp_bus_avg_rating_1  yelp_bus_count_5  yelp_bus_total_reviews_5  \
# 0                   3.50             116.0                    8634.0
# 1                    NaN               NaN                       NaN
# 2                    NaN              11.0                    1631.0
# 3                   3.65             160.0                   11434.0
# 4                    NaN              11.0                     147.0
#
#    yelp_bus_avg_rating_5
# 0               3.758621
# 1                    NaN
# 2               3.045455
# 3               3.715625
# 4               3.363636

# %%
abb.describe()
# Out:
#                  id  host_response_rate      latitude     longitude  \
# count  1.601500e+04        16015.000000  16015.000000  16015.000000
# mean   1.670187e+07           74.073806     43.675447    -79.394362
# std    7.574915e+06           41.326389      0.045715      0.059207
# min    1.419000e+03            0.000000     43.586713    -79.624535
# 25%    1.107421e+07           60.000000     43.644600    -79.421380
# 50%    1.830220e+07          100.000000     43.660277    -79.396762
# 75%    2.286471e+07          100.000000     43.683781    -79.377056
# max    2.758201e+07          100.000000     43.847487    -79.127812
#
#        accommodates     bathrooms      bedrooms          beds         price  \
# count  16015.000000  16015.000000  16015.000000  16015.000000  16015.000000
# mean       2.899157      1.178489      1.241399      1.586638    127.663128
# std        1.472875      0.363077      0.690384      0.851227     94.571789
# min        1.000000      1.000000      0.000000      1.000000     13.000000
# 25%        2.000000      1.000000      1.000000      1.000000     65.000000
# 50%        2.000000      1.000000      1.000000      1.000000    100.000000
# 75%        4.000000      1.000000      1.000000      2.000000    159.000000
# max        6.000000      2.000000      3.000000      4.000000    850.000000
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# count      16015.000000  16015.000000     16015.000000  16015.000000
# mean         205.808554     42.909397         1.537184     12.132688
# std          238.608769     38.071111         0.905129     15.279791
# min            0.000000      0.000000         1.000000      0.000000
# 25%            0.000000     10.000000         1.000000      0.000000
# 50%          150.000000     39.000000         1.000000      0.000000
# 75%          300.000000     65.000000         2.000000     20.000000
# max         1301.000000    170.000000         4.000000     50.000000
#
#        minimum_nights  availability_30  availability_60  availability_90  \
# count    16015.000000     16015.000000     16015.000000     16015.000000
# mean         3.718077         6.622354        17.506088        31.584265
# std          5.599526         8.669659        19.152098        30.762243
# min          1.000000         0.000000         0.000000         0.000000
# 25%          1.000000         0.000000         0.000000         0.000000
# 50%          2.000000         3.000000        10.000000        25.000000
# 75%          3.000000        10.000000        33.000000        59.000000
# max         25.000000        30.000000        60.000000        90.000000
#
#        availability_365  reviews_per_month  yelp_bus_count_1  \
# count      16015.000000       16015.000000       6833.000000
# mean         120.364721           1.631777          6.536953
# std          126.744106           2.107906          6.495054
# min            0.000000           0.000000          1.000000
# 25%            1.000000           0.120000          2.000000
# 50%           69.000000           0.810000          4.000000
# 75%          224.000000           2.340000          9.000000
# max          365.000000          16.860000         67.000000
#
#        yelp_bus_total_reviews_1  yelp_bus_avg_rating_1  yelp_bus_count_5  \
# count               6833.000000            6833.000000      14220.000000
# mean                 425.326211               3.411222         55.348664
# std                  624.357365               0.505063         62.526417
# min                    3.000000               1.000000          1.000000
# 25%                   50.000000               3.125000          9.000000
# 50%                  181.000000               3.444444         29.000000
# 75%                  526.000000               3.727273         86.000000
# max                 5010.000000               5.000000        362.000000
#
#        yelp_bus_total_reviews_5  yelp_bus_avg_rating_5
# count              14220.000000           14220.000000
# mean                3574.035162               3.455235
# std                 4942.273628               0.353630
# min                    3.000000               1.000000
# 25%                  246.000000               3.253650
# 50%                 1230.000000               3.423077
# 75%                 4683.000000               3.666667
# max                24010.000000               5.000000

# %% [markdown]
# After merging, I used the describe method to see the counts for the metrics for .1 and .5 mile. For comparison, the abb dataframe has 16,015 records.
#
# 6,833 AirBnB listings have at least one Yelp listing within .1 mile, which is less than half of all listings. I will need to decide what to do with the missing values. I will most likely replace them with 0s, and create a flag variable to indicate there were no businesses within that range.
#
# 14,220 AirBnB listings have at least one Yelp lsting within .5 mile, wich is close to 90% of all listings. Again I will need to do something with the missing values, most likely impute with 0 and create a flag.

# %% [markdown]
# ## Save File for Easy Access

# %%
abb.to_csv('../Capstone/Data/abb_merged.csv', index=False)
