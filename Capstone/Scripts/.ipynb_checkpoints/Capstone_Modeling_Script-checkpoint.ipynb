# %% [markdown]
# # Capstone Modeling Script

# %%
#Import general data manipulation/plotting packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy import stats

#Import regression packages
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels import regression
from patsy import dmatrices
from sklearn import linear_model

#Import train/test and cross validation packages
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import MinMaxScaler


#Import random forest package
from sklearn.ensemble import RandomForestRegressor

#allow all columns to be viewed:
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
current_path = % pwd
#If current_path is in Scripts folder, 
#go up one level so we can open the data folder
if (current_path.rsplit('\\', 1)[1] == 'Scripts'):
    % cd ..
# Out:
# D:\Coding Projects\Springboard\Springboard_Projects\Capstone

# %%
#Import data

#Read in AirBnB dataset that has been merged with summarized Yelp information:
#... (number of businesses, total reviews, and average star rating for businesses w/in .1 and .5 miles)
path1='../Capstone/Data/abb_stat_inf_changes.csv'
abb = pd.read_csv(path1)

print(abb.shape)
abb.head()
# Out:
# (16011, 73)
#       id host_response_time  host_response_rate host_is_superhost  \
# 0   1419     within an hour                 0.0                 f
# 1  10314     within an hour                 0.0                 f
# 2  12604     within an hour                 0.0                 f
# 3  17936     within an hour               100.0                 t
# 4  23691     within an hour               100.0                 t
#
#         neighborhood property_type        room_type  accommodates  bathrooms  \
# 0    Little Portugal         House  Entire home/apt           6.0        2.0
# 1          Riverdale         House     Private room           2.0        1.0
# 2          The Annex         House     Private room           1.0        1.5
# 3  Kensington Market     Apartment     Private room           4.0        1.0
# 4           Wychwood         House     Private room           2.0        1.0
#
#    bedrooms  beds       bed_type  price  security_deposit  cleaning_fee  \
# 0       3.0   4.0       Real Bed  470.0            1000.0         150.0
# 1       1.0   1.0       Real Bed   69.0               0.0           0.0
# 2       1.0   1.0  Pull-out Sofa   65.0             130.0          26.0
# 3       1.0   2.0       Real Bed   99.0             300.0          80.0
# 4       1.0   1.0       Real Bed   70.0               0.0           0.0
#
#    guests_included  extra_people  minimum_nights instant_bookable  \
# 0              1.0           0.0             4.0                f
# 1              2.0          20.0             1.0                f
# 2              1.0          20.0             1.0                f
# 3              1.0          20.0             2.0                f
# 4              2.0          25.0             1.0                t
#
#            cancellation_policy  square_feet_notNA  monthly_price_notNA  \
# 0  strict_14_with_grace_period               True                False
# 1                     moderate              False                 True
# 2                     moderate               True                 True
# 3  strict_14_with_grace_period              False                 True
# 4  strict_14_with_grace_period              False                 True
#
#    weekly_price_notNA  bathrooms_notNA  beds_notNA  bedrooms_notNA  \
# 0                True             True        True            True
# 1                True             True        True            True
# 2                True             True        True            True
# 3                True             True        True            True
# 4                True             True        True            True
#
#    security_deposit_notNA  cleaning_fee_notNA  host_response_rate_notNA  \
# 0                    True                True                     False
# 1                   False               False                     False
# 2                    True                True                     False
# 3                    True                True                      True
# 4                    True                True                      True
#
#    reviews_per_month_notNA  neighbourhood_notNA  host_neighbourhood_notNA  \
# 0                     True                 True                      True
# 1                     True                 True                      True
# 2                    False                 True                      True
# 3                     True                 True                      True
# 4                     True                 True                      True
#
#    neighbourhood_cleansed_notNA  host_response_time_notNA  \
# 0                          True                     False
# 1                          True                     False
# 2                          True                     False
# 3                          True                      True
# 4                          True                      True
#
#    host_is_superhost_notNA  has_Wifi  has_Heating  has_Essentials  \
# 0                     True      True        False           False
# 1                     True      True        False           False
# 2                     True      True        False           False
# 3                     True      True        False           False
# 4                     True      True        False           False
#
#    has_Kitchen  has_Smoke_detector  has_Air_conditioning  has_Hangers  \
# 0         True               False                  True        False
# 1         True               False                  True        False
# 2        False               False                 False        False
# 3         True               False                  True        False
# 4         True               False                  True        False
#
#    has_Washer  has_Dryer  has_Shampoo  has_TV  has_Familykid_friendly  \
# 0       False      False        False    True                   False
# 1       False      False        False   False                   False
# 2       False      False        False   False                   False
# 3       False      False        False    True                   False
# 4       False      False        False   False                   False
#
#    has_Elevator  has_Free_parking_on_premises  has_Internet  has_Gym  \
# 0         False                         False          True    False
# 1         False                         False         False    False
# 2         False                         False          True    False
# 3         False                         False          True    False
# 4         False                         False          True    False
#
#    has_Cable_TV  has_Paid_parking_off_premises  has_Pool  has_Hot_tub  \
# 0         False                          False     False        False
# 1         False                          False     False        False
# 2         False                          False     False        False
# 3         False                          False     False        False
# 4         False                          False     False        False
#
#    has_Pets_allowed  has_Breakfast  has_Buzzerwireless_intercom  \
# 0             False          False                        False
# 1             False          False                        False
# 2             False          False                        False
# 3             False          False                        False
# 4             False          False                        False
#
#    has_Indoor_fireplace  has_Free_street_parking  has_Wheelchair_accessible  \
# 0                 False                    False                      False
# 1                 False                    False                      False
# 2                 False                    False                      False
# 3                 False                    False                      False
# 4                 False                    False                      False
#
#    has_Doorman  has_Pets_live_on_this_property  has_Smoking_allowed  \
# 0        False                           False                False
# 1        False                           False                False
# 2        False                            True                False
# 3        False                           False                False
# 4        False                           False                False
#
#    host_lives_near_listing  yelp_bus_count_1  yelp_bus_total_reviews_1  \
# 0                    False               1.0                      66.0
# 1                     True               NaN                       NaN
# 2                     True               NaN                       NaN
# 3                     True              20.0                    1440.0
# 4                     True               NaN                       NaN
#
#    yelp_bus_avg_rating_1  yelp_bus_count_5  yelp_bus_total_reviews_5  \
# 0                   3.50             116.0                    8634.0
# 1                    NaN               NaN                       NaN
# 2                    NaN              11.0                    1631.0
# 3                   3.65             160.0                   11434.0
# 4                    NaN              11.0                     147.0
#
#    yelp_bus_avg_rating_5  log_price  Utilization_Rate
# 0               3.758621   6.152733          0.013053
# 1                    NaN   4.234107          0.042601
# 2               3.045455   4.174387          0.000866
# 3               3.715625   4.595120          0.105691
# 4               3.363636   4.248495          0.092562

# %% [markdown]
# ## Drop Unecessary Variables

# %% [markdown]
# ### Drop Uneeded Amenities
# Earlier in the Statistical Inference script I ran a series of t-tests to determine whether each Amenity has a statistically significant relationship to Price and/or Utilization Rate.
#
# I plan to drop Amenities that did not have a statistically significant relationship. My desired p-value to determine statistical significance is 0.05. However I know that when making multiple comparisons, it is often very easy to have tests that pass the threshold purely by chance. The Bonferroni correction is a simple way to avoid this issue.
#
# The number of comparisons being made is 29, so I know my actual p-value threshold needs to be (0.05/29=) 0.0017. I will drop any amenities that did not pass that threshold.
#
# Note: There were differences in which Amenities were statistically significant against Price vs. Utilization Rate. At this point I will create two datasets, one to predict Price, the other Utilization Rate, so I can keep the variables with the best relationship to each outcome.

# %%
#Create copies of dataset
abb_Price_predict = abb.copy()
abb_Util_predict = abb.copy()

# %%
#Drop amenity variables with a p-value greater than 0.0017 from Price prediction dataset
drop_cols = ['has_Wifi', 'has_Doorman', 'has_Indoor_fireplace', 'has_Familykid_friendly', 'has_Wheelchair_accessible',
            'has_Hot_tub', 'has_Hangers', 'has_Buzzerwireless_intercom', 'has_Shampoo']

abb_Price_predict.drop(columns=drop_cols, axis=1, inplace=True)

abb_Price_predict.shape
# Out:
# (16011, 64)

# %%
#Drop amenity variables with a p-value greater than 0.0017 from Utilization_Rate prediction dataset
drop_cols = ['has_Hangers', 'has_Smoking_allowed', 'has_Pool', 'has_Hot_tub', 'has_Air_conditioning', 'has_Elevator',
            'has_Gym', 'has_Familykid_friendly', 'has_Free_parking_on_premises', 'has_Smoke_detector', 'has_Wheelchair_accessible',
            'has_Pets_allowed', 'has_Indoor_fireplace', 'has_Paid_parking_off_premises', 'has_Breakfast', 'has_Doorman',
            'has_Essentials', 'has_Free_street_parking', 'has_Pets_live_on_this_property', 'has_Shampoo', 'has_Buzzerwireless_intercom']

abb_Util_predict.drop(columns=drop_cols, axis=1, inplace=True)

abb_Util_predict.shape
# Out:
# (16011, 52)

# %% [markdown]
# ### Drop Uneeded "NA" Flag Variables
#
# Now I will do the same for the \_notNA variables, which are flag variables I created during data wrangling to tell me if a value was missing for a given variable. I did a series of t-tests on these against Price and Utilization to see which had a statistically significant relationship.
#
# This time the number of comparisons was 10, so the p-value threshold they need to pass for significance is (0.05/10=) 0.005.
#
# Note: Technically there were 15 \_notNA variables tested in the Statistical Inference script, but this was a mistake. 5 of those had no NA values (likely the records with missing values were dropped over time for those) so they had no actual data to test. Those variables will be dropped below as well.

# %%
#Drop _notNA variables with a p-value greater than 0.0017 from Price prediction dataset
drop_cols = ['bathrooms_notNA', 'beds_notNA', 'bedrooms_notNA', 'neighbourhood_cleansed_notNA', 'host_is_superhost_notNA',
            'monthly_price_notNA', 'weekly_price_notNA', 'neighbourhood_notNA', 'host_response_rate_notNA', 'host_response_time_notNA',
            'host_neighbourhood_notNA', 'square_feet_notNA']

abb_Price_predict.drop(columns=drop_cols, axis=1, inplace=True)

abb_Price_predict.shape
# Out:
# (16011, 52)

# %%
#Drop _notNA variables with a p-value greater than 0.0017 from Utilization Rate prediction dataset
drop_cols = ['bathrooms_notNA', 'beds_notNA', 'bedrooms_notNA', 'neighbourhood_cleansed_notNA', 'host_is_superhost_notNA',
            'square_feet_notNA', 'weekly_price_notNA', 'host_neighbourhood_notNA', 'monthly_price_notNA']

abb_Util_predict.drop(columns=drop_cols, axis=1, inplace=True)

abb_Util_predict.shape
# Out:
# (16011, 43)

# %% [markdown]
# ### Drop Yelp Business Metrics w/out Statistical Significance, Create Flag Variables for Having a Business w/in .1 and .5 Miles
#
# Next I will drop the Yelp Business metrics that did not show a statistically significant correlation with Price/Utilization (or if the correlation was extremely low).
#
# As a reminder, the Yelp Business metrics are Number of Businesses, Total Reviews, and Avg. Star Rating. These were calculated for all businesses within .1 and .5 miles of each AirBnB listing, for 6 variables total.
#
# All three of the metrics for busineses within .1 mile had a very low correlation with both Price and Utilization. I will drop all three of the .1 mile metrics. However when doing a t-test comparing the Price of listings with at least one business within .1 mile and those that did not, there was a large and statistically significant price difference (same for those with/without businesses within .5 mile). So before dropping the .1 mile metrics I will create a flag variable that is True if the AirBnB listing has a business within .1 (and .5) miles.

# %%
#Create flag variable indicating if any business was within .1, .5 miles of an AirBnB listing
abb_Price_predict['Bus_in_pt_1'] = pd.notna(abb_Price_predict['yelp_bus_count_1'])
abb_Price_predict['Bus_in_pt_5'] = pd.notna(abb_Price_predict['yelp_bus_count_5'])

abb_Util_predict['Bus_in_pt_1'] = pd.notna(abb_Util_predict['yelp_bus_count_1'])
abb_Util_predict['Bus_in_pt_5'] = pd.notna(abb_Util_predict['yelp_bus_count_5'])

# %%
#Drop .1 mile Yelp Business variables
drop_cols = ['yelp_bus_count_1', 'yelp_bus_total_reviews_1', 'yelp_bus_avg_rating_1']

abb_Price_predict.drop(columns=drop_cols, axis=1, inplace=True)
abb_Util_predict.drop(columns=drop_cols, axis=1, inplace=True)

print(abb_Price_predict.shape)
print(abb_Util_predict.shape)
# Out:
# (16011, 51)
# (16011, 42)

# %% [markdown]
# The .5 mile Yelp Business metrics, specifically Number of Businesses and Total Reviews, did show both a practical correlation coefficient and statistical significance when compared to Price, so those variables will be kept in the Price prediction dataset. The Avg. Rating was not practically significant against Price, so it will be dropped.
#
# All three .5 mile Yelp Business metrics were not practically significant against Utilization Rate and will be dropped.

# %%
#Drop .5 mile Yelp Business variables from price prediction dataset
drop_cols = ['yelp_bus_avg_rating_5']

abb_Price_predict.drop(columns=drop_cols, axis=1, inplace=True)

print(abb_Price_predict.shape)
# Out:
# (16011, 50)

# %%
#Drop .5 mile Yelp Business variables from utilization prediction dataset
drop_cols = ['yelp_bus_count_5', 'yelp_bus_total_reviews_5', 'yelp_bus_avg_rating_5']

abb_Util_predict.drop(columns=drop_cols, axis=1, inplace=True)

print(abb_Util_predict.shape)
# Out:
# (16011, 39)

# %% [markdown]
# As a final step I will replace NaN values in the Yelp metrics with 0 to ensure the modeling algorithms do not drop those records.

# %%
abb_Price_predict[['yelp_bus_count_5', 'yelp_bus_total_reviews_5']] = abb_Price_predict[['yelp_bus_count_5', 'yelp_bus_total_reviews_5']].fillna(0.0)

# %% [markdown]
# ## Predicting Price
#
# ### Produce Baseline Price Prediction Model
# First I will create a simple baseline linear regression model predicting raw price (not log price) with all of the predictor variables. This will serve as my baseline model to compare future models against. I will use the ols function from the statsmodel package because it gives a nice, very readable output of the important metrics I need for comparison.

# %%
#Create formula components
X_cols = "+".join(abb_Price_predict.columns.difference(['id', 'price', 'Utilization_Rate', 'log_price']))
                  
formula = 'price~' + X_cols
formula_log = 'log_price~' + X_cols

# %%
#Fit baseline model
base_m = ols(formula, abb_Price_predict).fit()

print(base_m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                
0.000       0.001       0.002
# ==============================================================================
# Omnibus:                    10257.758   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           191212.515
# Skew:                           2.787   Prob(JB):                         0.00
# Kurtosis:                      18.986   Cond. No.                     4.22e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# My model has many input variables so I will use Adjusted R-Squared to evaluate the model. The baseline is decent at .493, indicating that around half of the variation in the outcome variable is explained by this model. However there are more variables than I would like (103), making the model difficult to interpret and explain to others, and the output report indicates there may be strong multicollinearity. Feature selection will need to be performed to fine-tune this model.

# %% [markdown]
# ### Fit Model on Log Price using Trimmed Variables
# First I will test running the model on the log of Price, to see if this improves anything.

# %%
#Fit baseline model on log price
base_m_log = ols(formula_log, abb_Price_predict).fit()

print(base_m_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.636
# Method:                 Least Squares   F-statistic:                     273.2
# Date:                Sun, 25 Nov 2018   Prob (F-statistic):               0.00
# Time:                        21:42:08   Log-Likelihood:                -7641.4
# No. Observations:               16011   AIC:                         1.549e+04
# Df Residuals:                   15907   BIC:                         1.629e+04
# Df Model:                         103
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              4.2522      0.075     56.994      0.000       4.106       4.398
# Bus_in_pt_1[T.True]                                    0.0168      0.008      1.991      0.047       0.000       0.033
# Bus_in_pt_5[T.True]                                    0.0184      0.011      1.658      0.097      -0.003       0.040
# bed_type[T.Couch]                                     -0.0190      0.094     -0.203      0.839      -0.202       0.164
# bed_type[T.Futon]                                     -0.0912      0.071     -1.278      0.201      -0.231       0.049
# bed_type[T.Pull-out Sofa]                             -0.0429      0.075     -0.573      0.567      -0.190       0.104
# bed_type[T.Real Bed]                                  -0.0312      0.063     -0.493      0.622      -0.155       0.093
# cancellation_policy[T.moderate]                       -0.0406      0.009     -4.598      0.000      -0.058      -0.023
# cancellation_policy[T.strict_14_with_grace_period]    -0.0225      0.009     -2.596      0.009      -0.039      -0.006
# cancellation_policy[T.super_strict_30]                 0.0927      0.086      1.073      0.283      -0.077       0.262
# cancellation_policy[T.super_strict_60]                 0.4805      0.227      2.118      0.034       0.036       0.925
# cleaning_fee_notNA[T.True]                            -0.1240      0.012    -10.451      0.000      -0.147      -0.101
# has_Air_conditioning[T.True]                           0.0288      0.011      2.645      0.008       0.007       0.050
# has_Breakfast[T.True]                                  0.0638      0.023      2.782      0.005       0.019       0.109
# has_Cable_TV[T.True]                                   0.0094      0.010      0.935      0.350      -0.010       0.029
# has_Dryer[T.True]                                      0.0104      0.045      0.231      0.818      -0.078       0.099
# has_Elevator[T.True]                                  -0.0149      0.017     -0.895      0.371      -0.048       0.018
# has_Essentials[T.True]                                -0.0618      0.047     -1.306      0.192      -0.155       0.031
# has_Free_parking_on_premises[T.True]                  -0.0395      0.022     -1.767      0.077      -0.083       0.004
# has_Free_street_parking[T.True]                       -0.0333      0.051     -0.658      0.510      -0.133       0.066
# has_Gym[T.True]                                        0.0050      0.015      0.346      0.729      -0.023       0.034
# has_Heating[T.True]                                   -0.0674      0.012     -5.753      0.000      -0.090      -0.044
# has_Internet[T.True]                                  -0.0282      0.009     -3.241      0.001      -0.045      -0.011
# has_Kitchen[T.True]                                   -0.0681      0.009     -7.862      0.000      -0.085      -0.051
# beds                                                  -0.0004      0.007     -0.052      0.959      -0.014       0.013
# cleaning_fee                                           0.0023      0.000     17.875      0.000       0.002       0.003
# extra_people                                        6.696e-06      0.000      0.027      0.978      -0.000       0.000
# guests_included                                        0.0040      0.005      0.848      0.397      -0.005       0.013
# host_response_rate                                     0.0004   9.61e-05      4.280      0.000       0.000       0.001
# minimum_nights                                        -0.0077      0.001    -13.058      0.000      -0.009      -0.007
# security_deposit                                       0.0002   1.73e-05      9.380      0.000       0.000       0.000
# yelp_bus_count_5                                      -0.0005      0.000     -2.668      0.008      -0.001      -0.000
# yelp_bus_total_reviews_5                            9.738e-06   2.15e-06      4.534      0.000    5.53e-06    1.39e-05
# ==============================================================================
# Omnibus:                     1311.662   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3967.506
# Skew:                           0.430   Prob(JB):                         0.00
# Kurtosis:                       5.282   Cond. No.                     4.22e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Using log price significantly improves the model, increasing the Adjusted R-Squared from 0.493 to 0.636, and showing a strong decrease in AIC and BIC. I will need to exponentiate the parameter coefficients before interpreting them to interpret them correctly, but for now I will continue to use log price in my models.

# %%
#Put baseline parameters into dataframe for later comparison
parameters = pd.DataFrame(base_m_log.params)
parameters.reset_index(level=0, inplace=True)
parameters.rename(columns={'index':'Parameter', 0:'Base_Model'}, inplace=True)
parameters
# Out:
#                                              Parameter  Base_Model
# 0                                            Intercept    4.252204
# 1                                  Bus_in_pt_1[T.True]    0.016758
# 2                                  Bus_in_pt_5[T.True]    0.018444
# 3                                    bed_type[T.Couch]   -0.018981
# 4                                    bed_type[T.Futon]   -0.091233
# 5                            bed_type[T.Pull-out Sofa]   -0.042890
# 6                                 bed_type[T.Real Bed]   -0.031161
# 7                      cancellation_policy[T.moderate]   -0.040567
# 8    cancellation_policy[T.strict_14_with_grace_per...   -0.022488
# 9               cancellation_policy[T.super_strict_30]    0.092653
# 10              cancellation_policy[T.super_strict_60]    0.480487
# 11                          cleaning_fee_notNA[T.True]   -0.124041
# 12                        has_Air_conditioning[T.True]    0.028812
# 13                               has_Breakfast[T.True]    0.063788
# 14                                has_Cable_TV[T.True]    0.009362
# 15                                   has_Dryer[T.True]    0.010439
# 16                                has_Elevator[T.True]   -0.014936
# 17                              has_Essentials[T.True]   -0.061824
# 18                has_Free_parking_on_premises[T.True]   -0.039548
# 19                     has_Free_street_parking[T.True]   -0.033332
# 20                                     has_Gym[T.True]    0.005032
# 21                                 has_Heating[T.True]   -0.067378
# 22                                has_Internet[T.True]   -0.028249
# 23                                 has_Kitchen[T.True]   -0.068056
# 24               has_Paid_parking_off_premises[T.True]   -0.046596
# 25                            has_Pets_allowed[T.True]   -0.059523
# 26              has_Pets_live_on_this_property[T.True]   -0.014299
# 27                                    has_Pool[T.True]    0.041126
# 28                          has_Smoke_detector[T.True]   -0.048303
# 29                         has_Smoking_allowed[T.True]   -0.044300
# 30                                      has_TV[T.True]    0.102975
# 31                                  has_Washer[T.True]   -0.033753
# 32                              host_is_superhost[T.t]   -0.032403
# 33                     host_lives_near_listing[T.True]   -0.041033
# 34                  host_response_time[T.within a day]   -0.060130
# 35            host_response_time[T.within a few hours]   -0.056125
# 36                host_response_time[T.within an hour]   -0.075839
# 37                               instant_bookable[T.t]   -0.021785
# 38                         neighborhood[T.Cabbagetown]    0.342225
# 39                           neighborhood[T.Casa Loma]    0.136070
# 40                            neighborhood[T.Corktown]    0.269891
# 41                          neighborhood[T.Davisville]    0.174107
# 42                           neighborhood[T.Deer Park]    0.185193
# 43                     neighborhood[T.Dovercourt Park]    0.090029
# 44                           neighborhood[T.Downsview]   -0.016084
# 45                       neighborhood[T.Downtown Core]    0.309197
# 46                      neighborhood[T.Dufferin Grove]    0.134718
# 47                           neighborhood[T.East York]   -0.010849
# 48              neighborhood[T.Entertainment District]    0.376626
# 49                           neighborhood[T.Etobicoke]    0.036312
# 50                           neighborhood[T.Greektown]    0.117747
# 51                     neighborhood[T.High Park North]    0.127301
# 52                       neighborhood[T.Hogg's Hollow]    0.113110
# 53                   neighborhood[T.Kensington Market]    0.345434
# 54                     neighborhood[T.Little Portugal]    0.230424
# 55                        neighborhood[T.Mount Dennis]    0.002090
# 56                         neighborhood[T.New Toronto]    0.005365
# 57                             neighborhood[T.Niagara]    0.334191
# 58             neighborhood[T.Palmerston/Little Italy]    0.204278
# 59                            neighborhood[T.Parkdale]    0.201114
# 60                             neighborhood[T.Rexdale]    0.072990
# 61                           neighborhood[T.Riverdale]    0.223329
# 62                        neighborhood[T.Roncesvalles]    0.179876
# 63                            neighborhood[T.Rosedale]    0.412106
# 64                      neighborhood[T.Saint Lawrence]    0.370667
# 65                         neighborhood[T.Scarborough]   -0.123618
# 66                          neighborhood[T.South Hill]    0.300684
# 67                             neighborhood[T.Swansea]    0.141712
# 68                           neighborhood[T.The Annex]    0.223432
# 69                         neighborhood[T.The Beaches]    0.181976
# 70                        neighborhood[T.The Danforth]    0.006315
# 71                        neighborhood[T.The Junction]    0.150474
# 72                   neighborhood[T.Trinity-Bellwoods]    0.328983
# 73                     neighborhood[T.Wallace Emerson]    0.086379
# 74                          neighborhood[T.Willowdale]    0.033055
# 75                            neighborhood[T.Wychwood]   -0.000146
# 76                      neighborhood[T.Yonge Eglinton]    0.263214
# 77                           neighborhood[T.Yorkville]    0.397344
# 78                  property_type[T.Bed and breakfast]    0.436336
# 79                           property_type[T.Bungalow]    0.027842
# 80                        property_type[T.Condominium]    0.075404
# 81                        property_type[T.Guest suite]   -0.022000
# 82                         property_type[T.Guesthouse]    0.041677
# 83                              property_type[T.House]    0.048100
# 84                               property_type[T.Loft]    0.191205
# 85                              property_type[T.Other]    0.193461
# 86                 property_type[T.Serviced apartment]    0.097815
# 87                          property_type[T.Townhouse]    0.055630
# 88                     reviews_per_month_notNA[T.True]   -0.160570
# 89                           room_type[T.Private room]   -0.427007
# 90                            room_type[T.Shared room]   -0.748769
# 91                      security_deposit_notNA[T.True]   -0.005711
# 92                                        accommodates    0.077254
# 93                                           bathrooms    0.088620
# 94                                            bedrooms    0.140140
# 95                                                beds   -0.000360
# 96                                        cleaning_fee    0.002266
# 97                                        extra_people    0.000007
# 98                                     guests_included    0.003962
# 99                                  host_response_rate    0.000411
# 100                                     minimum_nights   -0.007689
# 101                                   security_deposit    0.000162
# 102                                   yelp_bus_count_5   -0.000469
# 103                           yelp_bus_total_reviews_5    0.000010

# %% [markdown]
# ### Perform Feature Selection Procedures

# %% [markdown]
# #### Fit Ridge Regression Model

# %% [markdown]
# Next I will run Ridge regression on the dataset, but first I need to find the optimal value for Alpha. I will loop through values of alpha from 0 to 1, stepping by 0.05, and look for the alpha that only slightly decreases Adjusted R-Squared.

# %%
model = ols(formula_log, abb_Price_predict)

# %%
frames = []
for n in np.arange(0, 1, 0.05).tolist():
    results_fr = model.fit_regularized(L1_wt=0, alpha=n, start_params=base_m_log.params)
    results_fr_fit = sm.regression.linear_model.OLSResults(model, 
                                                        results_fr.params
                                                       )
    frames.append(np.append(n, results_fr_fit.rsquared_adj))

# %%
frames = pd.DataFrame(frames).rename(columns={0:'Alpha', 1:"Adj. R-Squared"})

# %%
fig=plt.figure(figsize=(10, 5), dpi=120)
sns.lineplot(x='Alpha', y='Adj. R-Squared', data=frames,
            markers=True, dashes=True)
plt.title("Adj. R-Squared vs. Alpha")
plt.show()

# %% [markdown]
# The line decreases fairly steadily but there is a slight "elbow" at alpha = 0.05, so I will choose that as my alpha for Ridge Regression.

# %%
base_m_Ridge = ols(formula_log, abb_Price_predict).fit_regularized(alpha=0.05, L1_wt=0)

# %%
ridge_params = pd.DataFrame(base_m_Ridge.params)

# %%
parameters = parameters.join(ridge_params)

# %%
parameters.rename(columns={0:'Ridge Model'}, inplace=True)
parameters
# Out:
#                                              Parameter  Base_Model  \
# 0                                            Intercept    4.252204
# 1                                  Bus_in_pt_1[T.True]    0.016758
# 2                                  Bus_in_pt_5[T.True]    0.018444
# 3                                    bed_type[T.Couch]   -0.018981
# 4                                    bed_type[T.Futon]   -0.091233
# 5                            bed_type[T.Pull-out Sofa]   -0.042890
# 6                                 bed_type[T.Real Bed]   -0.031161
# 7                      cancellation_policy[T.moderate]   -0.040567
# 8    cancellation_policy[T.strict_14_with_grace_per...   -0.022488
# 9               cancellation_policy[T.super_strict_30]    0.092653
# 10              cancellation_policy[T.super_strict_60]    0.480487
# 11                          cleaning_fee_notNA[T.True]   -0.124041
# 12                        has_Air_conditioning[T.True]    0.028812
# 13                               has_Breakfast[T.True]    0.063788
# 14                                has_Cable_TV[T.True]    0.009362
# 15                                   has_Dryer[T.True]    0.010439
# 16                                has_Elevator[T.True]   -0.014936
# 17                              has_Essentials[T.True]   -0.061824
# 18                has_Free_parking_on_premises[T.True]   -0.039548
# 19                     has_Free_street_parking[T.True]   -0.033332
# 20                                     has_Gym[T.True]    0.005032
# 21                                 has_Heating[T.True]   -0.067378
# 22                                has_Internet[T.True]   -0.028249
# 23                                 has_Kitchen[T.True]   -0.068056
# 24               has_Paid_parking_off_premises[T.True]   -0.046596
# 25                            has_Pets_allowed[T.True]   -0.059523
# 26              has_Pets_live_on_this_property[T.True]   -0.014299
# 27                                    has_Pool[T.True]    0.041126
# 28                          has_Smoke_detector[T.True]   -0.048303
# 29                         has_Smoking_allowed[T.True]   -0.044300
# 30                                      has_TV[T.True]    0.102975
# 31                                  has_Washer[T.True]   -0.033753
# 32                              host_is_superhost[T.t]   -0.032403
# 33                     host_lives_near_listing[T.True]   -0.041033
# 34                  host_response_time[T.within a day]   -0.060130
# 35            host_response_time[T.within a few hours]   -0.056125
# 36                host_response_time[T.within an hour]   -0.075839
# 37                               instant_bookable[T.t]   -0.021785
# 38                         neighborhood[T.Cabbagetown]    0.342225
# 39                           neighborhood[T.Casa Loma]    0.136070
# 40                            neighborhood[T.Corktown]    0.269891
# 41                          neighborhood[T.Davisville]    0.174107
# 42                           neighborhood[T.Deer Park]    0.185193
# 43                     neighborhood[T.Dovercourt Park]    0.090029
# 44                           neighborhood[T.Downsview]   -0.016084
# 45                       neighborhood[T.Downtown Core]    0.309197
# 46                      neighborhood[T.Dufferin Grove]    0.134718
# 47                           neighborhood[T.East York]   -0.010849
# 48              neighborhood[T.Entertainment District]    0.376626
# 49                           neighborhood[T.Etobicoke]    0.036312
# 50                           neighborhood[T.Greektown]    0.117747
# 51                     neighborhood[T.High Park North]    0.127301
# 52                       neighborhood[T.Hogg's Hollow]    0.113110
# 53                   neighborhood[T.Kensington Market]    0.345434
# 54                     neighborhood[T.Little Portugal]    0.230424
# 55                        neighborhood[T.Mount Dennis]    0.002090
# 56                         neighborhood[T.New Toronto]    0.005365
# 57                             neighborhood[T.Niagara]    0.334191
# 58             neighborhood[T.Palmerston/Little Italy]    0.204278
# 59                            neighborhood[T.Parkdale]    0.201114
# 60                             neighborhood[T.Rexdale]    0.072990
# 61                           neighborhood[T.Riverdale]    0.223329
# 62                        neighborhood[T.Roncesvalles]    0.179876
# 63                            neighborhood[T.Rosedale]    0.412106
# 64                      neighborhood[T.Saint Lawrence]    0.370667
# 65                         neighborhood[T.Scarborough]   -0.123618
# 66                          neighborhood[T.South Hill]    0.300684
# 67                             neighborhood[T.Swansea]    0.141712
# 68                           neighborhood[T.The Annex]    0.223432
# 69                         neighborhood[T.The Beaches]    0.181976
# 70                        neighborhood[T.The Danforth]    0.006315
# 71                        neighborhood[T.The Junction]    0.150474
# 72                   neighborhood[T.Trinity-Bellwoods]    0.328983
# 73                     neighborhood[T.Wallace Emerson]    0.086379
# 74                          neighborhood[T.Willowdale]    0.033055
# 75                            neighborhood[T.Wychwood]   -0.000146
# 76                      neighborhood[T.Yonge Eglinton]    0.263214
# 77                           neighborhood[T.Yorkville]    0.397344
# 78                  property_type[T.Bed and breakfast]    0.436336
# 79                           property_type[T.Bungalow]    0.027842
# 80                        property_type[T.Condominium]    0.075404
# 81                        property_type[T.Guest suite]   -0.022000
# 82                         property_type[T.Guesthouse]    0.041677
# 83                              property_type[T.House]    0.048100
# 84                               property_type[T.Loft]    0.191205
# 85                              property_type[T.Other]    0.193461
# 86                 property_type[T.Serviced apartment]    0.097815
# 87                          property_type[T.Townhouse]    0.055630
# 88                     reviews_per_month_notNA[T.True]   -0.160570
# 89                           room_type[T.Private room]   -0.427007
# 90                            room_type[T.Shared room]   -0.748769
# 91                      security_deposit_notNA[T.True]   -0.005711
# 92                                        accommodates    0.077254
# 93                                           bathrooms    0.088620
# 94                                            bedrooms    0.140140
# 95                                                beds   -0.000360
# 96                                        cleaning_fee    0.002266
# 97                                        extra_people    0.000007
# 98                                     guests_included    0.003962
# 99                                  host_response_rate    0.000411
# 100                                     minimum_nights   -0.007689
# 101                                   security_deposit    0.000162
# 102                                   yelp_bus_count_5   -0.000469
# 103                           yelp_bus_total_reviews_5    0.000010
#
#      Ridge Model
# 0       1.028971
# 1       0.075204
# 2       0.353676
# 3       0.030582
# 4       0.111692
# 5       0.081673
# 6       0.761177
# 7       0.011588
# 8       0.009417
# 9       0.005576
# 10      0.002307
# 11      0.044933
# 12      0.208844
# 13      0.066879
# 14      0.138259
# 15      0.032180
# 16      0.075123
# 17      0.014716
# 18      0.096261
# 19      0.014213
# 20      0.048729
# 21      0.081792
# 22      0.166175
# 23      0.172044
# 24      0.052943
# 25      0.042014
# 26      0.026252
# 27      0.068033
# 28      0.049258
# 29      0.025244
# 30      0.255943
# 31      0.050924
# 32     -0.066804
# 33      0.140507
# 34      0.242871
# 35      0.257988
# 36      0.351816
# 37     -0.010620
# 38      0.042071
# 39      0.003947
# 40      0.010565
# 41      0.044404
# 42      0.015195
# 43      0.001982
# 44      0.008232
# 45      0.100051
# 46      0.036234
# 47     -0.018117
# 48      0.104501
# 49      0.008417
# 50      0.030721
# 51      0.040692
# 52      0.005856
# 53      0.012644
# 54      0.030383
# 55      0.002192
# 56     -0.001140
# 57      0.119690
# 58      0.020924
# 59      0.039752
# 60      0.003077
# 61      0.074746
# 62      0.048006
# 63      0.042786
# 64      0.025964
# 65     -0.080980
# 66      0.012701
# 67      0.007655
# 68      0.051752
# 69      0.043489
# 70      0.009919
# 71     -0.002443
# 72      0.093050
# 73      0.009148
# 74     -0.011931
# 75     -0.031107
# 76      0.049807
# 77      0.052003
# 78      0.045880
# 79     -0.009428
# 80      0.101464
# 81      0.027707
# 82     -0.014436
# 83      0.004557
# 84      0.104158
# 85      0.049697
# 86      0.012828
# 87     -0.018730
# 88      0.037048
# 89     -0.070311
# 90     -0.050376
# 91      0.013724
# 92      0.141845
# 93      0.346756
# 94      0.112280
# 95      0.025387
# 96      0.001412
# 97     -0.001293
# 98      0.053101
# 99      0.001626
# 100     0.005695
# 101     0.000120
# 102     0.000426
# 103     0.000010

# %% [markdown]
# #### Fit LASSO Model

# %% [markdown]
# Ridge Regression shrinks the parameters but does not help with telling me what parameters I can safely remove. I would like to reduce the number of predictor variables I am feeding into the model to reduce complexity. To reach that goal I will try LASSO next, because I know it can shrink many predictors to 0.
#
# Again I will iterate through different values of alpha and choose the one that reduces complexity while not impacting Adjusted R-Squared too significantly.

# %%
frames = []
for n in np.arange(0, 1, 0.05).tolist():
    results_fr = model.fit_regularized(L1_wt=1, alpha=n, start_params=base_m_log.params)
    results_fr_fit = sm.regression.linear_model.OLSResults(model, 
                                                        results_fr.params
                                                       )
    frames.append(np.append(n, results_fr_fit.rsquared_adj))

# %%
frames = pd.DataFrame(frames).rename(columns={0:'Alpha', 1:"Adj. R-Squared"})

# %%
fig=plt.figure(figsize=(10, 5), dpi=120)
sns.lineplot(x='Alpha', y='Adj. R-Squared', data=frames,
            markers=True, dashes=True)
plt.title("Adj. R-Squared vs. Alpha")
plt.show()

# %% [markdown]
# I cannot use too high a value for alpha, because anything above 0 rapidly drops into negative values for adjusted r-squared. I will stick with alpha = 0.01. As shown below, it significantly decreases complexity (from 104 to 18 variables, including the intercept) without dropping adjusted r-squared too steeply.

# %%
base_m_Lasso = ols(formula_log, abb_Price_predict).fit_regularized(alpha=0.01, L1_wt=1)

# %%
print("Variable Count: " + str(len(base_m_Lasso.params[base_m_Lasso.params != 0].sort_values(ascending=False))))
print(base_m_Lasso.params[base_m_Lasso.params != 0].sort_values(ascending=False))
lasso_vars = base_m_Lasso.params[base_m_Lasso.params != 0]
# Out:
# Variable Count: 18
# Intercept                                 3.816356
# has_TV[T.True]                            0.152590
# accommodates                              0.130215
# bedrooms                                  0.121478
# property_type[T.Condominium]              0.086231
# Bus_in_pt_5[T.True]                       0.060622
# Bus_in_pt_1[T.True]                       0.031806
# has_Air_conditioning[T.True]              0.022476
# neighborhood[T.Entertainment District]    0.016847
# cleaning_fee                              0.002482
# yelp_bus_count_5                          0.000662
# security_deposit                          0.000196
# yelp_bus_total_reviews_5                  0.000011
# host_response_rate                       -0.000093
# minimum_nights                           -0.001939
# reviews_per_month_notNA[T.True]          -0.048320
# neighborhood[T.Scarborough]              -0.099888
# room_type[T.Private room]                -0.260193
# dtype: float64

# %%
lasso_params = pd.DataFrame(base_m_Lasso.params)
lasso_params.reset_index(inplace=True)
lasso_params
# Out:
#                                                  index         0
# 0                                            Intercept  3.816356
# 1                                  Bus_in_pt_1[T.True]  0.031806
# 2                                  Bus_in_pt_5[T.True]  0.060622
# 3                                    bed_type[T.Couch]  0.000000
# 4                                    bed_type[T.Futon]  0.000000
# 5                            bed_type[T.Pull-out Sofa]  0.000000
# 6                                 bed_type[T.Real Bed]  0.000000
# 7                      cancellation_policy[T.moderate]  0.000000
# 8    cancellation_policy[T.strict_14_with_grace_per...  0.000000
# 9               cancellation_policy[T.super_strict_30]  0.000000
# 10              cancellation_policy[T.super_strict_60]  0.000000
# 11                          cleaning_fee_notNA[T.True]  0.000000
# 12                        has_Air_conditioning[T.True]  0.022476
# 13                               has_Breakfast[T.True]  0.000000
# 14                                has_Cable_TV[T.True]  0.000000
# 15                                   has_Dryer[T.True]  0.000000
# 16                                has_Elevator[T.True]  0.000000
# 17                              has_Essentials[T.True]  0.000000
# 18                has_Free_parking_on_premises[T.True]  0.000000
# 19                     has_Free_street_parking[T.True]  0.000000
# 20                                     has_Gym[T.True]  0.000000
# 21                                 has_Heating[T.True]  0.000000
# 22                                has_Internet[T.True]  0.000000
# 23                                 has_Kitchen[T.True]  0.000000
# 24               has_Paid_parking_off_premises[T.True]  0.000000
# 25                            has_Pets_allowed[T.True]  0.000000
# 26              has_Pets_live_on_this_property[T.True]  0.000000
# 27                                    has_Pool[T.True]  0.000000
# 28                          has_Smoke_detector[T.True]  0.000000
# 29                         has_Smoking_allowed[T.True]  0.000000
# 30                                      has_TV[T.True]  0.152590
# 31                                  has_Washer[T.True]  0.000000
# 32                              host_is_superhost[T.t]  0.000000
# 33                     host_lives_near_listing[T.True]  0.000000
# 34                  host_response_time[T.within a day]  0.000000
# 35            host_response_time[T.within a few hours]  0.000000
# 36                host_response_time[T.within an hour]  0.000000
# 37                               instant_bookable[T.t]  0.000000
# 38                         neighborhood[T.Cabbagetown]  0.000000
# 39                           neighborhood[T.Casa Loma]  0.000000
# 40                            neighborhood[T.Corktown]  0.000000
# 41                          neighborhood[T.Davisville]  0.000000
# 42                           neighborhood[T.Deer Park]  0.000000
# 43                     neighborhood[T.Dovercourt Park]  0.000000
# 44                           neighborhood[T.Downsview]  0.000000
# 45                       neighborhood[T.Downtown Core]  0.000000
# 46                      neighborhood[T.Dufferin Grove]  0.000000
# 47                           neighborhood[T.East York]  0.000000
# 48              neighborhood[T.Entertainment District]  0.016847
# 49                           neighborhood[T.Etobicoke]  0.000000
# 50                           neighborhood[T.Greektown]  0.000000
# 51                     neighborhood[T.High Park North]  0.000000
# 52                       neighborhood[T.Hogg's Hollow]  0.000000
# 53                   neighborhood[T.Kensington Market]  0.000000
# 54                     neighborhood[T.Little Portugal]  0.000000
# 55                        neighborhood[T.Mount Dennis]  0.000000
# 56                         neighborhood[T.New Toronto]  0.000000
# 57                             neighborhood[T.Niagara]  0.000000
# 58             neighborhood[T.Palmerston/Little Italy]  0.000000
# 59                            neighborhood[T.Parkdale]  0.000000
# 60                             neighborhood[T.Rexdale]  0.000000
# 61                           neighborhood[T.Riverdale]  0.000000
# 62                        neighborhood[T.Roncesvalles]  0.000000
# 63                            neighborhood[T.Rosedale]  0.000000
# 64                      neighborhood[T.Saint Lawrence]  0.000000
# 65                         neighborhood[T.Scarborough] -0.099888
# 66                          neighborhood[T.South Hill]  0.000000
# 67                             neighborhood[T.Swansea]  0.000000
# 68                           neighborhood[T.The Annex]  0.000000
# 69                         neighborhood[T.The Beaches]  0.000000
# 70                        neighborhood[T.The Danforth]  0.000000
# 71                        neighborhood[T.The Junction]  0.000000
# 72                   neighborhood[T.Trinity-Bellwoods]  0.000000
# 73                     neighborhood[T.Wallace Emerson]  0.000000
# 74                          neighborhood[T.Willowdale]  0.000000
# 75                            neighborhood[T.Wychwood]  0.000000
# 76                      neighborhood[T.Yonge Eglinton]  0.000000
# 77                           neighborhood[T.Yorkville]  0.000000
# 78                  property_type[T.Bed and breakfast]  0.000000
# 79                           property_type[T.Bungalow]  0.000000
# 80                        property_type[T.Condominium]  0.086231
# 81                        property_type[T.Guest suite]  0.000000
# 82                         property_type[T.Guesthouse]  0.000000
# 83                              property_type[T.House]  0.000000
# 84                               property_type[T.Loft]  0.000000
# 85                              property_type[T.Other]  0.000000
# 86                 property_type[T.Serviced apartment]  0.000000
# 87                          property_type[T.Townhouse]  0.000000
# 88                     reviews_per_month_notNA[T.True] -0.048320
# 89                           room_type[T.Private room] -0.260193
# 90                            room_type[T.Shared room]  0.000000
# 91                      security_deposit_notNA[T.True]  0.000000
# 92                                        accommodates  0.130215
# 93                                           bathrooms  0.000000
# 94                                            bedrooms  0.121478
# 95                                                beds  0.000000
# 96                                        cleaning_fee  0.002482
# 97                                        extra_people  0.000000
# 98                                     guests_included  0.000000
# 99                                  host_response_rate -0.000093
# 100                                     minimum_nights -0.001939
# 101                                   security_deposit  0.000196
# 102                                   yelp_bus_count_5  0.000662
# 103                           yelp_bus_total_reviews_5  0.000011

# %%
parameters = parameters.merge(lasso_params, left_on='Parameter', right_on='index')
parameters.rename(columns={0:'Lasso Model'}, inplace=True)
parameters.drop(columns='index', inplace=True)
parameters
# Out:
#                                              Parameter  Base_Model  \
# 0                                            Intercept    4.252204
# 1                                  Bus_in_pt_1[T.True]    0.016758
# 2                                  Bus_in_pt_5[T.True]    0.018444
# 3                                    bed_type[T.Couch]   -0.018981
# 4                                    bed_type[T.Futon]   -0.091233
# 5                            bed_type[T.Pull-out Sofa]   -0.042890
# 6                                 bed_type[T.Real Bed]   -0.031161
# 7                      cancellation_policy[T.moderate]   -0.040567
# 8    cancellation_policy[T.strict_14_with_grace_per...   -0.022488
# 9               cancellation_policy[T.super_strict_30]    0.092653
# 10              cancellation_policy[T.super_strict_60]    0.480487
# 11                          cleaning_fee_notNA[T.True]   -0.124041
# 12                        has_Air_conditioning[T.True]    0.028812
# 13                               has_Breakfast[T.True]    0.063788
# 14                                has_Cable_TV[T.True]    0.009362
# 15                                   has_Dryer[T.True]    0.010439
# 16                                has_Elevator[T.True]   -0.014936
# 17                              has_Essentials[T.True]   -0.061824
# 18                has_Free_parking_on_premises[T.True]   -0.039548
# 19                     has_Free_street_parking[T.True]   -0.033332
# 20                                     has_Gym[T.True]    0.005032
# 21                                 has_Heating[T.True]   -0.067378
# 22                                has_Internet[T.True]   -0.028249
# 23                                 has_Kitchen[T.True]   -0.068056
# 24               has_Paid_parking_off_premises[T.True]   -0.046596
# 25                            has_Pets_allowed[T.True]   -0.059523
# 26              has_Pets_live_on_this_property[T.True]   -0.014299
# 27                                    has_Pool[T.True]    0.041126
# 28                          has_Smoke_detector[T.True]   -0.048303
# 29                         has_Smoking_allowed[T.True]   -0.044300
# 30                                      has_TV[T.True]    0.102975
# 31                                  has_Washer[T.True]   -0.033753
# 32                              host_is_superhost[T.t]   -0.032403
# 33                     host_lives_near_listing[T.True]   -0.041033
# 34                  host_response_time[T.within a day]   -0.060130
# 35            host_response_time[T.within a few hours]   -0.056125
# 36                host_response_time[T.within an hour]   -0.075839
# 37                               instant_bookable[T.t]   -0.021785
# 38                         neighborhood[T.Cabbagetown]    0.342225
# 39                           neighborhood[T.Casa Loma]    0.136070
# 40                            neighborhood[T.Corktown]    0.269891
# 41                          neighborhood[T.Davisville]    0.174107
# 42                           neighborhood[T.Deer Park]    0.185193
# 43                     neighborhood[T.Dovercourt Park]    0.090029
# 44                           neighborhood[T.Downsview]   -0.016084
# 45                       neighborhood[T.Downtown Core]    0.309197
# 46                      neighborhood[T.Dufferin Grove]    0.134718
# 47                           neighborhood[T.East York]   -0.010849
# 48              neighborhood[T.Entertainment District]    0.376626
# 49                           neighborhood[T.Etobicoke]    0.036312
# 50                           neighborhood[T.Greektown]    0.117747
# 51                     neighborhood[T.High Park North]    0.127301
# 52                       neighborhood[T.Hogg's Hollow]    0.113110
# 53                   neighborhood[T.Kensington Market]    0.345434
# 54                     neighborhood[T.Little Portugal]    0.230424
# 55                        neighborhood[T.Mount Dennis]    0.002090
# 56                         neighborhood[T.New Toronto]    0.005365
# 57                             neighborhood[T.Niagara]    0.334191
# 58             neighborhood[T.Palmerston/Little Italy]    0.204278
# 59                            neighborhood[T.Parkdale]    0.201114
# 60                             neighborhood[T.Rexdale]    0.072990
# 61                           neighborhood[T.Riverdale]    0.223329
# 62                        neighborhood[T.Roncesvalles]    0.179876
# 63                            neighborhood[T.Rosedale]    0.412106
# 64                      neighborhood[T.Saint Lawrence]    0.370667
# 65                         neighborhood[T.Scarborough]   -0.123618
# 66                          neighborhood[T.South Hill]    0.300684
# 67                             neighborhood[T.Swansea]    0.141712
# 68                           neighborhood[T.The Annex]    0.223432
# 69                         neighborhood[T.The Beaches]    0.181976
# 70                        neighborhood[T.The Danforth]    0.006315
# 71                        neighborhood[T.The Junction]    0.150474
# 72                   neighborhood[T.Trinity-Bellwoods]    0.328983
# 73                     neighborhood[T.Wallace Emerson]    0.086379
# 74                          neighborhood[T.Willowdale]    0.033055
# 75                            neighborhood[T.Wychwood]   -0.000146
# 76                      neighborhood[T.Yonge Eglinton]    0.263214
# 77                           neighborhood[T.Yorkville]    0.397344
# 78                  property_type[T.Bed and breakfast]    0.436336
# 79                           property_type[T.Bungalow]    0.027842
# 80                        property_type[T.Condominium]    0.075404
# 81                        property_type[T.Guest suite]   -0.022000
# 82                         property_type[T.Guesthouse]    0.041677
# 83                              property_type[T.House]    0.048100
# 84                               property_type[T.Loft]    0.191205
# 85                              property_type[T.Other]    0.193461
# 86                 property_type[T.Serviced apartment]    0.097815
# 87                          property_type[T.Townhouse]    0.055630
# 88                     reviews_per_month_notNA[T.True]   -0.160570
# 89                           room_type[T.Private room]   -0.427007
# 90                            room_type[T.Shared room]   -0.748769
# 91                      security_deposit_notNA[T.True]   -0.005711
# 92                                        accommodates    0.077254
# 93                                           bathrooms    0.088620
# 94                                            bedrooms    0.140140
# 95                                                beds   -0.000360
# 96                                        cleaning_fee    0.002266
# 97                                        extra_people    0.000007
# 98                                     guests_included    0.003962
# 99                                  host_response_rate    0.000411
# 100                                     minimum_nights   -0.007689
# 101                                   security_deposit    0.000162
# 102                                   yelp_bus_count_5   -0.000469
# 103                           yelp_bus_total_reviews_5    0.000010
#
#      Ridge Model  Lasso Model
# 0       1.028971     3.816356
# 1       0.075204     0.031806
# 2       0.353676     0.060622
# 3       0.030582     0.000000
# 4       0.111692     0.000000
# 5       0.081673     0.000000
# 6       0.761177     0.000000
# 7       0.011588     0.000000
# 8       0.009417     0.000000
# 9       0.005576     0.000000
# 10      0.002307     0.000000
# 11      0.044933     0.000000
# 12      0.208844     0.022476
# 13      0.066879     0.000000
# 14      0.138259     0.000000
# 15      0.032180     0.000000
# 16      0.075123     0.000000
# 17      0.014716     0.000000
# 18      0.096261     0.000000
# 19      0.014213     0.000000
# 20      0.048729     0.000000
# 21      0.081792     0.000000
# 22      0.166175     0.000000
# 23      0.172044     0.000000
# 24      0.052943     0.000000
# 25      0.042014     0.000000
# 26      0.026252     0.000000
# 27      0.068033     0.000000
# 28      0.049258     0.000000
# 29      0.025244     0.000000
# 30      0.255943     0.152590
# 31      0.050924     0.000000
# 32     -0.066804     0.000000
# 33      0.140507     0.000000
# 34      0.242871     0.000000
# 35      0.257988     0.000000
# 36      0.351816     0.000000
# 37     -0.010620     0.000000
# 38      0.042071     0.000000
# 39      0.003947     0.000000
# 40      0.010565     0.000000
# 41      0.044404     0.000000
# 42      0.015195     0.000000
# 43      0.001982     0.000000
# 44      0.008232     0.000000
# 45      0.100051     0.000000
# 46      0.036234     0.000000
# 47     -0.018117     0.000000
# 48      0.104501     0.016847
# 49      0.008417     0.000000
# 50      0.030721     0.000000
# 51      0.040692     0.000000
# 52      0.005856     0.000000
# 53      0.012644     0.000000
# 54      0.030383     0.000000
# 55      0.002192     0.000000
# 56     -0.001140     0.000000
# 57      0.119690     0.000000
# 58      0.020924     0.000000
# 59      0.039752     0.000000
# 60      0.003077     0.000000
# 61      0.074746     0.000000
# 62      0.048006     0.000000
# 63      0.042786     0.000000
# 64      0.025964     0.000000
# 65     -0.080980    -0.099888
# 66      0.012701     0.000000
# 67      0.007655     0.000000
# 68      0.051752     0.000000
# 69      0.043489     0.000000
# 70      0.009919     0.000000
# 71     -0.002443     0.000000
# 72      0.093050     0.000000
# 73      0.009148     0.000000
# 74     -0.011931     0.000000
# 75     -0.031107     0.000000
# 76      0.049807     0.000000
# 77      0.052003     0.000000
# 78      0.045880     0.000000
# 79     -0.009428     0.000000
# 80      0.101464     0.086231
# 81      0.027707     0.000000
# 82     -0.014436     0.000000
# 83      0.004557     0.000000
# 84      0.104158     0.000000
# 85      0.049697     0.000000
# 86      0.012828     0.000000
# 87     -0.018730     0.000000
# 88      0.037048    -0.048320
# 89     -0.070311    -0.260193
# 90     -0.050376     0.000000
# 91      0.013724     0.000000
# 92      0.141845     0.130215
# 93      0.346756     0.000000
# 94      0.112280     0.121478
# 95      0.025387     0.000000
# 96      0.001412     0.002482
# 97     -0.001293     0.000000
# 98      0.053101     0.000000
# 99      0.001626    -0.000093
# 100     0.005695    -0.001939
# 101     0.000120     0.000196
# 102     0.000426     0.000662
# 103     0.000010     0.000011

# %% [markdown]
# #### Fit Random Forest to view Feature Importance
#
# Next I plan to use Random Forest as another means of reducing the number of variables. I will start from all variables and use a Feature Importance plot to see which variables I should keep in the model. First I will need to convert all categorical variables into numeric flag variables, which I will do with Pandas get_dummies method. Statsmodels ols function is nice enough to do this automatically so I did not need to do it previously, but Sci-Kit Learn requires encoding ahead of time.
#
# I will also take this opportunity to use MinMaxScaler from Scikit-Learn to scale my numeric variables. I will use MinMax instead of Standard scaler because I know most of my numeric variables do not follow a normal distribution, and are in fact skewed right (long tail to the right).

# %%
abb_Price_predict.describe()
# Out:
#                  id  host_response_rate  accommodates     bathrooms  \
# count  1.601100e+04        16011.000000  16011.000000  16011.000000
# mean   1.670303e+07           74.092312      2.899319      1.178471
# std    7.574945e+06           41.314960      1.473007      0.363056
# min    1.419000e+03            0.000000      1.000000      1.000000
# 25%    1.107974e+07           60.000000      2.000000      1.000000
# 50%    1.830460e+07          100.000000      2.000000      1.000000
# 75%    2.286551e+07          100.000000      4.000000      1.000000
# max    2.758201e+07          100.000000      6.000000      2.000000
#
#            bedrooms          beds         price  security_deposit  \
# count  16011.000000  16011.000000  16011.000000      16011.000000
# mean       1.241459      1.586597    127.658110        205.841234
# std        0.690460      0.851228     94.572311        238.620780
# min        0.000000      1.000000     13.000000          0.000000
# 25%        1.000000      1.000000     65.000000          0.000000
# 50%        1.000000      1.000000    100.000000        150.000000
# 75%        1.000000      2.000000    159.000000        300.000000
# max        3.000000      4.000000    850.000000       1301.000000
#
#        cleaning_fee  guests_included  extra_people  minimum_nights  \
# count  16011.000000     16011.000000  16011.000000    16011.000000
# mean      42.917619         1.537193     12.133970        3.718444
# std       38.071328         0.905138     15.280283        5.600118
# min        0.000000         1.000000      0.000000        1.000000
# 25%       10.000000         1.000000      0.000000        1.000000
# 50%       39.000000         1.000000      0.000000        2.000000
# 75%       65.000000         2.000000     20.000000        3.000000
# max      170.000000         4.000000     50.000000       25.000000
#
#        yelp_bus_count_5  yelp_bus_total_reviews_5     log_price  \
# count      16011.000000              16011.000000  16011.000000
# mean          49.152832               3173.990007      4.634486
# std           61.456503               4792.052397      0.648911
# min            0.000000                  0.000000      2.564949
# 25%            5.000000                 83.000000      4.174387
# 50%           22.000000                808.000000      4.605170
# 75%           76.000000               4189.000000      5.068904
# max          362.000000              24010.000000      6.745236
#
#        Utilization_Rate
# count      16011.000000
# mean           0.094525
# std            0.142821
# min            0.000837
# 25%            0.011348
# 50%            0.037756
# 75%            0.117544
# max            1.000000

# %%
### ASK MENTOR ABOUT THIS - HOW TO USE WHEN IT CONVERTS TO NUMPY ARRAY (WITHOUT LOSING CATEGORICALS?)
### RERUN RANDOM FOREST TEST AND RFECV AFTER PROPERLY SCALING NUMERIC VARIABLES

#Assign numeric variables to scale
num_cols = abb_Price_predict[['host_response_rate', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'security_deposit',
                             'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'yelp_bus_count_5',
                             'yelp_bus_total_reviews_5']].columns

#Initialize MinMaxScaler
scaler = MinMaxScaler()

abb_Price_predict_scaled = scaler.fit_transform(abb_Price_predict[num_cols])
#abb_Price_predict_scaled = scaler.fit_transform(abb_Price_predict)
#abb_Price_predict_scaled.head()

# %%
#Perform get_dummies to one-hot encode categorical variables
cat_cols = abb_Price_predict[['host_response_time', 'neighborhood', 'host_is_superhost', 'room_type', 'bed_type',
                            'instant_bookable', 'cancellation_policy', 'property_type']].columns

abb_Price_predict_expanded = pd.get_dummies(abb_Price_predict, sparse=True, columns=cat_cols)

#Confirm only numeric variables remain
abb_Price_predict_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16011 entries, 0 to 16010
# Columns: 115 entries, id to property_type_Townhouse
# dtypes: bool(26), float64(15), int64(1), uint8(73)
# memory usage: 2.5 MB

# %%
#Create X and y
X_vars = abb_Price_predict_expanded.columns.difference(['id', 'price', 'Utilization_Rate', 'log_price'])
X = abb_Price_predict_expanded[X_vars]
y = abb_Price_predict_expanded['log_price']

# %%
#Initialize random forest regressor
rfc = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=17)

# %%
#Fit random forest
rfc.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=17, verbose=0, warm_start=False)

# %%
features = list(X_vars)
importances = rfc.feature_importances_
indices = np.argsort(importances)

# %%
fig=plt.figure(figsize=(10, 25), dpi=120)
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
features_df = pd.DataFrame(features)
features_df.rename(columns={0:'Parameter'}, inplace=True)

# %%
importances_df = pd.DataFrame(importances)
importances_df.rename(columns={0:'RF_Imp'}, inplace=True)

# %%
rf_vars = features_df.join(importances_df)

# %%
rf_vars = rf_vars[rf_vars['RF_Imp'] > 0.01]
rf_vars
# Out:
#                      Parameter    RF_Imp
# 2                 accommodates  0.042142
# 3                    bathrooms  0.078698
# 9                     bedrooms  0.017373
# 16                cleaning_fee  0.062650
# 18                extra_people  0.024589
# 43          host_response_rate  0.012818
# 50              minimum_nights  0.020931
# 95   property_type_Condominium  0.012987
# 103    reviews_per_month_notNA  0.010852
# 104  room_type_Entire home/apt  0.380659
# 107           security_deposit  0.023994
# 109           yelp_bus_count_5  0.033729
# 110   yelp_bus_total_reviews_5  0.060728

# %% [markdown]
# Setting the threshold at 0.01 importance score gives 13 variables identified as "important" by the random forest model.

# %% [markdown]
# ### Use Recursive Feature Elimination to determine relevant variables

# %% [markdown]
# I will use one more method to determine the best features to use in the model: Recursive Feature Elimination using scikit-learn's RFECV function.

# %%
ols = linear_model.LinearRegression()
rfecv = RFECV(estimator=ols, step=1, scoring='neg_mean_squared_error')

# %%
rfecv.fit(X, y)
# Out:
# RFECV(cv=None,
#    estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#    n_jobs=1, scoring='neg_mean_squared_error', step=1, verbose=0)

# %%
rfecv.n_features_
# Out:
# 111

# %% [markdown]
# ### Test each subset of variables using Ridge Regression and Cross Validation
#
# Now that I have created subsets of relevant variables using Lasso, Random Forest, and Recursive Feature Elimination, it is time to test these subsets in an actual model.

# %%
#Create train-test split
X_train, X_test, y_train,  y_test = train_test_split(X, y, 
                                                     test_size = 0.3, 
                                                     random_state=17)

# %%
#Initialize Model Parameters, Ridge Model, and GridSearchCV
param_grid = {'alpha':np.arange(0, 1, 0.05)}
ridge_model = linear_model.Ridge(random_state=17)
ridge_cv = GridSearchCV(ridge_model, param_grid, cv=10, scoring='neg_mean_squared_error')

# %%
#Fit ridge with all predictors
ridge_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=17, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'alpha': array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
#Extract scoring values
alpha1 = ridge_cv.best_params_
train_mse1 = ridge_cv.best_score_
test_mse1 = ridge_cv.score(X_test, y_test)

# %%
#Add scoring values to a data frame (grid_results) for easier comparison
grid_results = pd.DataFrame(columns=['Vars', 'Alpha', 'train_mse', 'test_mse'])
grid_results = grid_results.append([{'Vars':'All', 'Alpha':alpha1, 
                                     'train_mse':train_mse1, 'test_mse':test_mse1}])

# %%
#Initialize Lasso predictor variables
lasso_predictors = ['Bus_in_pt_1', 'Bus_in_pt_5', 'has_Air_conditioning', 'has_TV', 'neighborhood_Entertainment District',
                    'neighborhood_Scarborough', 'property_type_Condominium', 'reviews_per_month_notNA',
                   'room_type_Private room', 'accommodates', 'bedrooms', 'cleaning_fee', 'host_response_rate', 'minimum_nights',
                   'security_deposit', 'yelp_bus_count_5', 'yelp_bus_total_reviews_5']

# %%
#Fit gridsearch with lasso predictors
ridge_cv.fit(X_train[lasso_predictors], y_train)

#Add scores to grid_results
alpha2 = ridge_cv.best_params_
train_mse2 = ridge_cv.best_score_
test_mse2 = ridge_cv.score(X_test[lasso_predictors], y_test)

grid_results = grid_results.append([{'Vars':'Lasso', 'Alpha':alpha2, 
                                     'train_mse':train_mse2, 'test_mse':test_mse2}])

# %%
rf_predictors = ['accommodates', 'bathrooms', 'bedrooms', 'cleaning_fee', 'extra_people', 'host_response_rate',
                'minimum_nights', 'property_type_Condominium', 'reviews_per_month_notNA', 'room_type_Entire home/apt',
                'security_deposit', 'yelp_bus_count_5', 'yelp_bus_total_reviews_5']

# %%
#Fit gridsearch with lasso predictors
ridge_cv.fit(X_train[rf_predictors], y_train)

#Add scores to grid_results
alpha3 = ridge_cv.best_params_
train_mse3 = ridge_cv.best_score_
test_mse3 = ridge_cv.score(X_test[rf_predictors], y_test)

grid_results = grid_results.append([{'Vars':'RandomForest', 'Alpha':alpha3, 
                                     'train_mse':train_mse3, 'test_mse':test_mse3}])

# %%
grid_results
# Out:
#            Vars                          Alpha  train_mse  test_mse
# 0           All  {'alpha': 0.9500000000000001}  -0.153416 -0.157310
# 0         Lasso  {'alpha': 0.9500000000000001}  -0.178591 -0.183870
# 0  RandomForest  {'alpha': 0.9500000000000001}  -0.179646 -0.186533

# %% [markdown]
# #### Check Variance Inflation Factors for Multi-Collinearity

# %%
#X = abb_Price_predict.drop(['id', 'price', 'Utilization_Rate', 'log_price'], axis=1)
#features = "+".join(abb_Price_predict.columns - [['id', 'price', 'Utilization_Rate', 'log_price']])
y, X = dmatrices('price~' + X_cols, abb_Price_predict, return_type='dataframe')

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)

# %% [markdown]
# ## Predicting Utilization Rate
#
# ### Produce Baseline Utilization Rate Prediction Model
#
# #### First Calculate Price vs. Predicted Price Delta
